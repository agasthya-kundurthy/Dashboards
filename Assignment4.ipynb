# %% [markdown]
# This Python file contains the code for web scrapping data about the MSIS program of SCU, Median pay for MSIS graduates.
#
# Import all the required libraries.

# %%
import pandas
import requests

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# Tried to web scrape data using LinkedIn, but could not do it. I realised late that we need to use Selenium becasue of the dynamic nature of the website.

# %%
url = 'https://www.linkedin.com/school/10458916/'

# %%
r = requests.get(url)
##rtext = r.text()
soup = BeautifulSoup(r.content, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="519848174591-nj4uphrnrn6fjft50lvv72ikcu6jp55q.apps.googleusercontent.com" name="google-signin-clientid"/>
#   <meta content="https://www.googleapis.com/auth/plus.login https://www.googleapis.com/auth/userinfo.email" name="google-signin-scope"/>
#   <meta content="http://schema.org/AddAction" name="google-signin-requestvisibleactions"/>
#   <meta content="single_host_origin" name="google-signin-cookiepolicy"/>
#   <meta content="C8616F1DFF041DD64206D74E84019EF1" name="msvalidate.01"/>
#   <meta content="noodp" name="robots"/>
#   <meta content="FHdSolGD5jGIACQp4e9DZbhfgQo1nSJWZGKTrNn5S5c" name="google-site-verification"/>
#   <meta content="study abroad, overseas education, study overseas, international education, study in usa, ubergrad.com" property="keywords"/>
#   <meta content="Overseas Education – Ubergrad is an Online Platform for students to study abroad/overseas at various leading Universities &amp; Colleges in USA" property="description"/>
#   <meta content=" Ubergrad | Overseas Education" property="og:title"/>
#   <meta content="Overseas Education – Ubergrad is an Online Platform for students to study abroad/overseas at various leading Universities &amp; Colleges in USA" property="og:description"/>
#   <meta content="https://www.ubergrad.com/login" property="og:url"/>
#   <meta content="https://www.ubergrad.com/images/logocap.png" property="og:image"/>
#   <link href="https://www.ubergrad.com/login" rel="canonical"/>
#   <link href="https://fonts.googleapis.com/css?family=Abril+Fatface" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:300,300i,400,400i,500,500i,600,600i,700,700i" rel="stylesheet"/>
#   <style>
#    .g-recaptcha > div > div > iframe {
#             width: 100%;
#             height: 98px;
#         }
#
#         .g-recaptcha .rc-anchor-normal {
#             width: 100% !important;
#         }
#
#         #cssmenu > ul > li:last-child {
#             float: right;
#         }
#
#         @media (max-width:640px) {
#             #cssmenu > ul {
#                 padding-left: 0;
#             }
#         }
#   </style>
#   <link href="/fav32.ico" rel="icon" type="image/x-icon"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/fav120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/fav152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/PreloginHeaderCSS?v=FfwMTudvsjJrbVY80Vv3mSi53wo3jHRLi-n7k3JhCdo1" rel="stylesheet"/>
#   <style type="text/css">
#    table.aligned td section.signup-section {
#             margin-top: 0px !important;
#         }
#   </style>
#   <script type="text/javascript">
#    var Tawk_API = Tawk_API || {}, Tawk_LoadStart = new Date();
#         (function () {
#             var s1 = document.createElement("script"), s0 = document.getElementsByTagName("script")[0];
#             s1.async = true;
#             s1.src = 'https://embed.tawk.to/573aa9ac1b563e906dddf7a1/default';
#             s1.charset = 'UTF-8';
#             s1.setAttribute('crossorigin', '*');
#             s0.parentNode.insertBefore(s1, s0);
#         })();
#
#         window.heap = window.heap || [], heap.load = function (e, t) { window.heap.appid = e, window.heap.config = t = t || {}; var n = t.forceSSL || "https:" === document.location.protocol, a = document.createElement("script"); a.type = "text/javascript", a.async = !0, a.src = (n ? "https:" : "http:") + "//cdn.heapanalytics.com/js/heap-" + e + ".js"; var o = document.getElementsByTagName("script")[0]; o.parentNode.insertBefore(a, o); for (var r = function (e) { return function () { heap.push([e].concat(Array.prototype.slice.call(arguments, 0))) } }, p = ["clearEventProperties", "identify", "setEventProperties", "track", "unsetEventProperty"], c = 0; c < p.length; c++) heap[p[c]] = r(p[c]) };
#         heap.load("803541404");
#
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-44204673-1', 'ubergrad.com', { 'siteSpeedSampleRate': 100 });
#         ga('require', 'displayfeatures');
#         ga('send', 'pageview');
#
#         // Hotjar Tracking Code for http://www.ubergrad.com
#         (function (h, o, t, j, a, r) {
#             h.hj = h.hj || function () { (h.hj.q = h.hj.q || []).push(arguments) };
#             h._hjSettings = { hjid: 170562, hjsv: 5 };
#             a = o.getElementsByTagName('head')[0];
#             r = o.createElement('script'); r.async = 1;
#             r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#             a.appendChild(r);
#         })(window, document, '//static.hotjar.com/c/hotjar-', '.js?sv=');
#   </script>
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script type="text/javascript">
#    (adsbygoogle = window.adsbygoogle || []).push({
#             google_ad_client: "ca-pub-8545655977583242",
#             enable_page_level_ads: true
#         });
#   </script>
#   <title>
#    Login | Ubergrad
#   </title>
#  </head>
#  <body data-offset="120" data-spy="scroll" data-target="#myScrollspy">
#   <div class="loading">
#   </div>
#   <!--HEAER PART DESIGN START-->
#   <div id="fb-root">
#   </div>
#   <div id="headerScrollDiv">
#   </div>
#   <div class="container-fluid header">
#    <div class="row header_1">
#     <div class="fixwidthlg">
#      <div class="col-lg-2 col-md-2 col-sm-3 col-xs-8">
#       <div class="emblem">
#        <a href="/">
#         <img alt="" src="/newimages/logo.png"/>
#        </a>
#       </div>
#      </div>
#      <div class="col-lg-7 col-md-7 col-sm-4 col-xs-4">
#       <div id="cssmenu">
#        <ul>
#         <li class="headertabs" id="universitiestab">
#          <a href="https://www.ubergrad.com/universities" style="background: none;">
#           Universities
#          </a>
#         </li>
#         <li class="headertabs" id="communitytab">
#          <a href="https://www.ubergrad.com/success-stories" style="background: none;">
#           Success Stories
#          </a>
#         </li>
#         <li class="headertabs" id="marketpalcetab">
#          <a href="https://www.ubergrad.com/market-place" style="background: none;">
#           Market Place
#          </a>
#         </li>
#         <li class="headertabs" id="informationtab">
#          <a href="https://www.ubergrad.com/information-hub" style="background: none;">
#           Information Hub
#          </a>
#         </li>
#         <li class="headertabs positionrel" id="">
#          <a class="counselor" href="https://www.ubergrad.com/talk-to-our-counselor">
#           Talk to Our Counselor
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-5 col-xs-12">
#       <div class="signin">
#        <a class="active" href="https://www.ubergrad.com/login">
#         Sign In
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="row" style="border-bottom: 1px solid #eef0f2; background: #FFFFFF;">
#     <div class="fixwidthlg">
#      <div class="secnav" id="PageNameIds">
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--HEADER PART DESIGN END-->
#   <div class="fixedheight">
#    <input id="Redirecturl" name="ctl00$HTMLSection$Redirecturl" type="hidden"/>
#    <input id="hdnisLoginFromGetRecommedation" name="ctl00$HTMLSection$hdnisLoginFromGetRecommedation" type="hidden" value="0"/>
#    <style type="text/css">
#     .presentation{cursor:pointer}
# .success{color:#2BCD60}
# .danger{color:#D06377}
#    </style>
#    <div class="profileset mt30 mb30 section-forgot-password" style="max-width: 620px; position: relative; display: none;">
#     <div class="logpophead">
#      <a class="pull-left show-login-form" href="javascript:;">
#       <i class="icon icon-arrow-back">
#       </i>
#      </a>
#      Forgot Password
#     </div>
#     <div class="forgotlogin">
#      <div class="coordinatortext">
#       Enter the email-id used to register on Ubergrad and we will send you a link to reset your password.
#      </div>
#      <div class="appinp" style="max-width: 300px; margin: 0 auto;">
#       <input class="app-input" id="txtUsermail" placeholder="sample@example.com" style="text-align: center; padding: 0;" type="text"/>
#      </div>
#      <div class="text-center" id="errorPassword" style="margin-top: 15px;">
#      </div>
#      <a class="signupbutton verifybtn" data-toggle="modal" href="#" id="getPassword">
#       Send
#      </a>
#     </div>
#    </div>
#    <!--PROFILE STEP 1 PART DESIGN START-->
#    <div class="section-log-in">
#     <div class="modal-header">
#      <button class="close" data-dismiss="modal" id="closeLoginIcon" style="display:none;" type="button">
#       ×
#      </button>
#      <h4 class="modal-title" id="modaltitle" style="text-align:center;">
#       Sign In
#      </h4>
#     </div>
#     <div class="profileset" style="max-width:620px;">
#      <div style="padding:30px;">
#       <div class="coordinatortext">
#        with any of the social profiles
#       </div>
#       <div class="row">
#        <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#         <a class="facebookbtn fb_login" href="javascript:;">
#          Sign up with Facebook
#         </a>
#        </div>
#        <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#         <a class="gplusbtn g_login" href="javascript:;">
#          Sign up with Google Plus
#         </a>
#        </div>
#       </div>
#       <div class="signor">
#        <span>
#         OR
#        </span>
#       </div>
#       <div class="coordinatortext">
#        Sign in with Mobile OTP
#       </div>
#       <div class="row" id="sendOTPdiv">
#        <div class="col-lg-9 col-md-9 col-sm-9 col-xs-12">
#         <div class="clearfix">
#          <div class="twoparts">
#           <div class="apptext">
#            Country Prefix
#           </div>
#           <div class="selectinputtype inputnocurveleft mbzero">
#            <select class="inputselect" id="login_countryprefix">
#             <option value="99">
#              +91 India
#             </option>
#            </select>
#           </div>
#          </div>
#          <div class="twoparts">
#           <div class="apptext">
#            Mobile Number
#           </div>
#           <div class="appinp">
#            <input class="app-input inputnocurveright" id="login_mobilenumber" placeholder="Mobile Number"/>
#           </div>
#          </div>
#         </div>
#         <div class="clearfix" style="min-height:24px;">
#          <div id="errorMessage_OTP">
#          </div>
#         </div>
#        </div>
#        <div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
#         <a class="signupbutton pull-right mt30" href="javascript:;" id="sendOTP">
#          Send OTP
#         </a>
#        </div>
#       </div>
#       <div class="row" id="CheckOTPDiv" style="display:none;">
#        <div class="col-lg-9 col-md-9 col-sm-9 col-xs-12">
#         <div class="loginotptext">
#          We have sent you an OTP (One Time Password) on
#          <span id="displayMnumber">
#          </span>
#          .
#         </div>
#         <div class="appinp">
#          <input class="app-input" id="login_OTP" placeholder="Enter OTP (One Time Password)"/>
#         </div>
#         <div class="clearfix" style="min-height:24px;">
#          <div id="errorMessage_CheckOTP">
#          </div>
#         </div>
#        </div>
#        <div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
#         <a class="signupbutton pull-right mt30" href="javascript:;" id="loginOTP">
#          Sign In
#         </a>
#        </div>
#       </div>
#       <div class="signor" style="margin-top:10px;">
#        <span>
#         OR
#        </span>
#       </div>
#       <div class="coordinatortext">
#        Sign in with Ubergrad account
#       </div>
#       <div class="apptext">
#        Email
#       </div>
#       <div class="appinp">
#        <input class="app-input" id="txtUsername" name="ctl00$HTMLSection$ctl00$txtUsername" placeholder="Email address" type="email"/>
#       </div>
#       <div class="apptext">
#        Password
#       </div>
#       <div class="appinp">
#        <input class="app-input" id="txtPassword" name="ctl00$HTMLSection$ctl00$txtPassword" placeholder="Password" style="color: black;" type="password"/>
#       </div>
#       <div id="errorMessage">
#       </div>
#       <div class="row mt10">
#        <div class="col-lg-7 col-md-7 col-sm-7 col-xs-7">
#         <div class="notify mt10">
#          <span class="squaredThree">
#           <input id="remember" name="ctl00$HTMLSection$ctl00$remember" type="checkbox" value="None"/>
#           <label for="remember" style="right: 0px;">
#           </label>
#          </span>
#          <span class="plan">
#           Remember Me
#          </span>
#         </div>
#        </div>
#        <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5">
#         <a class="signupbutton pull-right" href="javascript:;" id="login_ID">
#          Sign In
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="profilefoot clearfix">
#       <div class="forgot aligncenter">
#        <a class="show-reset-form" href="javascript:;">
#         Forgot Password?
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="fixwidthsm footerversionone" id="footer">
#    <div class="row">
#     <div class="col-lg-8 col-md-8 col-sm-12 col-xs-12">
#      <div class="footerversiononenav">
#       <a href="https://www.ubergrad.com/about-us">
#        About Us
#       </a>
#       <a href="https://www.ubergrad.com/contact-us">
#        Contact Us
#       </a>
#       <a href="https://www.ubergrad.com/terms">
#        Terms &amp; Conditions
#       </a>
#       <a href="https://www.ubergrad.com/policy">
#        Privacy Policy
#       </a>
#       <a href="https://www.ubergrad.com/sitemap">
#        Site Map
#       </a>
#      </div>
#     </div>
#     <div class="col-lg-4 col-md-4 col-sm-12 col-xs-12">
#      <div class="footerversiononenav footerversiononesocial">
#       <a href="https://twitter.com/ubergrad_com">
#        <img alt="" src="/newimages/ftwit.png"/>
#       </a>
#       <a href="https://www.facebook.com/Ubergrad">
#        <img alt="" src="/newimages/fface.png"/>
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="errors_modal">
#    <div class="modal-dialog" style="margin: 260px auto;">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#        <span class="sr-only">
#         Close
#        </span>
#       </button>
#      </div>
#      <div class="modal-body" id="popup_err_message" style="color: red; font-size: 14px;">
#      </div>
#     </div>
#     <!-- /.modal-content -->
#    </div>
#    <!-- /.modal-dialog -->
#   </div>
#   <!-- /.modal -->
#   <div aria-hidden="true" class="modal fade" id="SignUpModal" role="dialog" style="display: none;" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content signup-modal">
#      <section class="signup-section clearfix">
#       <style>
#        @media (max-width:1024px){.tabletwidth{width:100%}.facebookbtn,.gplusbtn{margin-top:10px}}
#       </style>
#       <div class="profilestephead dark" style="position: relative;">
#        Create Account
#        <button class="close" data-dismiss="modal" type="button">
#         ×
#        </button>
#       </div>
#       <div class="clearfix popupregstyle" style="background: #FFFFFF; padding: 10px 30px;">
#        <div class="registersmallhead">
#         Use your social accounts or Sign Up with your Email
#        </div>
#        <div class="row">
#         <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12 tabletwidth">
#          <a class="facebookbtn fb_login" href="javascript:;">
#           Sign up with Facebook
#          </a>
#         </div>
#         <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12 tabletwidth">
#          <a class="gplusbtn g_login" href="javascript:;">
#           Sign up with Google Plus
#          </a>
#         </div>
#        </div>
#        <div class="signor">
#         <span>
#          OR
#         </span>
#        </div>
#        <div class="row">
#         <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#          <div class="apptext">
#           First Name
#          </div>
#          <div class="appinp">
#           <input class="app-input" id="fir_name_signup" placeholder="First Name" type="text"/>
#          </div>
#         </div>
#         <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#          <div class="apptext">
#           Last Name
#          </div>
#          <div class="appinp">
#           <input class="app-input" id="last_name_signup" placeholder="Last Name" type="text"/>
#          </div>
#         </div>
#        </div>
#        <div class="row">
#         <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#          <div class="apptext">
#           Email
#          </div>
#          <div class="appinp">
#           <input class="app-input" data-placement="bottom" data-toggle="tooltip" id="email_signup" placeholder="Email Address" title="Please enter a valid and active email-id as we would be sending you a verification code to verify this email-id" type="text"/>
#          </div>
#         </div>
#        </div>
#        <div class="row">
#         <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#          <div class="apptext">
#           What do you plan to study ?
#          </div>
#          <div class="row">
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#            <div class="listfilter clearfix antilistfilter" style="background: none;">
#             <ul>
#              <li style="float: left;">
#               <input id="IsBachelors" name="DegreeLevel" type="radio" value="Bachelors"/>
#               <label class="bachelors" for="IsBachelors" style="font-size:12px; font-weight:400;">
#                Bachelors
#               </label>
#               <div class="check" style="top:0px; width:15px; height:15px;">
#               </div>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#            <div class="listfilter clearfix antilistfilter" style="background: none;">
#             <ul>
#              <li style="float: left;">
#               <input id="IsMasters" name="DegreeLevel" type="radio" value="Masters"/>
#               <label class="bachelors" for="IsMasters" style="font-size:12px; font-weight:400;">
#                Masters
#               </label>
#               <div class="check" style="top:0px; width:15px; height:15px;">
#               </div>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="row">
#         <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#          <div class="apptext">
#           Password
#          </div>
#          <div class="appinp">
#           <input class="app-input" id="passwd_signup" placeholder="Password" type="password"/>
#          </div>
#         </div>
#         <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#          <div class="apptext">
#           Confirm Password
#          </div>
#          <div class="appinp">
#           <input class="app-input" id="confm_pass_signup" placeholder="Confirm Password" type="password"/>
#          </div>
#         </div>
#        </div>
#        <div class="clearfix mt20">
#         <div class="notify">
#          <span class="squaredThree">
#           <input checked="checked" id="agreeTerms" name="check" type="checkbox" value="1"/>
#           <label for="agreeTerms" style="right: 0px;">
#           </label>
#          </span>
#          <span class="plan">
#           I agree to
#           <a href="/terms">
#            Terms &amp; Conditions
#           </a>
#           .
#          </span>
#         </div>
#        </div>
#        <div class="clearfix">
#         <div class="notify" style="margin-top: -8px; position: absolute;">
#          <span class="squaredThree">
#           <input checked="checked" id="weeklyLessons" name="check" type="checkbox" value="1"/>
#           <label for="weeklyLessons" style="right: 0px;">
#           </label>
#          </span>
#          <span class="plan">
#           Signup to Ubergrad Weekly Lessons.
#          </span>
#         </div>
#        </div>
#        <div id="error" style="display: none; padding-left: 20px; margin-top: 30px;">
#        </div>
#        <div class="profilefoot clearfix" style="margin-top: 30px;">
#         Already a Member?
#         <a href="/login" id="LoginLink">
#          Sign In
#         </a>
#         <a class="signupbutton pull-right" href="javascript:;" id="signup">
#          Sign Up
#         </a>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="LoginModal" role="dialog" style="display: none;" tabindex="-1">
#    <div class="modal-dialog" id="">
#     <div class="modal-content signup-modal">
#      <section class="signup-section clearfix">
#       <style type="text/css">
#        .presentation{cursor:pointer}
# .success{color:#2BCD60}
# .danger{color:#D06377}
#       </style>
#       <div class="profileset mt30 mb30 section-forgot-password" style="max-width: 620px; position: relative; display: none;">
#        <div class="logpophead">
#         <a class="pull-left show-login-form" href="javascript:;">
#          <i class="icon icon-arrow-back">
#          </i>
#         </a>
#         Forgot Password
#        </div>
#        <div class="forgotlogin">
#         <div class="coordinatortext">
#          Enter the email-id used to register on Ubergrad and we will send you a link to reset your password.
#         </div>
#         <div class="appinp" style="max-width: 300px; margin: 0 auto;">
#          <input class="app-input" id="txtUsermail" placeholder="sample@example.com" style="text-align: center; padding: 0;" type="text"/>
#         </div>
#         <div class="text-center" id="errorPassword" style="margin-top: 15px;">
#         </div>
#         <a class="signupbutton verifybtn" data-toggle="modal" href="#" id="getPassword">
#          Send
#         </a>
#        </div>
#       </div>
#       <!--PROFILE STEP 1 PART DESIGN START-->
#       <div class="section-log-in">
#        <div class="modal-header">
#         <button class="close" data-dismiss="modal" id="closeLoginIcon" style="display:none;" type="button">
#          ×
#         </button>
#         <h4 class="modal-title" id="modaltitle" style="text-align:center;">
#          Sign In
#         </h4>
#        </div>
#        <div class="profileset" style="max-width:620px;">
#         <div style="padding:30px;">
#          <div class="coordinatortext">
#           with any of the social profiles
#          </div>
#          <div class="row">
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#            <a class="facebookbtn fb_login" href="javascript:;">
#             Sign up with Facebook
#            </a>
#           </div>
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#            <a class="gplusbtn g_login" href="javascript:;">
#             Sign up with Google Plus
#            </a>
#           </div>
#          </div>
#          <div class="signor">
#           <span>
#            OR
#           </span>
#          </div>
#          <div class="coordinatortext">
#           Sign in with Mobile OTP
#          </div>
#          <div class="row" id="sendOTPdiv">
#           <div class="col-lg-9 col-md-9 col-sm-9 col-xs-12">
#            <div class="clearfix">
#             <div class="twoparts">
#              <div class="apptext">
#               Country Prefix
#              </div>
#              <div class="selectinputtype inputnocurveleft mbzero">
#               <select class="inputselect" id="login_countryprefix">
#                <option value="99">
#                 +91 India
#                </option>
#               </select>
#              </div>
#             </div>
#             <div class="twoparts">
#              <div class="apptext">
#               Mobile Number
#              </div>
#              <div class="appinp">
#               <input class="app-input inputnocurveright" id="login_mobilenumber" placeholder="Mobile Number"/>
#              </div>
#             </div>
#            </div>
#            <div class="clearfix" style="min-height:24px;">
#             <div id="errorMessage_OTP">
#             </div>
#            </div>
#           </div>
#           <div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
#            <a class="signupbutton pull-right mt30" href="javascript:;" id="sendOTP">
#             Send OTP
#            </a>
#           </div>
#          </div>
#          <div class="row" id="CheckOTPDiv" style="display:none;">
#           <div class="col-lg-9 col-md-9 col-sm-9 col-xs-12">
#            <div class="loginotptext">
#             We have sent you an OTP (One Time Password) on
#             <span id="displayMnumber">
#             </span>
#             .
#            </div>
#            <div class="appinp">
#             <input class="app-input" id="login_OTP" placeholder="Enter OTP (One Time Password)"/>
#            </div>
#            <div class="clearfix" style="min-height:24px;">
#             <div id="errorMessage_CheckOTP">
#             </div>
#            </div>
#           </div>
#           <div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
#            <a class="signupbutton pull-right mt30" href="javascript:;" id="loginOTP">
#             Sign In
#            </a>
#           </div>
#          </div>
#          <div class="signor" style="margin-top:10px;">
#           <span>
#            OR
#           </span>
#          </div>
#          <div class="coordinatortext">
#           Sign in with Ubergrad account
#          </div>
#          <div class="apptext">
#           Email
#          </div>
#          <div class="appinp">
#           <input class="app-input" id="txtUsername" name="ctl00$ctl02$txtUsername" placeholder="Email address" type="email"/>
#          </div>
#          <div class="apptext">
#           Password
#          </div>
#          <div class="appinp">
#           <input class="app-input" id="txtPassword" name="ctl00$ctl02$txtPassword" placeholder="Password" style="color: black;" type="password"/>
#          </div>
#          <div id="errorMessage">
#          </div>
#          <div class="row mt10">
#           <div class="col-lg-7 col-md-7 col-sm-7 col-xs-7">
#            <div class="notify mt10">
#             <span class="squaredThree">
#              <input id="remember" name="ctl00$ctl02$remember" type="checkbox" value="None"/>
#              <label for="remember" style="right: 0px;">
#              </label>
#             </span>
#             <span class="plan">
#              Remember Me
#             </span>
#            </div>
#           </div>
#           <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5">
#            <a class="signupbutton pull-right" href="javascript:;" id="login_ID">
#             Sign In
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="profilefoot clearfix">
#          <div class="forgot aligncenter">
#           <a class="show-reset-form" href="javascript:;">
#            Forgot Password?
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="WelcomeModal" role="dialog" style="display: none;" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content signup-modal">
#      <section class="signup-section clearfix">
#       <!--PROFILE STEP 1 PART DESIGN START-->
#       <div class="profilestephead dark">
#        Welcome to Ubergrad !
#        <span>
#         Your registration is complete.
#        </span>
#       </div>
#       <div class="profileset mb30" style="max-width: 620px;">
#        <div class="verifyemail">
#         <img alt="" height="129" src="/newimages/confirmemail_icon.jpg" width="112"/>
#         <br/>
#         <br/>
#         <span>
#          Build your profile now
#         </span>
#         Universities like to contact students with complete profiles. A comprehensive profile also helps us make correct University recommendations.
#        </div>
#        <div class="profilefoot clearfix">
#         <a href="https://www.ubergrad.com" id="doitlater">
#          I will do it later
#         </a>
#         <a class="signupbutton buildyourprofile" href="javascript:;">
#          Complete Profile
#         </a>
#        </div>
#       </div>
#       <!-- Facebook Pixel Code -->
#       <script type="text/javascript">
#        !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window,document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
#  fbq('init', '221476741617752');
# fbq('track', 'PageView');
# fbq('track', 'CompleteRegistration');
#       </script>
#       <noscript>
#        <img height="1" src="https://www.facebook.com/tr?id=221476741617752&amp;ev=PageView
# &amp;noscript=1" width="1"/>
#       </noscript>
#       <!-- End Facebook Pixel Code -->
#      </section>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="EmailVerifyModal" role="dialog" style="display: none;" tabindex="-1">
#    <div class="modal-dialog modal-lg" style="max-width: 720px;">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h4 class="modal-title" style="text-align: center;">
#        Verifications
#       </h4>
#      </div>
#      <div class="modal-body" style="padding: 0px;">
#       <div class="mainreport" style="text-align: center;">
#        <div class="profileset" style="max-width:620px;">
#         <div id="EmailVerificationDiv">
#          <div class="row verifyborderbottom" id="divrecverihead">
#           <div class="col-lg-8 col-md-8 col-sm-8 col-xs-12">
#            <div class="fullverificationhead titlehead">
#             <span>
#              Email Verification
#             </span>
#            </div>
#           </div>
#           <div class="col-lg-4 col-md-4 col-sm-4 col-xs-12">
#            <button class="buttonfullblue skipverifybtn" id="hrefEmialSkip1" style="display: none;">
#             Skip
#            </button>
#           </div>
#          </div>
#          <div class="tentwenty">
#           <div id="divStep1" style="display: none;">
#            <div class="verifyicon emailverifynormal">
#            </div>
#            <div class="textone aligncenter mb10">
#             Please enter the One Time Password (OTP) sent to
#             <br/>
#             your email id
#             <span id="spanUserEmail" style="color:#ef7245;">
#             </span>
#             here.
#             <a href="javascript:;" id="ChangeEmailAddress" style="margin-top: 0px;">
#              Change Email Address
#             </a>
#            </div>
#            <div class="verifywidth" id="divNOchangeEmail">
#             <div class="row">
#              <div class="col-lg-8 col-lg-8 col-lg-8 col-lg-12">
#               <div class="appinp mb10">
#                <input class="app-input" id="txtEmailVerifyCode" placeholder="e.g. 7240" type="text"/>
#                <span id="spanEmailError">
#                </span>
#               </div>
#              </div>
#              <div class="col-lg-4 col-lg-4 col-lg-4 col-lg-12">
#               <a class="buttonborderblue" href="javascript:;" id="hrefEmailVerify">
#                Verify
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="verifywidth" id="divchangeEmail" style="display: none;">
#             <div class="row">
#              <div class="col-lg-8 col-lg-8 col-lg-8 col-lg-12">
#               <div class="appinp mb10">
#                <input class="app-input" id="txtUserEmail" placeholder="Email" type="text"/>
#                <span id="spanchangeEmailErr">
#                </span>
#               </div>
#              </div>
#              <div class="col-lg-4 col-lg-4 col-lg-4 col-lg-12">
#               <a class="buttonborderblue" href="javascript:;" id="hrefVerifyEmailSendAgain">
#                Submit
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="textone aligecenter" style="margin-bottom: 0px;">
#             Did not receive yet?
#             <a href="javascript:;" id="hrefEmialSendAgain" style="font-weight: 500; margin-top: 0px; display: inline-block;">
#              Send Again
#             </a>
#            </div>
#           </div>
#           <div class="verifygapnew" id="emailVerifySuccess" style="display: none;">
#            <div class="verifyicon emailverifysuccess">
#            </div>
#            <div class="textone aligncenter mb10">
#             Your Email is verified Successfully.
#            </div>
#           </div>
#           <div class="verifygapnew" id="divEmailSkip" style="display: none;">
#            <div class="verifyicon emailverifyskip">
#            </div>
#            <div class="textone aligncenter mb10">
#             Thank you register with us,
#             <br/>
#             your email not verified yet verify it later.
#            </div>
#           </div>
#          </div>
#         </div>
#         <div id="MobileVerificationDiv">
#          <div class="row verifyborderbottom" id="divrecveriheadm" style="border-top:#ebebeb 1px solid;">
#           <div class="col-lg-8 col-md-8 col-sm-8 col-xs-12">
#            <div class="fullverificationhead titlehead">
#             <span>
#              Mobile Verification
#             </span>
#            </div>
#           </div>
#           <div class="col-lg-4 col-md-4 col-sm-4 col-xs-12">
#            <button class="buttonfullblue skipverifybtn" id="hrefMobileSkip2" style="display: none;">
#             Skip
#            </button>
#           </div>
#          </div>
#          <div class="tentwenty">
#           <div id="divStep2" style="display: none;">
#            <div class="verifyicon mobileverifynormal">
#            </div>
#            <div class="textone aligncenter mb10">
#             Please enter the One Time Password (OTP) sent to
#             <br/>
#             your mobile number
#             <span id="spanUserMobileNUmber" style="color:#e7a800;">
#             </span>
#             here.
#             <a href="javascript:;" id="ChangeMobileNumber" style="margin-top: 0px;">
#              Change Phone Number
#             </a>
#            </div>
#            <div class="verifywidth" id="divNOchangeMobile">
#             <div class="row">
#              <div class="col-lg-8 col-lg-8 col-lg-8 col-lg-12">
#               <div class="appinp mb10">
#                <input class="app-input" id="txtMobileVerification" placeholder="e.g. 7240" type="text"/>
#                <span id="spanMObilelError">
#                </span>
#               </div>
#              </div>
#              <div class="col-lg-4 col-lg-4 col-lg-4 col-lg-12">
#               <a class="buttonborderblue" href="javascript:;" id="hrefMobileVerify">
#                Verify
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="verifywidth" id="divchangeMobile" style="display: none;">
#             <div class="row">
#              <div class="col-lg-8 col-lg-8 col-lg-8 col-lg-12">
#               <div class="appinp mb10">
#                <input class="app-input" id="txtUserMobile" placeholder="Mobile Number" type="text"/>
#                <span id="spanchangeMobileErr">
#                </span>
#               </div>
#              </div>
#              <div class="col-lg-4 col-lg-4 col-lg-4 col-lg-12">
#               <a class="buttonborderblue" href="javascript:;" id="hrefVerifyMobileSendAgain">
#                Submit
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="textone aligecenter mt10" style="margin-bottom: 0px;">
#             Did not receive yet?
#             <a href="javascript:;" id="hrefMobileSendAgain" style="font-weight: 500; margin-top: 0px; display: inline-block;">
#              Send Again
#             </a>
#            </div>
#           </div>
#           <div class="verifygap" id="MobilelVerifySuccess" style="display: none;">
#            <div class="verifyicon mobileverifysuccess">
#            </div>
#            <div class="textone aligncenter mb10">
#             Your Mobile is verified Successfully.
#            </div>
#           </div>
#           <div class="verifygap" id="divMobileSkip" style="display: none;">
#            <div class="verifyicon mobileverifyskip">
#            </div>
#            <div class="textone aligncenter mb10">
#             Thank you register with us,
#             <br/>
#             your mobile not verified yet verify it later.
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="modal-footer" style="text-align: center;">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="project-modal-label" class="modal fade home_page_dialog" id="ThankYouForSubscribing" role="dialog" tabindex="-1">
#    <div class="modal-dialog" style="width: 45%;">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h4 class="modal-title" id="H5">
#        <span style="color: #fe7e03">
#         Thank you For Subscribing
#        </span>
#       </h4>
#      </div>
#      <div class="modal-body">
#       <div class="row">
#        <div class="col-md-12">
#         <div id="thankYouMessage">
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-default" data-dismiss="modal" type="button">
#        Close
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="project-modal-label" class="modal fade home_page_dialog" id="DefaultPopup" role="dialog" tabindex="-1">
#    <div class="modal-dialog" style="width: 45%;">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h4 class="modal-title">
#        <span id="Defaultheading" style="color: #fe7e03">
#        </span>
#       </h4>
#      </div>
#      <div class="modal-body">
#       <div class="row">
#        <div class="col-md-12">
#         <div id="Defaultcontent">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="DegreeLevelModal" role="dialog">
#    <div class="modal-dialog modal-md">
#     <div class="modal-content">
#      <div class="modal-header" style="border-bottom: none;">
#      </div>
#      <div class="modal-body">
#       <div class="mainreport">
#        <div class="row">
#         <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#          <div class="headingone aligncenter">
#           What Do You Want Study
#          </div>
#          <div style="padding: 0px 20px 20px 20px;">
#           <div class="row">
#            <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#             <a class="bachelordegree" href="javascript:;" id="StuBachelor">
#              <img src="/newimages/bachelor_icon.png"/>
#              Bachelors Degree
#             </a>
#            </div>
#            <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#             <a class="bachelordegree" href="javascript:;" id="StuMaster" style="background: #d0a9f8;">
#              <img src="/newimages/master_icon.png"/>
#              Masters Degree
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="mapEmailPopup" role="dialog">
#    <div class="modal-dialog modal-md">
#     <div class="modal-content">
#      <div class="modal-header" style="border-bottom: none;">
#      </div>
#      <div class="modal-body">
#       <div class="mainreport">
#        <div class="row">
#         <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#          <div class="headingone aligncenter" id="mapemailheading">
#          </div>
#          <div style="padding: 0px 20px 20px 20px;">
#           <div class="row">
#            <div class="apptext">
#             Email Address
#            </div>
#            <div class="appinp">
#             <input class="app-input" id="mapEmail" placeholder="Email Address" style="color: black;"/>
#            </div>
#            <div id="errorMessage_mapEmail">
#            </div>
#            <a class="signupbutton pull-right" href="javascript:;" id="mapMobileToEmail">
#             Submit
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <input id="Redirecturl" type="hidden"/>
#   <input id="PageORPopup" type="hidden" value="1"/>
#   <input id="Captcharesponse" type="hidden" value=""/>
#   <input id="hdn_actiontab" type="hidden" value=""/>
#   <input id="hdn_profilepic" type="hidden" value=""/>
#   <input id="hdn_currentobj" objecttype="" type="hidden" value=""/>
#   <input id="HdnEmail" type="hidden"/>
#   <input id="OffsiteRedirecturl" name="ctl00$OffsiteRedirecturl" type="hidden"/>
#   <input id="hdnWebsiteURL" name="ctl00$hdnWebsiteURL" type="hidden" value="https://www.ubergrad.com"/>
#   <script async="" defer="" src="https://apis.google.com/js/client:platform.js?onload=render">
#   </script>
#   <script src="/PreloginHeaderScript?v=R_aa2Zy1PkJxydgujr-mUXB5mrHytUPuGgQLPPLUMEQ1">
#   </script>
#   <script src="/content/scripts/blockUI.js">
#   </script>
#   <script type="text/javascript">
#    function blinker() { $('.blinking').fadeOut(800); $('.blinking').fadeIn(800); }
#         setInterval(blinker, 1000);
#         var CurrentClickedObj;
#         $('[data-toggle="tooltip"]').tooltip();
#         $(document).delegate("#doitlater", "click", function () {
#             window.location.href = "/" + $("#Redirecturl").val();
#         });
#         $(document).delegate(".fb_login", "click", function () {
#             login();
#             schedule_login = $(".fb-login").attr("sch");
#             tutorial_login = $(".fb-login").attr("tt");
#         });
#         $(document).delegate(".g_login", "click", function () {
#             gapi.auth.signIn({
#                 'callback': signinCallback
#             });
#         });
#
#         function login() {
#             FB.getLoginStatus(function (a) {
#                 if (a.status === "connected") {
#                     console.log(a.authResponse.userID);
#                     create_session(a.authResponse.userID);
#                 } else {
#                     FB.login(function (response) {
#                         if (response.authResponse) {
#                             // connected
#                             access_token = response.authResponse.accessToken;
#                             fb_user_id = response.authResponse.userID;
#                             create_session(fb_user_id);
#                             console.log(access_token);
#                             console.log(fb_user_id);
#                         } else {
#                             // cancelled
#                         }
#                     }, { scope: 'email,publish_actions' })
#                 }
#             });
#         }
#
#         function create_session(fb_user_id) {
#             FB.api('/me', { fields: 'email,first_name,last_name,gender,name,location' }, function (response) {
#                 //console.log(response);
#                 var st = "", city = "", country = "", gender = "", fn = "", ln = "";
#                 fn = (response.first_name) ? response.first_name : "";
#                 ln = (response.last_name) ? response.last_name : "";
#                 gender = (response.gender) ? response.gender : "";
#                 city = (response.location) ? response.location.name : "";
#                 var tutorial = $('#tutorial').html();
#                 var PageorPopup = $("#PageORPopup").val();
#                 $.ajax(
#                         {
#                             url: '/StudentLogin.ashx',
#                             type: 'POST',
#                             dataType: 'JSON',
#                             beforeSend: function (xhr) { xhr.setRequestHeader('X-CSRF-Token', $('meta[name="csrf-token"]').attr('content')) },
#                             data: {
#                                 type: 6, facebook_user_id: response.id, facebook_name: response.name, facebook_email: response.email, tutorial: tutorial,
#                                 first_name: fn, last_name: ln, gender: gender, state: st, country: country, city: city
#                             },
#                             success: function (data) {
#                                 if (data.ret_msg == 'ok') {
#                                     if (PageorPopup == 0) {
#                                     $("#SignUpModal").modal("hide");
#                                     //if (res.profileStatus == 0) {
#                                     //        SignupAfterAction(res.profileStatus);
#                                     //       $("#WelcomeModal").modal("show");
#                                     //   } else {
#                                             window.location.reload();
#                                      //  }
#                                    }
#                                     if (PageorPopup == 1 ) {
#                                     //  window.location.href = "/welcome";
#                                     //} else if (res.profileStatus == 1) {
#                                         window.location.href = "/studenthome";
#                                     }
#                                   // $("#DegreeLevelModal").modal("show");
#                                   if ($("#OffsiteRedirecturl").val() != "") {
#                                        window.location.href = $("#OffsiteRedirecturl").val();
#                                    }
#                                   else {
#                                       // SignupAfterAction(data.profileStatus);
#                                       window.location.href = "/studenthome";
#                                   }
#
#                                 }
#                                 else if (data.ret_msg == 'exists') {
#                                     alert("email already exists");
#                                 }
#                             }
#                         }
#                         );
#             });
#         }
#         var access_token = "";
#         var fb_user_id = "";
#         $(document).ready(function () {
#             $("#registration").addClass("active");
#             $("#logIn").removeClass("active");
#             (function () {
#                 var e = document.createElement('script');
#                 e.src = '//connect.facebook.net/en_US/all.js';
#                 e.async = true;
#                 document.getElementById('fb-root').appendChild(e);
#             }());
#             window.fbAsyncInit = function () {
#
#                 FB.init({ appId: "170090126513098", status: true, cookie: true, xfbml: true, oauth: true });
#             };
#         });
#
#         //function render() {
#         //    $('.g_login').click(function () {
#         //        gapi.auth.signIn({
#         //            'callback': signinCallback
#         //        });
#         //    });
#         //}
#         function signinCallback(authResult) {
#             var PageorPopup = $("#PageORPopup").val();
#             if (authResult['status']['signed_in']) {
#                 console.log(authResult);
#                 if (authResult['status']['method'] == "PROMPT") {
#                     $.ajax({
#                         url: "/StudentLogin.ashx",
#                         type: "POST",
#                         async: false,
#                         data: { atoken: authResult.access_token, type: 7 },
#                         dataType: "json",
#                         success: function (a) {
#
#                             $.ajax({
#                                 url: "/StudentLogin.ashx",
#                                 type: "POST",
#                                 async: false,
#                                 data: { name: a.name, email: a.email, user_id: a.id, picture: a.picture, type: 8, otype: "google", fname: a.given_name, lname: a.family_name },
#                                 dataType: "json",
#                                 success: function (a) {
#                                     if (a.ret_msg == 'ok') {
#                                        // $("#DegreeLevelModal").modal("show");
#                                         if ($("#OffsiteRedirecturl").val() != "") {
#                                             window.location.href = $("#OffsiteRedirecturl").val();
#                                         }
#                                         else {
#                                             //SignupAfterAction(a.profileStatus);
#                                             window.location.href = "/studenthome";
#                                         }
#
#                                         if (PageorPopup == 0) {
#                                             $("#SignUpModal").modal("hide");
#                                             //if (res.profileStatus == 0) {
#                                             //    $("#WelcomeModal").modal("show");
#                                             //} else {
#                                                 window.location.reload();
#                                             //}
#                                         }
#                                         if (PageorPopup == 1) {
#                                         //    window.location.href = "/welcome";
#                                         //} else if (res.profileStatus == 1) {
#                                             window.location.href = "/studenthome";
#                                         }
#
#                                     }
#                                     else if (a.ret_msg == 'exists') {
#                                         alert("Already account exists with this Email Address !! Please use another account.");
#                                     }
#                                 },
#                                 error: function (a, err) { alert(err); }
#                             });
#
#
#                         },
#                         error: function (a, err) {
#                             alert(err);
#                         }
#                     });
#
#                 }
#             }
#         }
#         function ReplaceAllSpecChar(name) {
#             name = name.replace(/( |_|&|-|\/|'|"|,)+/gi, '-');
#             return name;
#         }
#
#
#         function GetUnivEncodedName(name) {
#             name = name.replace(/[^a-zA-Z0-9]+/gi, '-').replace(/(^-)|(-$)/g, "");
#             return name;
#         }
#         $(document).ready(function () {
#             $(document).on("click", ".headerscroll", function () {
#                 $("html, body").animate({ scrollTop: $("#headerScrollDiv").offset().top - 300 }, 1000);
#             });
#             $(document).on('click', '.show-reset-form', function () {
#                 $("#errorPassword").html('')
#                 $("#two_btn").hide();
#                 $("#txtUsermail").val('');
#                 $(".section-log-in").hide();
#                 $(".section-forgot-password").show();
#             });
#             $(document).on('click', '.show-login-form', function () {
#                 $(".section-log-in").show();
#                 $(".section-forgot-password").hide();
#
#             });
#             $('#txtSearchUniversityName').keypress(function (event) {
#                 if (event.keyCode == 13) {
#                     var searchUniversityKey = $('#txtSearchUniversityName').val();
#                     if (searchUniversityKey != '' || searchUniversityKey != 0) {
#                         window.location.href = $("#hdnWebsiteURL").val() + '/CommunityCollegeList.aspx?universityKey=' + searchUniversityKey;
#                     }
#                 }
#             });
#
#
#             var images = $(".img-circle");
#             images.on('load', function () {
#             }).on('error', function () { $(this).attr("src", "/newimages/add-universe.png") });
#
#         });
#   </script>
#   <script src="/Content/scripts/stulogin.js">
#   </script>
#   <script type="text/javascript">
#    $("#PageNameIds").html('<ul><li><a href="/">Home</a></li>Sign In</ul>');
#   </script>
#   <script type="text/javascript">
#    //var verifyCallback = function (response) {
#         //    $("#Captcharesponse").val(response);
#         //};
#         //var LoadCallBack = function () {
#         //    grecaptcha.render('googlecaptcha', {
#         //        'sitekey': '6Le_BhcUAAAAAPl9y_eAFogi3SHgtA-XiMDxUM65',
#         //        'callback': verifyCallback
#         //    });
#         //}
#
#         function VerifyCaptcha() {
#             var boolFlag = false;
#             $.ajax({
#                 url: "/StudentLogin.ashx",
#                 type: "POST",
#                 async: false,
#                 data: { gresponse: $("#Captcharesponse").val(), type: 29 },
#                 dataType: "JSON",
#                 success: function (a) {
#                     //alert(a.success);
#                     boolFlag = a.success;
#                 },
#                 error: function (res, err) {
#                     console.log(err);
#                 }
#             });
#             return boolFlag;
#         }
#         $(document).on("click", "#StuBachelor", function () {
#             var studentLevel = 'Bachelors';
#             submitstudentlevel(studentLevel);
#         });
#         $(document).on("click", "#StuMaster", function () {
#             var studentLevel = 'Masters';
#             submitstudentlevel(studentLevel);
#         });
#         function submitstudentlevel(studentLevel) {
#             $.ajax({
#                 url: "/StudentLogin.ashx",
#                 type: "POST",
#                 async: false,
#                 data: { Degreelevel: studentLevel, type: 31 },
#                 dataType: "JSON",
#                 success: function (a) {
#                     if (a.retMsg == 'ok') {
#                         $("#DegreeLevelModal").modal("hide");
#                         if ($("#OffsiteRedirecturl").val() != "") {
#                             window.location.href = $("#OffsiteRedirecturl").val();
#                         }
#                         else {
#                             if (studentLevel == "Bachelors") {
#                                 window.location.href = "Bachelors/Home";
#                             }
#                             else {
#                                 window.location.href = "/studenthome";
#                             }
#                             //SignupAfterAction(a.Level, a.profileStatus);
#                         }
#
#                     }
#                 },
#                 error: function (res, err) {
#                     console.log(err);
#                 }
#             });
#         }
#   </script>
#  </body>
# </html>

# %%
for links in soup.find_all("a"):
    print(links.get("href"))
# Out:
# /feed/
# /feed/
# /feed/
# /mynetwork/
# /jobs/
# /messaging/
# /notifications/
# #

# %%
for links in soup.find_all("a"):
    print(links.get("href"),"  ", links)
# Out:
# /feed/    <a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/"><span aria-role="presentation" class="nav-item__icon nav-item__icon--inbug" lang="en"><li-icon aria-hidden="true" color="brand" size="34dp" type="linkedin-bug"><svg preserveaspectratio="xMinYMin meet" xmlns="http://www.w3.org/2000/svg"><g class="scaling-icon" style="fill-opacity: 1"><defs><lineargradient id="premium-linkedin-bug-color-gradient" x1="100%" x2="0%" y1="0%" y2="100%"><stop class="stop1" offset="0%" stop-color="#C5B583"></stop><stop class="stop2" offset="50%" stop-color="#AF9B62"></stop></lineargradient></defs><g class="bug-14dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25" fill="#FFFFFF"></path><path class="background" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25 Z M5,5 L6.85,5 L6.85,6.016 L6.893,6.016 C7.259,5.541 8.018,4.938 9.25,4.938 C11.125,4.938 12,5.808 12,8 L12,12 L10,12 L10,8.75 C10,7.313 9.672,6.875 8.632,6.875 C7.5,6.875 7,7.75 7,9 L7,12 L5,12 L5,5 Z M2,12 L4,12 L4,5 L2,5 L2,12 Z M4.335,3 C4.335,3.737 3.737,4.335 3,4.335 C2.263,4.335 1.665,3.737 1.665,3 C1.665,2.263 2.263,1.665 3,1.665 C3.737,1.665 4.335,2.263 4.335,3 Z" fill="#0073B2"></path></g><g class="dpi-gt1" transform="scale(0.2917)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-21dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0" fill="#FFFFFF"></path><path class="background" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0 Z M8,8 L10.827,8 L10.827,9.441 L10.858,9.441 C11.289,8.664 12.562,7.875 14.136,7.875 C17.157,7.875 18,9.479 18,12.45 L18,18 L15,18 L15,12.997 C15,11.667 14.469,10.5 13.227,10.5 C11.719,10.5 11,11.521 11,13.197 L11,18 L8,18 L8,8 Z M3,18 L6,18 L6,8 L3,8 L3,18 Z M6.375,4.5 C6.375,5.536 5.536,6.375 4.5,6.375 C3.464,6.375 2.625,5.536 2.625,4.5 C2.625,3.464 3.464,2.625 4.5,2.625 C5.536,2.625 6.375,3.464 6.375,4.5 Z" fill="#0077B5"></path></g><g class="dpi-gt1" transform="scale(0.4375)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 1 ...
# /feed/    <a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="nav.homepage-zh_CN" data-link-to="feed" href="/feed/"><span aria-role="" class="nav-item__china-logo"><span class="visually-hidden">LinkedIn领英</span></span></a>
# /feed/    <a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/"><span aria-role="presentation" class="nav-item__icon" id="feed-tab-icon" lang="en"><li-icon aria-hidden="true" color="true" type="nav-small-home-icon"><svg class="nav-icon" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><g class="active-item" style="fill-opacity: 1"><path d="M22,8.45L12.85,2.26a1.5,1.5,0,0,0-1.69,0L2,8.45,3.06,10,4,9.37V19a1,1,0,0,0,1,1h5V15h4v5h5a1,1,0,0,0,1-1V9.37L20.94,10Z"></path></g><g class="inactive-item" style="fill: currentColor"><path d="M22,9.45L12.85,3.26a1.5,1.5,0,0,0-1.69,0L2,9.45,3.06,11,4,10.37V20a1,1,0,0,0,1,1h6V16h2v5h6a1,1,0,0,0,1-1V10.37L20.94,11ZM18,19H15V15a1,1,0,0,0-1-1H10a1,1,0,0,0-1,1v4H6V8.89l6-4,6,4V19Z"></path></g></svg></li-icon></span> <span class="nav-item__title">Home</span></a>
# /mynetwork/    <a class="nav-item__link js-nav-item-link" data-alias="relationships" data-control-name="" data-link-to="mynetwork" data-resource="voyagerCommunicationsTabBadges" href="/mynetwork/"><span aria-role="presentation" class="nav-item__icon" id="mynetwork-tab-icon" lang="en"><li-icon aria-hidden="true" color="true" type="nav-small-people-icon"><svg class="nav-icon" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><g class="active-item" style="fill-opacity: 1"><path d="M16,17.85V20a1,1,0,0,1-1,1H1a1,1,0,0,1-1-1V17.85a4,4,0,0,1,2.55-3.73l2.95-1.2V11.71l-0.73-1.3A6,6,0,0,1,4,7.47V6a4,4,0,0,1,4.39-4A4.12,4.12,0,0,1,12,6.21V7.47a6,6,0,0,1-.77,2.94l-0.73,1.3v1.21l2.95,1.2A4,4,0,0,1,16,17.85Zm4.75-3.65L19,13.53v-1a6,6,0,0,0,1-3.31V9a3,3,0,0,0-6,0V9.18a6,6,0,0,0,.61,2.58A3.61,3.61,0,0,0,16,13a3.62,3.62,0,0,1,2,3.24V21h4a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.75,14.2Z"></path></g><g class="inactive-item" style="fill: currentColor"><path d="M20.74,14.2L19,13.54V12.86l0.25-.41A5,5,0,0,0,20,9.82V9a3,3,0,0,0-6,0V9.82a5,5,0,0,0,.75,2.63L15,12.86v0.68l-1,.37a4,4,0,0,0-.58-0.28l-2.45-1V10.83A8,8,0,0,0,12,7V6A4,4,0,0,0,4,6V7a8,8,0,0,0,1,3.86v1.84l-2.45,1A4,4,0,0,0,0,17.35V20a1,1,0,0,0,1,1H22a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.74,14.2ZM16,8.75a1,1,0,0,1,2,0v1.44a3,3,0,0,1-.38,1.46l-0.33.6a0.25,0.25,0,0,1-.22.13H16.93a0.25,0.25,0,0,1-.22-0.13l-0.33-.6A3,3,0,0,1,16,10.19V8.75ZM6,5.85a2,2,0,0,1,4,0V7.28a6,6,0,0,1-.71,2.83L9,10.72a1,1,0,0,1-.88.53H7.92A1,1,0,0,1,7,10.72l-0.33-.61A6,6,0,0,1,6,7.28V5.85ZM14,19H2V17.25a2,2,0,0,1,1.26-1.86L7,13.92v-1a3,3,0,0,0,1,.18H8a3,3,0,0,0,1-.18v1l3.72,1.42A2,2,0,0,1,14,17.21V19Zm7,0H16V17.35a4,4,0,0,0-.55-2l1.05-.4V14.07a2,2,0,0,0,.4.05h0.2a2,2,0,0,0,.4-0.05v0.88l2.53,1a1.5,1.5,0,0,1,1,1.4V19Z"></path></g></svg></li-icon></span> <span class="nav-item__title">My Network</span></a>
# /jobs/    <a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="jobs" data-resource="" href="/jobs/"><span aria-role="presentation" class="nav-item__icon" id="jobs-tab-icon" lang="en"><li-icon aria-hidden="true" color="true" type="nav-small-jobs-icon"><svg class="nav-icon" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><g class="active-item" style="fill-opacity: 1"><path d="M2,13H22v6a1,1,0,0,1-1,1H3a1,1,0,0,1-1-1V13ZM22,8v4H2V8A1,1,0,0,1,3,7H7V6a3,3,0,0,1,3-3h4a3,3,0,0,1,3,3V7h4A1,1,0,0,1,22,8ZM15,6a1,1,0,0,0-1-1H10A1,1,0,0,0,9,6V7h6V6Z"></path></g><g class="inactive-item" style="fill: currentColor"><path d="M21,7H17V6a3,3,0,0,0-3-3H10A3,3,0,0,0,7,6V7H3A1,1,0,0,0,2,8V19a1,1,0,0,0,1,1H21a1,1,0,0,0,1-1V8A1,1,0,0,0,21,7ZM9,6a1,1,0,0,1,1-1h4a1,1,0,0,1,1,1V7H9V6ZM20,18H4V13H20v5Zm0-6H4V9H20v3Z"></path></g></svg></li-icon></span> <span class="nav-item__title">Jobs</span></a>
# /messaging/    <a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="messaging" data-resource="voyagerCommunicationsTabBadges" href="/messaging/"><span aria-role="presentation" class="nav-item__icon" id="messaging-tab-icon" lang="en"><li-icon aria-hidden="true" color="true" type="nav-small-messaging-icon"><svg class="nav-icon" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><g class="active-item" style="fill-opacity: 1"><path d="M21,9H8a1,1,0,0,0-1,1V20a1,1,0,0,0,1,1H18l4,3V10A1,1,0,0,0,21,9Zm-4,8H12V16h5v1Zm1-3H11V13h7v1ZM17,5V7H6A1,1,0,0,0,5,8v8H3a1,1,0,0,1-1-1V5A1,1,0,0,1,3,4H16A1,1,0,0,1,17,5Z"></path></g><g class="inactive-item" style="fill: currentColor"><path d="M21,8H8A1,1,0,0,0,7,9V19a1,1,0,0,0,1,1H18l4,3V9A1,1,0,0,0,21,8ZM20,19.11L18.52,18H9V10H20v9.11ZM12,15h5v1H12V15ZM4,13H5v2H3a1,1,0,0,1-1-1V4A1,1,0,0,1,3,3H16a1,1,0,0,1,1,1V6H15V5H4v8Zm14,0H11V12h7v1Z"></path></g></svg></li-icon></span> <span class="nav-item__title">Messaging</span></a>
# /notifications/    <a class="nav-item__link js-nav-item-link" data-alias="identity" data-control-name="" data-link-to="notifications" data-resource="voyagerCommunicationsTabBadges" href="/notifications/"><span aria-role="presentation" class="nav-item__icon" id="notifications-tab-icon" lang="en"><li-icon aria-hidden="true" color="true" type="nav-small-notifications-icon"><svg class="nav-icon" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><g class="active-item" style="fill-opacity: 1"><path d="M18.94,14H5.06L5.79,8.44A6.26,6.26,0,0,1,12,3h0a6.26,6.26,0,0,1,6.21,5.44Zm2,5-1.71-4H4.78L3.06,19a0.71,0.71,0,0,0-.06.28,0.75,0.75,0,0,0,.75.76H10a2,2,0,1,0,4,0h6.27A0.74,0.74,0,0,0,20.94,19Z"></path></g><g class="inactive-item" style="fill: currentColor"><path d="M20.94,19L19,14.49s-0.41-3.06-.8-6.06A6.26,6.26,0,0,0,12,3h0A6.26,6.26,0,0,0,5.79,8.44L5,14.49,3.06,19a0.71,0.71,0,0,0-.06.28,0.75,0.75,0,0,0,.75.76H10a2,2,0,1,0,4,0h6.27A0.74,0.74,0,0,0,20.94,19ZM12,4.75h0a4.39,4.39,0,0,1,4.35,3.81c0.28,2.1.56,4.35,0.7,5.44H7L7.65,8.56A4.39,4.39,0,0,1,12,4.75ZM5.52,18l1.3-3H17.18l1.3,3h-13Z"></path></g></svg></li-icon></span> <span class="nav-item__title">Notifications</span></a>
# #    <a class="nav-placeholder" href="#"><span class="nav-item__title">Try Premium for free</span></a>

# %%
url1 = 'https://www.linkedin.com/school/10458916/alumni/'
r1 = requests.get(url1)
r1.content
soup1 = BeautifulSoup(r1.content, "html5lib")
print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script type="application/javascript">
#    !function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    LinkedIn
#   </title>
#   <meta content="" name="description"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
#   <meta content="#0077B5" name="theme-color"/>
#   <meta content="false" name="is-http2"/>
#   <meta content="%7B%22modulePrefix%22%3A%22extended%22%2C%22environment%22%3A%22production%22%2C%22lix%22%3A%7B%22tests%22%3A%5B%22lego_free_profile_review_promo_banner_widget%22%2C%22lego_jobs%3Ajobs-home_onboarding_flow_oc_promo_in_header_widget%22%2C%22lego_jobs_open_candidates_banner_widget%22%2C%22neptune.jobs.enableInitiateReferrals%22%2C%22voyager.jobs.web.apply-button-copy%22%2C%22voyager.jobs.web.byv-by-param%22%2C%22voyager.jobs.web.careers-dashboard-pill-count%22%2C%22voyager.jobs.web.enabledActionableSkillPills%22%2C%22voyager.jobs.web.enableGaPixelCall%22%2C%22voyager.jobs.web.extended.open-candidate-enable%22%2C%22voyager.jobs.web.extended.open-candidate-title-version%22%2C%22voyager.jobs.web.fasttrack-emphasis%22%2C%22voyager.jobs.web.job-basic-quality-match%22%2C%22voyager.jobs.web.job-basic-quality-match-apply%22%2C%22voyager.jobs.web.jobs-details-salary%22%2C%22voyager.jobs.web.jobs-home-referrals%22%2C%22voyager.jobs.web.jobs-home-search-starters%22%2C%22voyager.jobs.web.jobs-home-track%22%2C%22voyager.jobs.web.jobs-viewport-tracking%22%2C%22voyager.jobs.web.jymbii-browsemap%22%2C%22voyager.jobs.web.post-apply-job-details-browsemap%22%2C%22voyager.jobs.web.post-apply-job-home-redirect%22%2C%22voyager.jobs.web.post-apply-oc-modal%22%2C%22voyager.jobs.web.premium-salary-histogram%22%2C%22voyager.jobs.web.premium-show-premium-flavors-jserp%22%2C%22voyager.jobs.web.premium-top-applicant-jobs-carousel%22%2C%22voyager.jobs.web.profinder-job-details-promo%22%2C%22voyager.jobs.web.profinder-jobs-home-promo%22%2C%22voyager.jobs.web.pymk-for-jobs%22%2C%22voyager.jobs.web.referrals-emphasis%22%2C%22voyager.jobs.web.video-description%22%2C%22voyager.jobs.web.work-authorization%22%2C%22neptune.jobs.enableInitiateReferrals%22%2C%22neptune.jobs.enableSalaryLink%22%2C%22voyager.jobs-search.web.jobs-save-jobs%22%2C%22voyager.jobs.web.enableP4pHovercard%22%2C%22voyager.jobs.web.enableP4pUpsell%22%2C%22voyager.jobs.web.extended.career-interests-jobs-link%22%2C%22voyager.jobs.web.extended.goto-sms%22%2C%22voyager.jobs.web.extended.jobs-home-post-job-btn%22%2C%22voyager.jobs.web.extended.open-candidate-enable%22%2C%22voyager.jobs.web.extended.open-candidate-title-version%22%2C%22voyager.jobs.web.extended.willing-to-share-phone-number-default-value%22%2C%22voyager.jobs.web.jobs-details-salary%22%2C%22voyager.jobs.web.premium-course-recommendations-jobs-details%22%2C%22voyager.jobs.web.premium-free-profile-review-upsell%22%2C%22voyager.jobs.web.premium-learning-recommendation-carousel-jobs-home-headline%22%2C%22voyager.jobs.web.premium-learning-recommended-courses%22%2C%22voyager.jobs.web.premium-top-applicant-jobs-carousel%22%2C%22voyager.jobs.web.premium-career-interests-upsell%22%2C%22voyager.jobs-search.web.enable-redux-extension%22%2C%22voyager.jobs-search.web.jobs-save-jobs%22%2C%22voyager.jobs-search.web.jymbii-on-no-results-page%22%2C%22voyager.jobs-search.web.sticky-facets%22%2C%22voyager.jobs-search.web.promoted-jobs-tag%22%2C%22voyager.jobs-search.web.two-pane%22%2C%22voyager.notifications.web.project-virality-landing%22%2C%22voyager.notifications.web.show-all-notifications-on-settings%22%2C%22voyager.notifications.web.promo-li-chrome-ext%22%2C%22voyager.notifications.web.project-virality-landing%22%2C%22org.media.library%22%2C%22voyager.organization.web.admin-staffing-upgrades%22%2C%22voyager.organization.web.enable-video-action-1%22%2C%22voyager.organization.web.enable-video-action-2%22%2C%22voyager.organization.web.enable-video-action-3%22%2C%22voyager.organization.web.enable-video-action-4%22%2C%22voyager.organization.web.enable-video-action-5%22%2C%22voyager.organization.web.enable-targeted-details%22%2C%22neptune.search.lazy-filters%22%2C%22voyager.feed.client.storyline-share%22%2C%22voyager.feed.client.storyline-social-actions%22%2C%22voyager.feed.client.storyline-social-proof%22%2C%22voyager.feed.web.fetch-storyline-social-detail%22%2C%22voyager.feed.web.max-storyline-comments%22%2C%22voyager.search.web.add-con ...
#   <link href="https://static.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca" id="favicon-ico" rel="shortcut icon"/>
#   <link href="https://static.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon"/>
#   <link href="https://static.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed"/>
#   <link href="https://static.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#   <link href="https://static.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="https://static.licdn.com/sc/h/47p3k9ppk9w480n2cncuxuhyu" rel="stylesheet"/>
#   <link href="https://static.licdn.com/sc/h/toa5abjdmje2rcyhc5o2hfuw" rel="stylesheet"/>
#   <meta content='{"assets/highcharts/highcharts.js":"https://static.licdn.com/sc/h/8zadmsmgvnlot1j2bqm5n92wg","assets/highcharts/modules/map.js":"https://static.licdn.com/sc/h/8cc366qna9cu11xe7nsclmsa2","assets/proj4.js":"https://static.licdn.com/sc/h/d6jai8ed2od8qvczyatulwpui","assets/world.js":"https://static.licdn.com/sc/h/bnwmdc0to1gdikjm7fpmmoqoo","assets/src/chartbeat.js":"https://static.licdn.com/sc/h/75rnhwv4xo1j504pwos0wpyim","assets/favicon.ico":"https://static.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca","assets/favicon-notification.ico":"https://static.licdn.com/sc/h/1bt1uwq5akv756knzdj4l6cdc"}' name="spark/hash-includes"/>
#   <meta content="en_US" name="i18nDefaultLocale"/>
#   <meta content="en_US" name="i18nLocale"/>
#   <meta content="https://static.licdn.com/sc/h/dhlvagkf5eqyu33gsddlhc3f8" name="i18nIntlPolyfillUrl"/>
#   <meta content="us" name="requestIpCountryCode"/>
#   <meta content="urn:li:page:bpr;y7LGG5luRdizVRKIP9Btrw==" name="bprPageInstance"/>
#   <meta content='{"applicationUrn": "urn:li:application:(voyager-web,voyager-web)", "version": "1.0.14552", "trackingId": [60, -5, 56, -16, 97, -70, 70, 16, -73, -58, 14, 28, 120, 17, 97, -106]}' name="applicationInstance"/>
#   <meta content="r5Gg4/+6QsKFoJ9RVidnyw==" name="clientPageInstanceId"/>
#   <meta content="none" name="liamOrLisa"/>
#   <meta content="voyager-web" name="service"/>
#   <meta content="i001" name="serviceInstance"/>
#   <meta content="1.0.14552" name="serviceVersion"/>
#   <meta content='{"lix":{"voyager.web.mynetwork.abi.paginated.results":{"treatment":"control","testKey":"voyager.web.mynetwork.abi.paginated.results","trackingInfo":null},"voyager.messaging.client.truncate-legal-text":{"treatment":"treatment","testKey":"voyager.messaging.client.truncate-legal-text","trackingInfo":null},"voyager.search.web.right-rail-news-module":{"treatment":"control","testKey":"voyager.search.web.right-rail-news-module","trackingInfo":{"experimentId":1703888,"treatmentIndex":0,"segmentIndex":4}},"neptune.jobs.enableInitiateReferrals":{"treatment":"control","testKey":"neptune.jobs.enableInitiateReferrals","trackingInfo":null},"voyager.me.client.notification-show-presence":{"treatment":"enabled","testKey":"voyager.me.client.notification-show-presence","trackingInfo":{"experimentId":1700663,"treatmentIndex":1,"segmentIndex":1}},"voyager.profile.web.extended.wechat":{"treatment":"enabled","testKey":"voyager.profile.web.extended.wechat","trackingInfo":null},"voyager.messaging.web.extended.linkedin-assistant-search-entry-point":{"treatment":"control","testKey":"voyager.messaging.web.extended.linkedin-assistant-search-entry-point","trackingInfo":null},"voyager.l2m.client.realtime-badging":{"treatment":"control","testKey":"voyager.l2m.client.realtime-badging","trackingInfo":{"experimentId":1702640,"treatmentIndex":0,"segmentIndex":3}},"voyager.infra.web.nav.extended.loading-bar":{"treatment":"remove","testKey":"voyager.infra.web.nav.extended.loading-bar","trackingInfo":null},"voyager.entities.client.presence-on-company":{"treatment":"enabled","testKey":"voyager.entities.client.presence-on-company","trackingInfo":{"experimentId":1700677,"treatmentIndex":1,"segmentIndex":1}},"voyager.launchpad.web.extended.show-pending-invite":{"treatment":"enabled","testKey":"voyager.launchpad.web.extended.show-pending-invite","trackingInfo":{"experimentId":1701964,"treatmentIndex":1,"segmentIndex":1}},"voyager.messaging.web.enable-archive":{"treatment":"control","testKey":"voyager.messaging.web.enable-archive","trackingInfo":{"experimentId":1692156,"treatmentIndex":0,"segmentIndex":1}},"voyager.search.web.search-ads-integrated-ui":{"treatment":"control","testKey":"voyager.search.web.search-ads-integrated-ui","trackingInfo":{"experimentId":1706108,"treatmentIndex":0,"segmentIndex":1}},"voyager.video.web.settings-modal":{"treatment":"control","testKey":"voyager.video.web.settings-modal","trackingInfo":null},"voyager.organization.web.enable-organization-ratings":{"treatment":"enabled","testKey":"voyager.organization.web.enable-organization-ratings","trackingInfo":{"experimentId":1702458,"treatmentIndex":1,"segmentIndex":0}},"voyager.jobs.web.enableP4pHovercard":{"treatment":"control","testKey":"voyager.jobs.web.enableP4pHovercard","trackingInfo":null},"voyager.search.web.add-connection-of-facet":{"treatment":"enabled","testKey":"voyager.search.web.add-connection-of-facet","trackingInfo":null},"voyager.feed.web.end-of-feed":{"treatment":"enabled","testKey":"voyager.feed.web.end-of-feed","trackingInfo":null},"voyager.jobs.web.jobs-home-search-starters":{"treatment":"control","testKey":"voyager.jobs.web.jobs-home-search-starters","trackingInfo":null},"voyager.feed.client.updates-request-comments-count":{"treatment":"control","testKey":"voyager.feed.client.updates-request-comments-count","trackingInfo":{"experimentId":1703995,"treatmentIndex":0,"segmentIndex":1}},"voyager.notifications.web.show-all-notifications-on-settings":{"treatment":"control","testKey":"voyager.notifications.web.show-all-notifications-on-settings","trackingInfo":{"experimentId":1700667,"treatmentIndex":0,"segmentIndex":1}},"voyager.mynetwork.web.connection-suggester-receiver":{"treatment":"cs_mynetwork","testKey":"voyager.mynetwork.web.connection-suggester-receiver","trackingInfo":{"experimentId":1696989,"treatmentIndex":1,"segmentIndex":1}},"voyager.jobs-search.web.jymbii-on-no-results-page":{"treatment":"control","testKey":"voyager.jobs-search.web.jymbii-on-no-result ...
#   <meta content="true" name="isGuest"/>
#   <meta data-mode="BIGPIPE" name="renderingMode"/>
#   <meta content="5000" name="bigpipeResponseTimeout"/>
#   <meta content="false" name="bigpipeJetRethrowError"/>
#   <meta content='["static\\.licdn\\.com","media\\.licdn\\.com","voyager/api/typeahead/hits"]' name="bigpipeBlacklistUrls"/>
#   <script src="https://static.licdn.com/sc/h/39r4tyh7m0cf036lc1dkcp78n">
#   </script>
#   <meta content="1f9y3ZUE7RQAd/HnIisAAA==" name="treeID"/>
#   <!--HEAD_SSR-->
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22article-reader-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="article-reader-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22company-creation-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="company-creation-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/lib/s-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22feed-ext%22%2C%22persistentCache%22%3Afalse%2C%22discover%22%3Atrue%7D%7D" name="feed-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%7D%7D" name="feed-shared-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%7D%7D" name="feed-base-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%2C%22assets%22%3A%7B%22sources%22%3A%5B%7B%22directory%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/public/assets%22%2C%22globOpts%22%3A%7B%22ignore%22%3A%5B%22**/*.js%22%2C%22**/*.s%5Bac%5Dss%22%5D%7D%7D%5D%7D%7D%2C%22annotation%22%3A%22jobs-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="jobs-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22jobs-search-ext%22%2C%22persistentCache%22%3Afalse%2C%22discover%22%3Atrue%7D%2C%22googleAnalytics%22%3A%7B%22trackingId%22%3A%22UA-62256447-1%22%7D%7D" name="jobs-search-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/lib/s-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22lead-capture-ext%22%2C%22persistentCache%22%3Afalse%2C%22discover%22%3Atrue%7D%7D" name="lead-capture-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22me-ca-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="me-ca-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22me-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="me-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22messaging-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="messaging-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%7D%7D" name="messaging-overlay/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22mynetwork-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="mynetwork-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22notifications-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="notifications-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-opportunities%22%7D%5D%7D%2C%22annotation%22%3A%22opportunities-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="opportunities-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/lib/s-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22organization-ext%22%2C%22persistentCache%22%3Afalse%2C%22discover%22%3Atrue%7D%7D" name="organization-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22organization-admin%22%2C%22persistentCache%22%3Afalse%2C%22discover%22%3Atrue%7D%7D" name="organization-admin-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22onboarding-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="onboarding-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%2C%22assets%22%3A%7B%22sources%22%3A%5B%7B%22directory%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/public/assets%22%2C%22globOpts%22%3A%7B%22ignore%22%3A%5B%22**/*.js%22%2C%22**/*.s%5Bac%5Dss%22%5D%7D%7D%5D%7D%7D%2C%22annotation%22%3A%22premium-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="premium-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22profile-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="profile-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22profile-edit-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="profile-edit-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22profile-ge-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="profile-ge-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22profile-search-analytics-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="profile-search-analytics-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22profile-subroutes-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="profile-subroutes-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/lib/s-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22school-ext%22%2C%22persistentCache%22%3Afalse%2C%22discover%22%3Atrue%7D%7D" name="school-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22search-ext%22%2C%22persistentCache%22%3Afalse%7D%7D" name="search-ext/config/environment"/>
#   <meta content="%7B%22eyeglass%22%3A%7B%22eyeglass%22%3A%7B%22modules%22%3A%5B%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/lib/s-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/extended/lib/shared-ext/se-base%22%7D%2C%7B%22path%22%3A%22/export/home/tester/orca/MP_TRUNKDEV_POSTCOMMIT/workspace/voyager-web_227a89a692a7866d440d91a46035cfa0650d7522/global/theme%22%7D%5D%7D%2C%22annotation%22%3A%22showcase-ext%22%2C%22persistentCache%22%3Afalse%2C%22discover%22%3Atrue%7D%7D" name="showcase-ext/config/environment"/>
#   <meta content="https://static.licdn.com/sc/h/7a3bzhbixt0rvgxdw791guhfq" id="artdeco/static/fonts/fonts64.css" name="asset-url"/>
#   <meta content="https://static.licdn.com/sc/h/643vcber5lnojo342ijyt5h4m" id="artdeco/static/fonts/ar64.css" name="asset-url"/>
#   <meta content="https://static.licdn.com/sc/h/alk87jkqg2z0xdiclg3zcnip4" id="artdeco/static/fonts/ru64.0.css" name="asset-url"/>
#   <meta content="https://static.licdn.com/sc/h/8mmq68vtbg474jhg3yeeh9mne" id="artdeco/static/fonts/ru64.1.css" name="asset-url"/>
#   <meta content="https://static.licdn.com/sc/h/w9ee6bewhnulizrnfstoz5e6" id="artdeco/static/fonts/th64.css" name="asset-url"/>
#   <meta content="https://static.licdn.com/sc/h/bxpdsvv8941zef0i0l2c40ok2" id="artdeco/static/images/icons.svg" name="asset-url"/>
#   <meta content='{"bundles":{"article-reader-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/e9ol4yqtrdto9e7ho02agkfmj"},{"type":"js","uri":"https://static.licdn.com/sc/h/5ys5fy3vlxcomtn7belhfeg2r"},{"type":"css","uri":"https://static.licdn.com/sc/h/d9juurn3lybxp3bbnmpiza7e8"}],"dependencies":null},"company-creation-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/2l9xmen80vaia3l1pz2xzqk9k"},{"type":"js","uri":"https://static.licdn.com/sc/h/ar9dufr248rjwpdrhwhq93jrv"},{"type":"css","uri":"https://static.licdn.com/sc/h/cyt7midf0vwd4oi5xnfx4gnp9"}],"dependencies":null},"feed-base-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/9nvxm3morkzede6z4yj2liyth"},{"type":"js","uri":"https://static.licdn.com/sc/h/8kd4d1upx3cbpdiu2cst6wx7a"}],"dependencies":null},"feed-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/6vgr8gj5c9855uonhx57wh8mk"},{"type":"js","uri":"https://static.licdn.com/sc/h/bx2jm9cxm0hetvy6ftai8vog8"}],"dependencies":null},"feed-shared-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/aclhnwtgnldz3ymd8pbcasvjj"},{"type":"js","uri":"https://static.licdn.com/sc/h/282noy6lgfe37bsh78ao5drg3"}],"dependencies":null},"jobs-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/8xxfc8zod395oohtr8errj81u"},{"type":"js","uri":"https://static.licdn.com/sc/h/79od7v1fcasvvxqa3sz1krple"},{"type":"css","uri":"https://static.licdn.com/sc/h/d9w9khs076drfmnhaxlif3nt"}],"dependencies":null},"jobs-search-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/4uvmi4esi7s6nucehc4vp4qg0"},{"type":"js","uri":"https://static.licdn.com/sc/h/f86r0nez9q516gq8cm85wp7x"},{"type":"css","uri":"https://static.licdn.com/sc/h/4h4yb1liqmhq95javyisoorqy"}],"dependencies":null},"lead-capture-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/5e8wcla9ury5mv8qz98vd6722"},{"type":"js","uri":"https://static.licdn.com/sc/h/497q096mcg9ysomy8qj5cus9b"},{"type":"css","uri":"https://static.licdn.com/sc/h/br6qifa9efgx9f2rxxzzgedwq"}],"dependencies":null},"me-ca-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/7dgdng8kzpts4u9ke7uwdi53y"},{"type":"js","uri":"https://static.licdn.com/sc/h/d881dk58j4hjgq14o5v85rqjq"}],"dependencies":null},"me-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/f2f6zy432ldlpeyxi95k2q3mr"},{"type":"js","uri":"https://static.licdn.com/sc/h/dx0pzlzhouoykh0havcmau1en"},{"type":"css","uri":"https://static.licdn.com/sc/h/b7u82qdoe53ctxjbothxloa3y"}],"dependencies":null},"messaging-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/1chewdrdr6d7yohklvu0lvxeb"},{"type":"js","uri":"https://static.licdn.com/sc/h/2fxax9o9ksaiv4dhfcxgnf420"},{"type":"css","uri":"https://static.licdn.com/sc/h/eroewypos8snds09ngkd6ym69"}],"dependencies":null},"messaging-overlay":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/c38yjq2iok4h7xuk3xkswm7pu"},{"type":"js","uri":"https://static.licdn.com/sc/h/etxe4ygd9f1eytyr8deiwm0qo"}],"dependencies":null},"mynetwork-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/1lh26qe7q1d2lxlmhgsxmk3d1"},{"type":"js","uri":"https://static.licdn.com/sc/h/edae7j2dycbxad0y69mn8d6ov"},{"type":"css","uri":"https://static.licdn.com/sc/h/ah7uieyury2h4jfa7ouzvwbdy"}],"dependencies":null},"notifications-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/d6exck3vcu77b5sar9f1kfdd1"},{"type":"js","uri":"https://static.licdn.com/sc/h/arv0ryxe8vuttmahtllva1b4e"},{"type":"css","uri":"https://static.licdn.com/sc/h/2sw8j3kutn92pb8y1ei1wx4x"}],"dependencies":null},"onboarding-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/cd1yz84nhbm4kdpjlotuo4mvm"},{"type":"js","uri":"https://static.licdn.com/sc/h/25zmcnj1fq1mu4kyziowmxpa7"},{"type":"css","uri":"https://static.licdn.com/sc/h/a7m4ivc4tqlaemzd8lwt5zs3k"}],"dependencies":null},"opportunities-ext":{"assets":[{"type":"js","uri":"https://static.licdn.com/sc/h/b5cnjv0o2igm0ttstkfi0 ...
#   <link href="https://static.licdn.com/sc/h/c8ffzl03l9yvgp2ksam6r4jpa" rel="stylesheet"/>
#   <link href="https://static.licdn.com/sc/h/52kp7xu1mcy18ghwou1qxdudk" rel="stylesheet"/>
#   <style>
#   </style>
#   <meta content="app-id=288429040, affiliate-data=ct=campaign_vw_smart_app_banner&amp;pt=10746, app-argument=voyager://school/10458916/alumni/?trk=vw_smart_app_banner" name="apple-itunes-app"/>
#   <meta content="noindex" name="robots"/>
#  </head>
#  <body class="render-mode-BIGPIPE nav-v2 " dir="ltr">
#   <div id="artdeco-modal-outlet">
#   </div>
#   <div id="a11y-menu">
#   </div>
#   <nav class="extended-nav nav-main-container global-alert-offset-top" id="extended-nav" role="banner" tabindex="-1">
#    <div class="nav-main__content display-flex">
#     <div class="nav-main__inbug-container fl mr3">
#      <div class="nav-item--inbug" id="inbug-nav-item" lang="en">
#       <a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/">
#        <span aria-role="presentation" class="nav-item__icon nav-item__icon--inbug" lang="en">
#         <li-icon aria-hidden="true" color="brand" size="34dp" type="linkedin-bug">
#          <svg preserveAspectRatio="xMinYMin meet" xmlns="http://www.w3.org/2000/svg">
#           <g class="scaling-icon" style="fill-opacity: 1">
#            <defs>
#             <linearGradient id="premium-linkedin-bug-color-gradient" x1="100%" x2="0%" y1="0%" y2="100%">
#              <stop class="stop1" offset="0%" stop-color="#C5B583">
#              </stop>
#              <stop class="stop2" offset="50%" stop-color="#AF9B62">
#              </stop>
#             </linearGradient>
#            </defs>
#            <g class="bug-14dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#             <g class="dp-1">
#              <path class="bug-text-color" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25" fill="#FFFFFF">
#              </path>
#              <path class="background" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25 Z M5,5 L6.85,5 L6.85,6.016 L6.893,6.016 C7.259,5.541 8.018,4.938 9.25,4.938 C11.125,4.938 12,5.808 12,8 L12,12 L10,12 L10,8.75 C10,7.313 9.672,6.875 8.632,6.875 C7.5,6.875 7,7.75 7,9 L7,12 L5,12 L5,5 Z M2,12 L4,12 L4,5 L2,5 L2,12 Z M4.335,3 C4.335,3.737 3.737,4.335 3,4.335 C2.263,4.335 1.665,3.737 1.665,3 C1.665,2.263 2.263,1.665 3,1.665 C3.737,1.665 4.335,2.263 4.335,3 Z" fill="#0073B2">
#              </path>
#             </g>
#             <g class="dpi-gt1" transform="scale(0.2917)">
#              <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#              </rect>
#              <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#              </path>
#             </g>
#            </g>
#            <g class="bug-21dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#             <g class="dp-1">
#              <path class="bug-text-color" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0" fill="#FFFFFF">
#              </path>
#              <path class="background" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0 Z M8,8 L10.827,8 L10.827,9.441 L10.858,9.441 C11.289,8.664 12.562,7.875 14.136,7.875 C17.157,7.875 18,9.479 18,12.45 L18,18 L15,18 L15,12.997 C15,11.667 14.469,10.5 13.227,10.5 C11.719,10.5 11,11.521 11,13.197 L11,18 L8,18 L8,8 Z M3,18 L6,18 L6,8 L3,8 L3,18 Z M6.375,4.5 C6.375,5.536 5.536,6.375 4.5,6.375 C3.464,6.375 2.625,5.536 2.625,4.5 C2.625,3.464 3.464,2.625 4.5,2.625 C5.536,2.625 6.375,3.464 6.375,4.5 Z" fill="#0077B5">
#              </path>
#             </g>
#             <g class="dpi-gt1" transform="scale(0.4375)">
#              <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#              </rect>
#              <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#              </path>
#             </g>
#            </g>
#            <g class="bug-28dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#             <g class="dp-1">
#              <path class="bug-text-color" d="M25.375,0 L2.625,0 C1.175,0 0,1.175 0,2.625 L0,25.375 C0,26.825 1.175,28 2.625,28 L25.375,28 C26.825,28 28,26.825 28,25.375 L28,2.625 C28,1.175 26.825,0 25.375,0" fill="#FFFFFF">
#              </path>
#              <path class="background" d="M25.375,0 L2.625,0 C1.175,0 0,1.175 0,2.625 L0,25.375 C0,26.825 1.175,28 2.625,28 L25.375,28 C26.825,28 28,26.825 28,25.375 L28,2.625 C28,1.175 26.825,0 25.375,0 Z M14.8747,12.025 L14.8747,10 L10.9997,10 L10.9997,24 L14.9997,24 L14.9997,17.375 C14.9997,15.603 15.6627,13.875 17.6497,13.875 C19.4667,13.875 19.9997,14.965 19.9997,16.875 L19.9997,24 L23.9997,24 L23.9997,14.975 C23.9997,11.75 22.2917,9.875 19.0137,9.875 C16.9227,9.875 15.4487,11.025 14.8747,12.025 Z M4,24 L8,24 L8,10 L4,10 L4,24 Z M6,3.665 C4.71,3.665 3.665,4.71 3.665,6 C3.665,7.29 4.71,8.335 6,8.335 C7.29,8.335 8.335,7.29 8.335,6 C8.335,4.71 7.29,3.665 6,3.665 Z" fill="#0077B5">
#              </path>
#             </g>
#             <g class="dpi-gt1" transform="scale(0.5833)">
#              <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#              </rect>
#              <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#              </path>
#             </g>
#            </g>
#            <g class="bug-34dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#             <g class="dp-1">
#              <path class="bug-text-color" d="M2.8,34 L31.2,34 C32.746,34 34,32.746 34,31.2 L34,2.8 C34,1.254 32.746,0 31.2,0 L2.8,0 C1.254,0 0,1.254 0,2.8 L0,31.2 C0,32.746 1.254,34 2.8,34" fill="#FFFFFF">
#              </path>
#              <path class="background" d="M2.8,34 L31.2,34 C32.746,34 34,32.746 34,31.2 L34,2.8 C34,1.254 32.746,0 31.2,0 L2.8,0 C1.254,0 0,1.254 0,2.8 L0,31.2 C0,32.746 1.254,34 2.8,34 Z M13,13 L17.75,13 L17.75,15.391 C18.387,14.114 20.242,12.75 22.695,12.75 C27.397,12.75 29,14.875 29,19.922 L29,29 L24,29 L24,20.984 C24,18.328 23.481,16.875 21.542,16.875 C18.921,16.875 18,18.867 18,20.984 L18,29 L13,29 L13,13 Z M5,29 L10,29 L10,13 L5,13 L5,29 Z M10.55,7.5 C10.55,9.184 9.184,10.55 7.5,10.55 C5.816,10.55 4.45,9.184 4.45,7.5 C4.45,5.815 5.816,4.45 7.5,4.45 C9.184,4.45 10.55,5.815 10.55,7.5 Z" fill="#0077B5">
#              </path>
#             </g>
#             <g class="dpi-gt1" transform="scale(0.7083)">
#              <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#              </rect>
#              <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#              </path>
#             </g>
#            </g>
#            <g class="bug-40dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#             <g class="dp-1">
#              <path class="bug-text-color" d="M40,3.5 L40,36.5 C40,38.434 38.434,40 36.5,40 L3.5,40 C1.566,40 0,38.434 0,36.5 L0,3.5 C0,1.566 1.566,0 3.5,0 L36.5,0 C38.434,0 40,1.566 40,3.5 L40,3.5 Z" fill="#FFFFFF">
#              </path>
#              <path class="background" d="M40,3.5 L40,36.5 C40,38.434 38.434,40 36.5,40 L3.5,40 C1.566,40 0,38.434 0,36.5 L0,3.5 C0,1.566 1.566,0 3.5,0 L36.5,0 C38.434,0 40,1.566 40,3.5 Z M15,15.0000122 L20.875,15.0000122 L20.875,18.3330122 C21.542,17.1460122 23,14.7000122 26.957,14.7000122 C33.137,14.7000122 34,18.6800122 34,23.9670122 L34,34.0000122 L28,34.0000122 L28,25.0180122 C28,22.1830122 27.542,19.8750122 24.922,19.8750122 C21.75,19.8750122 21,21.9560122 21,24.5160122 L21,34.0000122 L15,34.0000122 L15,15.0000122 Z M6,34 L12,34 L12,15 L6,15 L6,34 Z M12.6509756,8.99997559 C12.6509756,11.0159756 11.0169756,12.6499756 9.00097559,12.6499756 C6.98397559,12.6499756 5.34997559,11.0159756 5.34997559,8.99997559 C5.34997559,6.98397559 6.98397559,5.34997559 9.00097559,5.34997559 C11.0169756,5.34997559 12.6509756,6.98397559 12.6509756,8.99997559 Z" fill="#0077B5">
#              </path>
#             </g>
#             <g class="dpi-gt1" transform="scale(0.8333)">
#              <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#              </rect>
#              <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#              </path>
#             </g>
#            </g>
#            <g class="bug-48dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#             <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#             </rect>
#             <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#             </path>
#            </g>
#           </g>
#          </svg>
#         </li-icon>
#        </span>
#        <span class="nav-item__title">
#        </span>
#       </a>
#      </div>
#      <div class="nav-item--inbug nav-item--china-branding hidden" id="china-branding-nav-item" lang="en">
#       <a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="nav.homepage-zh_CN" data-link-to="feed" href="/feed/">
#        <span aria-role="" class="nav-item__china-logo">
#         <span class="visually-hidden">
#          LinkedIn领英
#         </span>
#        </span>
#       </a>
#      </div>
#     </div>
#     <form class="nav-search" id="extended-nav-search">
#      <div class="nav-search-bar">
#       <input class="nav-placeholder" disabled="disabled" id="nav-typeahead-placeholder" type="search"/>
#       <div id="nav-typeahead-wormhole">
#       </div>
#      </div>
#      <div class="nav-search-controls" id="nav-search-controls-wormhole">
#      </div>
#     </form>
#     <ul class="nav-main nav-container" role="navigation">
#      <li class="nav-item nav-item--feed" id="feed-nav-item" lang="en">
#       <a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/">
#        <span aria-role="presentation" class="nav-item__icon" id="feed-tab-icon" lang="en">
#         <li-icon aria-hidden="true" color="true" type="nav-small-home-icon">
#          <svg class="nav-icon" height="24px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#           <g class="active-item" style="fill-opacity: 1">
#            <path d="M22,8.45L12.85,2.26a1.5,1.5,0,0,0-1.69,0L2,8.45,3.06,10,4,9.37V19a1,1,0,0,0,1,1h5V15h4v5h5a1,1,0,0,0,1-1V9.37L20.94,10Z">
#            </path>
#           </g>
#           <g class="inactive-item" style="fill: currentColor">
#            <path d="M22,9.45L12.85,3.26a1.5,1.5,0,0,0-1.69,0L2,9.45,3.06,11,4,10.37V20a1,1,0,0,0,1,1h6V16h2v5h6a1,1,0,0,0,1-1V10.37L20.94,11ZM18,19H15V15a1,1,0,0,0-1-1H10a1,1,0,0,0-1,1v4H6V8.89l6-4,6,4V19Z">
#            </path>
#           </g>
#          </svg>
#         </li-icon>
#        </span>
#        <span class="nav-item__title">
#         Home
#        </span>
#       </a>
#      </li>
#      <li class="nav-item nav-item--mynetwork" id="mynetwork-nav-item" lang="en">
#       <a class="nav-item__link js-nav-item-link" data-alias="relationships" data-control-name="" data-link-to="mynetwork" data-resource="voyagerCommunicationsTabBadges" href="/mynetwork/">
#        <span aria-role="presentation" class="nav-item__icon" id="mynetwork-tab-icon" lang="en">
#         <li-icon aria-hidden="true" color="true" type="nav-small-people-icon">
#          <svg class="nav-icon" height="24px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#           <g class="active-item" style="fill-opacity: 1">
#            <path d="M16,17.85V20a1,1,0,0,1-1,1H1a1,1,0,0,1-1-1V17.85a4,4,0,0,1,2.55-3.73l2.95-1.2V11.71l-0.73-1.3A6,6,0,0,1,4,7.47V6a4,4,0,0,1,4.39-4A4.12,4.12,0,0,1,12,6.21V7.47a6,6,0,0,1-.77,2.94l-0.73,1.3v1.21l2.95,1.2A4,4,0,0,1,16,17.85Zm4.75-3.65L19,13.53v-1a6,6,0,0,0,1-3.31V9a3,3,0,0,0-6,0V9.18a6,6,0,0,0,.61,2.58A3.61,3.61,0,0,0,16,13a3.62,3.62,0,0,1,2,3.24V21h4a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.75,14.2Z">
#            </path>
#           </g>
#           <g class="inactive-item" style="fill: currentColor">
#            <path d="M20.74,14.2L19,13.54V12.86l0.25-.41A5,5,0,0,0,20,9.82V9a3,3,0,0,0-6,0V9.82a5,5,0,0,0,.75,2.63L15,12.86v0.68l-1,.37a4,4,0,0,0-.58-0.28l-2.45-1V10.83A8,8,0,0,0,12,7V6A4,4,0,0,0,4,6V7a8,8,0,0,0,1,3.86v1.84l-2.45,1A4,4,0,0,0,0,17.35V20a1,1,0,0,0,1,1H22a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.74,14.2ZM16,8.75a1,1,0,0,1,2,0v1.44a3,3,0,0,1-.38,1.46l-0.33.6a0.25,0.25,0,0,1-.22.13H16.93a0.25,0.25,0,0,1-.22-0.13l-0.33-.6A3,3,0,0,1,16,10.19V8.75ZM6,5.85a2,2,0,0,1,4,0V7.28a6,6,0,0,1-.71,2.83L9,10.72a1,1,0,0,1-.88.53H7.92A1,1,0,0,1,7,10.72l-0.33-.61A6,6,0,0,1,6,7.28V5.85ZM14,19H2V17.25a2,2,0,0,1,1.26-1.86L7,13.92v-1a3,3,0,0,0,1,.18H8a3,3,0,0,0,1-.18v1l3.72,1.42A2,2,0,0,1,14,17.21V19Zm7,0H16V17.35a4,4,0,0,0-.55-2l1.05-.4V14.07a2,2,0,0,0,.4.05h0.2a2,2,0,0,0,.4-0.05v0.88l2.53,1a1.5,1.5,0,0,1,1,1.4V19Z">
#            </path>
#           </g>
#          </svg>
#         </li-icon>
#        </span>
#        <span class="nav-item__title">
#         My Network
#        </span>
#       </a>
#      </li>
#      <li class="nav-item nav-item--jobs" id="jobs-nav-item" lang="en">
#       <a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="jobs" data-resource="" href="/jobs/">
#        <span aria-role="presentation" class="nav-item__icon" id="jobs-tab-icon" lang="en">
#         <li-icon aria-hidden="true" color="true" type="nav-small-jobs-icon">
#          <svg class="nav-icon" height="24px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#           <g class="active-item" style="fill-opacity: 1">
#            <path d="M2,13H22v6a1,1,0,0,1-1,1H3a1,1,0,0,1-1-1V13ZM22,8v4H2V8A1,1,0,0,1,3,7H7V6a3,3,0,0,1,3-3h4a3,3,0,0,1,3,3V7h4A1,1,0,0,1,22,8ZM15,6a1,1,0,0,0-1-1H10A1,1,0,0,0,9,6V7h6V6Z">
#            </path>
#           </g>
#           <g class="inactive-item" style="fill: currentColor">
#            <path d="M21,7H17V6a3,3,0,0,0-3-3H10A3,3,0,0,0,7,6V7H3A1,1,0,0,0,2,8V19a1,1,0,0,0,1,1H21a1,1,0,0,0,1-1V8A1,1,0,0,0,21,7ZM9,6a1,1,0,0,1,1-1h4a1,1,0,0,1,1,1V7H9V6ZM20,18H4V13H20v5Zm0-6H4V9H20v3Z">
#            </path>
#           </g>
#          </svg>
#         </li-icon>
#        </span>
#        <span class="nav-item__title">
#         Jobs
#        </span>
#       </a>
#      </li>
#      <li class="nav-item nav-item--messaging" id="messaging-nav-item" lang="en">
#       <a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="messaging" data-resource="voyagerCommunicationsTabBadges" href="/messaging/">
#        <span aria-role="presentation" class="nav-item__icon" id="messaging-tab-icon" lang="en">
#         <li-icon aria-hidden="true" color="true" type="nav-small-messaging-icon">
#          <svg class="nav-icon" height="24px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#           <g class="active-item" style="fill-opacity: 1">
#            <path d="M21,9H8a1,1,0,0,0-1,1V20a1,1,0,0,0,1,1H18l4,3V10A1,1,0,0,0,21,9Zm-4,8H12V16h5v1Zm1-3H11V13h7v1ZM17,5V7H6A1,1,0,0,0,5,8v8H3a1,1,0,0,1-1-1V5A1,1,0,0,1,3,4H16A1,1,0,0,1,17,5Z">
#            </path>
#           </g>
#           <g class="inactive-item" style="fill: currentColor">
#            <path d="M21,8H8A1,1,0,0,0,7,9V19a1,1,0,0,0,1,1H18l4,3V9A1,1,0,0,0,21,8ZM20,19.11L18.52,18H9V10H20v9.11ZM12,15h5v1H12V15ZM4,13H5v2H3a1,1,0,0,1-1-1V4A1,1,0,0,1,3,3H16a1,1,0,0,1,1,1V6H15V5H4v8Zm14,0H11V12h7v1Z">
#            </path>
#           </g>
#          </svg>
#         </li-icon>
#        </span>
#        <span class="nav-item__title">
#         Messaging
#        </span>
#       </a>
#      </li>
#      <li class="nav-item nav-item--notifications" id="notifications-nav-item" lang="en">
#       <a class="nav-item__link js-nav-item-link" data-alias="identity" data-control-name="" data-link-to="notifications" data-resource="voyagerCommunicationsTabBadges" href="/notifications/">
#        <span aria-role="presentation" class="nav-item__icon" id="notifications-tab-icon" lang="en">
#         <li-icon aria-hidden="true" color="true" type="nav-small-notifications-icon">
#          <svg class="nav-icon" height="24px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#           <g class="active-item" style="fill-opacity: 1">
#            <path d="M18.94,14H5.06L5.79,8.44A6.26,6.26,0,0,1,12,3h0a6.26,6.26,0,0,1,6.21,5.44Zm2,5-1.71-4H4.78L3.06,19a0.71,0.71,0,0,0-.06.28,0.75,0.75,0,0,0,.75.76H10a2,2,0,1,0,4,0h6.27A0.74,0.74,0,0,0,20.94,19Z">
#            </path>
#           </g>
#           <g class="inactive-item" style="fill: currentColor">
#            <path d="M20.94,19L19,14.49s-0.41-3.06-.8-6.06A6.26,6.26,0,0,0,12,3h0A6.26,6.26,0,0,0,5.79,8.44L5,14.49,3.06,19a0.71,0.71,0,0,0-.06.28,0.75,0.75,0,0,0,.75.76H10a2,2,0,1,0,4,0h6.27A0.74,0.74,0,0,0,20.94,19ZM12,4.75h0a4.39,4.39,0,0,1,4.35,3.81c0.28,2.1.56,4.35,0.7,5.44H7L7.65,8.56A4.39,4.39,0,0,1,12,4.75ZM5.52,18l1.3-3H17.18l1.3,3h-13Z">
#            </path>
#           </g>
#          </svg>
#         </li-icon>
#        </span>
#        <span class="nav-item__title">
#         Notifications
#        </span>
#       </a>
#      </li>
#      <li class="nav-item nav-item--profile" id="profile-nav-item" lang="en">
#      </li>
#     </ul>
#     <ul class="nav-side nav-container" role="navigation">
#      <li class="nav-item nav-item--spotlight-one nav-item__spotlight" id="spotlight-one-nav-item">
#       <a class="nav-placeholder" href="#">
#        <span class="nav-item__title">
#         Try Premium for free
#        </span>
#       </a>
#      </li>
#      <li class="nav-item nav-item--app-launcher" id="app-launcher-nav-item">
#       <span class="nav-placeholder">
#        <span class="nav-item__icon svg-icon-wrap">
#         <span class="visually-hidden">
#         </span>
#         <li-icon aria-hidden="true" color="true" type="nav-small-app-switcher-icon">
#          <svg class="nav-icon" height="24px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#           <g class="active-item" style="fill-opacity: 1">
#            <path d="M9,2h6V8H9V2ZM2,15H8V9H2v6Zm7,0h6V9H9v6ZM2,8H8V2H2V8ZM2,22H8V16H2v6Zm14-7h6V9H16v6ZM16,2V8h6V2H16ZM9,22h6V16H9v6Zm7,0h6V16H16v6Z">
#            </path>
#           </g>
#           <g class="inactive-item" style="fill: currentColor">
#            <path d="M10,10h4v4H10V10Zm0,11h4V17H10v4ZM3,14H7V10H3v4Zm0,7H7V17H3v4ZM3,7H7V3H3V7Zm14,7h4V10H17v4ZM17,3V7h4V3H17ZM10,7h4V3H10V7Zm7,14h4V17H17v4Z">
#            </path>
#           </g>
#          </svg>
#         </li-icon>
#        </span>
#        <span class="nav-item__title">
#         More
#        </span>
#       </span>
#      </li>
#     </ul>
#     <div id="nav-loader-wormhole">
#     </div>
#    </div>
#   </nav>
#   <div class="app-boot-bg-skeleton" id="app-boot-bg">
#    <div class="top-bar">
#    </div>
#    <div class="content">
#     <div class="initial-load-animation">
#      <div class="linkedin-image">
#      </div>
#      <div class="loading-bar">
#       <div class="blue-bar">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="https://static.licdn.com/sc/h/baygm8k9t825da5fw5ypwoj3q">
#   </script>
#   <script src="https://static.licdn.com/sc/h/46kk5s86huvp83j82wj442fsz,99oi985nuzch25cpm4fr5vora">
#   </script>
#   <script src="https://static.licdn.com/sc/h/169toz9uxzo7yszybf1i1u9nv">
#   </script>
#   <script src="https://static.licdn.com/sc/h/cu5eim5ijv6peoapd68yrxr4h">
#   </script>
#   <script src="https://static.licdn.com/sc/h/hkx8oajkzywxk0ue4eriuj9g">
#   </script>
#   <script src="https://static.licdn.com/sc/h/aclhnwtgnldz3ymd8pbcasvjj">
#   </script>
#   <script src="https://static.licdn.com/sc/h/282noy6lgfe37bsh78ao5drg3">
#   </script>
#   <script src="https://static.licdn.com/sc/h/9nvxm3morkzede6z4yj2liyth">
#   </script>
#   <script src="https://static.licdn.com/sc/h/8kd4d1upx3cbpdiu2cst6wx7a">
#   </script>
#   <script src="https://static.licdn.com/sc/h/1yc6bsvjbzsyg4rz2tjx49nj6,3hs5cwe5ufx5lx9j6tw5ux99w">
#   </script>
#   <code id="bpr-guid-229516" style="display: none">
#    {"data":{"$deletedFields":["launchAlert"],"mediaConfig":"crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig","$type":"com.linkedin.voyager.common.Configuration","$id":"crc4KtMwSB9CyP/2sFIqSw==,root"},"included":[{"mprConfig":"crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig","$deletedFields":[],"$type":"com.linkedin.voyager.common.MediaConfig","$id":"crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig"},{"$deletedFields":[],"sizes":["crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-0","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-1","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-2","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-3","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-4","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-5","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-6","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-7","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-8","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-9","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-10","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-11","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-12","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-13","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-14","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-15","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-16","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-17","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-18","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-19","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-20","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-21","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-22","crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-23"],"filters":"crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,filters","$type":"com.linkedin.voyager.common.MediaProcessorConfig","$id":"crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig"},{"cover":"https://media.licdn.com/mpr/mpr/shrinknp_{width}_{height}{+id}","$deletedFields":[],"contain":"https://media.licdn.com/mpr/mpr/shrinknp_{width}_{height}{+id}","original":"https://media.licdn.com/media{+id}","fill":"https://media.licdn.com/mpr/mpr/shrink_{width}_{height}{+id}","$type":"com.linkedin.voyager.common.MediaProcessorFilters","$id":"crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,filters"},{"$deletedFields":[],"width":60,"height":36,"$type":"com.linkedin.voyager.common.MediaProcessorSize","$id":"crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-1"},{"$deletedFields":[],"width":400,"height":400,"$type":"com.linkedin.voyager.common.MediaProcessorSize","$id":"crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig,sizes,49a307d4-93a7-4335-8262-2f2a6e3e0f02-21"},{"$deletedFields":[],"width":60,"height":30,"$type":"com.linkedin.voyager.common.MediaProcessorSize","$id":"crc4KtMwSB9CyP/2sFIqSw==,root,mediaConfig,mprConfig, ...
#   </code>
#   <code id="datalet-bpr-guid-229516" style="display: none">
#    {"request":"/voyager/api/configuration","status":200,"body":"bpr-guid-229516"}
#   </code>
#   <img class="datalet-bpr-guid-229516" src="..." style="display: none"/>
#   <code id="clientPageInstance" style="display: none">
#    urn:li:page:d_flagship3_university_alumni;r5Gg4/+6QsKFoJ9RVidnyw==
#   </code>
#   <img class="terminatorlet" src="..." style="display: none"/>
#   <div aria-live="polite" class="visually-hidden" id="a11y-notification" role="region">
#   </div>
#  </body>
# </html>

# %%
for links1 in soup1.find_all("a"):
    print(links1.get("href"))
# Out:
# /feed/
# /feed/
# /feed/
# /mynetwork/
# /jobs/
# /messaging/
# /notifications/
# #

# %% [markdown]
# Extracted data from SCU website to get a normal overview of the MSIS program.

# %%
url2 = 'https://www.scu.edu/business/ms-information-systems/prospective-students/class-profile/'
r2 = requests.get(url2)
r2.content
soup2 = BeautifulSoup(r2.content, "lxml")
#print(soup2.prettify())

# %%
for data1 in soup2.find_all("div", {"class" : "media-body"}):
    print(data1.text)
# Out:
# Class DemographicsWomen : 51%
# Average age : 26
# Multilingual :  89%
# AcademicsAverage undergraduate GPA  3.2
# Average GMAT  650
# Average GRE  308
# % holding graduate degrees  20%
# Professional ProfileAverage work experience :  2.3 years
# Employed at time of admission : 66%
# Selected hiring companies :  Apple, Cisco, Ernst & Young, Facebook, NetApp, NVIDIA, Symantec, Twitter
# Where SCU works

# %% [markdown]
# Tried to get data from a website called UberGrad.

# %%
url3 = 'https://www.ubergrad.com/universities/usa/mba-in-management-information-systems/top-universities'

r3 = requests.get(url3, auth = ('agasthya.agu@gmail.com','agasthya1992'))
soup3 = BeautifulSoup(r3.content, "lxml")
print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="519848174591-nj4uphrnrn6fjft50lvv72ikcu6jp55q.apps.googleusercontent.com" name="google-signin-clientid"/>
#   <meta content="https://www.googleapis.com/auth/plus.login https://www.googleapis.com/auth/userinfo.email" name="google-signin-scope"/>
#   <meta content="http://schema.org/AddAction" name="google-signin-requestvisibleactions"/>
#   <meta content="single_host_origin" name="google-signin-cookiepolicy"/>
#   <meta content="C8616F1DFF041DD64206D74E84019EF1" name="msvalidate.01"/>
#   <meta content="noodp" name="robots"/>
#   <meta content="FHdSolGD5jGIACQp4e9DZbhfgQo1nSJWZGKTrNn5S5c" name="google-site-verification"/>
#   <meta content="Study Abroad, Study in USA, Overseas Education &amp; Study Abroad Consultants - Ubergrad.com" property="keywords"/>
#   <meta content="Study abroad for overseas higher education or want to study in US? Ubergrad.com is an Overseas Higher Education &amp; Study Abroad Consultants providing expert advice &amp; information on leading universities &amp; colleges, courses, admission, student visa, application process to study overseas." property="description"/>
#   <meta content="Study Abroad, Study in USA, Overseas Education &amp; Study Abroad Consultants - Ubergrad.com" property="og:title"/>
#   <meta content="Study abroad for overseas higher education or want to study in US? Ubergrad.com is an Overseas Higher Education &amp; Study Abroad Consultants providing expert advice &amp; information on leading universities &amp; colleges, courses, admission, student visa, application process to study overseas." property="og:description"/>
#   <meta content="https://www.ubergrad.com/universities/usa/mba-in-management-information-systems/top-universities" property="og:url"/>
#   <meta content="https://www.ubergrad.com/images/logocap.png" property="og:image"/>
#   <link href="https://www.ubergrad.com/universities/usa/mba-in-management-information-systems/top-universities" rel="canonical"/>
#   <link href="https://fonts.googleapis.com/css?family=Abril+Fatface" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:300,300i,400,400i,500,500i,600,600i,700,700i" rel="stylesheet"/>
#   <style>
#    .g-recaptcha > div > div > iframe {
#             width: 100%;
#             height: 98px;
#         }
#
#         .g-recaptcha .rc-anchor-normal {
#             width: 100% !important;
#         }
#
#         #cssmenu > ul > li:last-child {
#             float: right;
#         }
#
#         @media (max-width:640px) {
#             #cssmenu > ul {
#                 padding-left: 0;
#             }
#         }
#   </style>
#   <link href="/fav32.ico" rel="icon" type="image/x-icon"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/fav120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/fav152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/PreloginHeaderCSS?v=FfwMTudvsjJrbVY80Vv3mSi53wo3jHRLi-n7k3JhCdo1" rel="stylesheet"/>
#   <link href="/Content/Plugins/seiyria-bootstrap-slider/dist/css/bootstrap-slider.css" rel="stylesheet"/>
#   <link href="/Content/Plugins/nanoscroller/dist/css/nanoscroller.css" rel="stylesheet"/>
#   <link href="/Content/Plugins/awesome-bootstrap-checkbox/awesome-bootstrap-checkbox.css" rel="stylesheet"/>
#   <link href="/Content/css/jPaginator.css" rel="stylesheet"/>
#   <link href="/Content/css/bootstrap-responsive-table-scrolling-shadows.css" rel="stylesheet"/>
#   <link href="/Content/css/bootstrap-multiselect.css" rel="stylesheet" type="text/css"/>
#   <link href="/Content/css/select2.css" rel="stylesheet"/>
#   <style type="text/css">
#    .filtersortbycost{font-size:13px;line-height:24px}
# .filtersortbycost a{display:block;color:grey;text-decoration:none}
# .filtersortbycost a.active,.filtersortbycost a:hover{color:#009df7;text-decoration:none}
# #SignUpModal{background:rgba(0,0,0,.3)}
# .modal-content{border:none;box-shadow:inherit}
# .panel-default{border:none}
# .checkbox input[type=checkbox],.checkbox input[type=radio]{opacity:1}
# .btn-group,.btn-group-vertical{width:100%}
# .dropdown-menu{width:230px;left:-20px}
# .newbtngroup{width:600px;margin:0 auto}
# .multiselect-container>li>a>label{overflow:hidden;margin-top:0;margin-bottom:0}
# .btn-group>.dropdown-menu::before,.dropdown-toggle>.dropdown-menu::before,.dropdown>.dropdown-menu::before{top:-10px}
# .section.search-layout .leftcell .module button.btn.btn-default{margin:0 0 10px}
# .btn-group>.dropdown-menu,.dropdown-toggle>.dropdown-menu,.dropdown>.dropdown-menu{margin-top:0}
# .recommendationsleft{width:70%;float:left}
# .recommendationsright{width:30%;float:left}
# .getrecommendationbox{width:95%;float:right;border:1px solid #E0E0E0;border-radius:5px;padding:15px;margin:10px 0}
# .getrecommendationboxtext{font-size:14px;line-height:20px;color:#606060}
# .removeTags{margin-left:3px}
# .form-control:focus{color:#202020!important}
# .form-control,.select2-container .select2-choice{color:#555!important}
# section.signup-section .form-group{margin:0;padding:0 0 10px}
# section.signup-section .row .col-sm-4,section.signup-section .row .col-sm-8,section.signup-section .row .left,section.signup-section .row .right{padding:0}
# section.signup-section .row{margin:0}
# section.signup-section .row .left .form-control{-webkit-border-radius:6px 0 0 6px;border-radius:6px 0 0 6px;border-right:0}
# section.signup-section .row .right .form-control{-webkit-border-radius:0 6px 6px 0;border-radius:0 6px 6px 0;border-left:1px solid #dce1e4}
# #ResultsDiv .featured{border-color:#d7b81f;background:#fffdf3;padding-top:16px}
# #ResultsDiv .featured span.sticky{position:absolute;top:-20px;right:25px;display:block;text-transform:uppercase;font-size:.72em;background:#d7b81f;padding:2px 7px;color:#fff;-webkit-border-radius:3px;border-radius:3px}
# #sort_by_items{background:0 0;border:1px solid #a7b5bd;border-radius:6px;height:30px;box-shadow:none;padding:0 12px!important}
# .search-layout .leftcell .module ul.nav.nav-tabs li a{color:#8b98a6!important;background:#fff!important}
# .search-layout .leftcell .module ul.nav.nav-tabs li.active a{background:#eef0f2!important;font-size:13px!important;color:#000!important}
# section.search-layout .leftcell .module span.radio label{color:grey;font-size:.86em}
# .scrollable-one{height:215px!important;margin-bottom:8px;width:100%}
# .nano{min-height:150px!important;max-height:250px!important}
# .dropdown-menu li a{color:#505050}
# .msaddbtn{position:absolute;top:10px;right:5px}
# .dropdown-menu>.active>a,.dropdown-menu>.active>a:focus,.dropdown-menu>.active>a:hover{background-color:#f6f6f6}
# .filtersortbycost{font-size:13px; line-height:24px;}
# .filtersortbycost a{display:block; color:#808080; text-decoration:none;}
# .filtersortbycost a:hover, .filtersortbycost a.active{color:#009df7; text-decoration:none;}
# #SignUpModal{background:rgba(0, 0, 0, 0.3);}
# .modal-content {border:none; box-shadow:inherit; }
# .panel-default{border:none;}
#  .checkbox input[type=checkbox],.checkbox input[type=radio]{opacity:1}
#  .checkbox input[type=radio],.checkboxnew input[type=checkbox]{opacity:0!important}
# .btn-group, .btn-group-vertical{width:100%;}
# .dropdown-menu{width:230px; left:-20px;}
# .newbtngroup{width:600px; margin:0 auto; }
# .section.search-layout .leftcell .module button.btn.btn-default{margin:0;}
# .multiselect-container > li > a > label{overflow:hidden; margin-top:0px; margin-bottom:0px;}
# .btn-group > .dropdown-menu::before, .dropdown-toggle > .dropdown-menu::before, .dropdown > .dropdown-menu::before{top:-10px;}
# .section.search-layout .leftcell .module button.btn.btn-default{margin-bottom:10px;}
# .btn-group > .dropdown-menu, .dropdown-toggle > .dropdown-menu, .dropdown > .dropdown-menu{margin-top:0;}
# .recommendationsleft{width:70%; float:left;}
# .recommendationsright{width:30%; float:left;}
# .getrecommendationbox{width:95%; float:right; border:#E0E0E0 1px solid; border-radius:5px; padding:15px; margin:10px 0;}
# .getrecommendationboxtext{font-size:14px; line-height:20px; color:#606060; }
# .removeTags{margin-left:3px;}
# .form-control:focus{color:#202020 !important;}
# .select2-container .select2-choice, .form-control{color:#555 !important;}
# section.signup-section .form-group{margin:0; padding:0px 0px 10px 0px;}
# section.signup-section .row{margin:0;}
# section.signup-section .row .col-sm-4, section.signup-section .row .col-sm-8{padding:0;}
# section.signup-section .row .left{padding:0px 0px 0px 0px;}
# section.signup-section .row .left .form-control{-webkit-border-radius: 6px 0 0 6px; border-radius:6px 0 0 6px; border-right: 0;}
# section.signup-section .row .right{padding:0px 0px 0px 0px;}
# section.signup-section .row .right .form-control{-webkit-border-radius:0 6px 6px 0; border-radius:0 6px 6px 0; border-left:1px solid #dce1e4;}
# #ResultsDiv .featured{border-color:#d7b81f; background:#fffdf3; padding-top:16px;}
# #ResultsDiv .featured span.sticky{position:absolute; top:-20px; right:25px; display:block; text-transform:uppercase; font-size:0.72em; background:#d7b81f; padding:2px 7px; color:#fff; -webkit-border-radius:3px; border-radius:3px;}
# #sort_by_items{background:transparent none repeat scroll 0 0; border:1px solid #a7b5bd; border-radius:6px; height:30px; box-shadow:none;}
# .search-layout .leftcell .module ul.nav.nav-tabs li a{color:#8b98a6 !important; background:#fff !important;}
# .search-layout .leftcell .module ul.nav.nav-tabs li.active a{background:#eef0f2 !important; font-size:13px !important; color:#000 !important;}
# section.search-layout .leftcell .module span.radio label{color:#808080; font-size:0.86em;}
# .scrollable-one{height:215px !important; margin-bottom:8px; width:100%;}
# #sort_by_items{padding:0 12px !important;}
# .nano{min-height:150px !important; max-height:250px !important;}
# .dropdown-menu li a{color:#505050;}
# .msaddbtn{position:absolute; top:10px; right:5px;}
# .dropdown-menu > .active > a, .dropdown-menu > .active > a:hover, .dropdown-menu > .active > a:focus{background-color:#f6f6f6;}
# input[type="checkbox"].styled:checked + label:after,
# input[type="radio"].styled:checked + label:after {
#   font-family: 'FontAwesome';
#   content: "";
# }
# .affix{top:120px !important;}
# #divGetFreeRecommendations{max-width:320px;}
#   </style>
#   <style type="text/css">
#    @media (max-width: 768px){
# .sidenav{height:100%;width:0px;position: fixed;z-index:500;top: 0;left:-30px;background-color: #FFFFFF;overflow-x: hidden;transition: 0.5s;padding:0;}
# .sidenavpadd{padding:0px 20px 0 30px;}
# .sidenav .closebtn{position: absolute;top: 0;right: 25px;font-size: 36px;margin-left: 50px;}
# }
# @media screen and (max-height: 450px){
# .sidenav a{font-size: 13px;}
# }
#   </style>
#   <script>
#    function openNav() {
#             document.getElementById("mySidenav").style.width = "350px";
#         }
#         function closeNav() {
#             document.getElementById("mySidenav").style.width = "0";
#         }
#   </script>
#   <script type="text/javascript">
#    var Tawk_API = Tawk_API || {}, Tawk_LoadStart = new Date();
#         (function () {
#             var s1 = document.createElement("script"), s0 = document.getElementsByTagName("script")[0];
#             s1.async = true;
#             s1.src = 'https://embed.tawk.to/573aa9ac1b563e906dddf7a1/default';
#             s1.charset = 'UTF-8';
#             s1.setAttribute('crossorigin', '*');
#             s0.parentNode.insertBefore(s1, s0);
#         })();
#
#         window.heap = window.heap || [], heap.load = function (e, t) { window.heap.appid = e, window.heap.config = t = t || {}; var n = t.forceSSL || "https:" === document.location.protocol, a = document.createElement("script"); a.type = "text/javascript", a.async = !0, a.src = (n ? "https:" : "http:") + "//cdn.heapanalytics.com/js/heap-" + e + ".js"; var o = document.getElementsByTagName("script")[0]; o.parentNode.insertBefore(a, o); for (var r = function (e) { return function () { heap.push([e].concat(Array.prototype.slice.call(arguments, 0))) } }, p = ["clearEventProperties", "identify", "setEventProperties", "track", "unsetEventProperty"], c = 0; c < p.length; c++) heap[p[c]] = r(p[c]) };
#         heap.load("803541404");
#
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-44204673-1', 'ubergrad.com', { 'siteSpeedSampleRate': 100 });
#         ga('require', 'displayfeatures');
#         ga('send', 'pageview');
#
#         // Hotjar Tracking Code for http://www.ubergrad.com
#         (function (h, o, t, j, a, r) {
#             h.hj = h.hj || function () { (h.hj.q = h.hj.q || []).push(arguments) };
#             h._hjSettings = { hjid: 170562, hjsv: 5 };
#             a = o.getElementsByTagName('head')[0];
#             r = o.createElement('script'); r.async = 1;
#             r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#             a.appendChild(r);
#         })(window, document, '//static.hotjar.com/c/hotjar-', '.js?sv=');
#   </script>
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script type="text/javascript">
#    (adsbygoogle = window.adsbygoogle || []).push({
#             google_ad_client: "ca-pub-8545655977583242",
#             enable_page_level_ads: true
#         });
#   </script>
#   <title>
#    Study Abroad, Study in USA, Overseas Education &amp; Study Abroad Consultants - Ubergrad.com
#   </title>
#  </head>
#  <body data-offset="120" data-spy="scroll" data-target="#myScrollspy">
#   <div class="loading">
#   </div>
#   <!--HEAER PART DESIGN START-->
#   <div id="fb-root">
#   </div>
#   <div id="headerScrollDiv">
#   </div>
#   <div class="container-fluid header">
#    <div class="row header_1">
#     <div class="fixwidthlg">
#      <div class="col-lg-2 col-md-2 col-sm-3 col-xs-8">
#       <div class="emblem">
#        <a href="/">
#         <img alt="" src="/newimages/logo.png"/>
#        </a>
#       </div>
#      </div>
#      <div class="col-lg-7 col-md-7 col-sm-4 col-xs-4">
#       <div id="cssmenu">
#        <ul>
#         <li class="headertabs" id="universitiestab">
#          <a href="https://www.ubergrad.com/universities" style="background: none;">
#           Universities
#          </a>
#         </li>
#         <li class="headertabs" id="communitytab">
#          <a href="https://www.ubergrad.com/success-stories" style="background: none;">
#           Success Stories
#          </a>
#         </li>
#         <li class="headertabs" id="marketpalcetab">
#          <a href="https://www.ubergrad.com/market-place" style="background: none;">
#           Market Place
#          </a>
#         </li>
#         <li class="headertabs" id="informationtab">
#          <a href="https://www.ubergrad.com/information-hub" style="background: none;">
#           Information Hub
#          </a>
#         </li>
#         <li class="headertabs positionrel" id="">
#          <a class="counselor" href="https://www.ubergrad.com/talk-to-our-counselor">
#           Talk to Our Counselor
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-5 col-xs-12">
#       <div class="signin">
#        <a class="active" href="https://www.ubergrad.com/login">
#         Sign In
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="row" style="border-bottom: 1px solid #eef0f2; background: #FFFFFF;">
#     <div class="fixwidthlg">
#      <div class="secnav" id="PageNameIds">
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--HEADER PART DESIGN END-->
#   <div class="fixedheight">
#    <input id="DefaultScoresList" name="ctl00$HTMLSection$DefaultScoresList" type="hidden" value='{
#   "GreMin": "210",
#   "GreMax": "340",
#   "GmatMin": "300",
#   "GmatMax": "800",
#   "IeltsMax": "9",
#   "IeltsMin": "3",
#   "ToeflMin": "50",
#   "ToeflMax": "120",
#   "MarksMin": "40",
#   "MarksMax": "100",
#   "CgpaMin": "4",
#   "CgpaMax": "10",
#   "GpaMin": "2",
#   "GpaMax": "4",
#   "FeeMin": "4500",
#   "FeeMax": "45000",
#   "HouseRentMin": "3000",
#   "HouseRentMax": "20000"
# }'/>
#    <input id="program_list" name="ctl00$HTMLSection$program_list" style="display: none;" type="hidden" value="Business / Management"/>
#    <input id="spec_list" name="ctl00$HTMLSection$spec_list" style="display: none;" type="hidden" value="Management Information Systems"/>
#    <input id="bud_min" name="ctl00$HTMLSection$bud_min" style="display: none;" type="hidden" value="4500"/>
#    <input id="bud_max" name="ctl00$HTMLSection$bud_max" style="display: none;" type="hidden" value="45000"/>
#    <input id="catalogID" name="ctl00$HTMLSection$catalogID" style="display: none;" type="hidden" value="31"/>
#    <input id="CatalogDeptID" name="ctl00$HTMLSection$CatalogDeptID" style="display: none;" type="hidden" value="2"/>
#    <input id="IsSearchPage" type="hidden" value="1"/>
#    <input id="IsBookmark" type="hidden" value="0"/>
#    <input id="SelectedCampusID" type="hidden" value="1"/>
#    <input id="SelectedCourseRefID" type="hidden" value="1"/>
#    <input id="hdn_actiontab" name="ctl00$HTMLSection$hdn_actiontab" type="hidden"/>
#    <input id="hdnStudentId" name="ctl00$HTMLSection$hdnStudentId" type="hidden" value="0"/>
#    <input id="HdnEmail" name="ctl00$HTMLSection$HdnEmail" type="hidden"/>
#    <input id="HdnSMObile" name="ctl00$HTMLSection$HdnSMObile" type="hidden"/>
#    <input id="hdnUrlID" name="ctl00$HTMLSection$hdnUrlID" type="hidden" value="mba-in-management-information-systems"/>
#    <input id="hdnDeptSort" name="ctl00$HTMLSection$hdnDeptSort" type="hidden" value="top-universities"/>
#    <input id="HdnUrlGre" name="ctl00$HTMLSection$HdnUrlGre" type="hidden"/>
#    <input id="HdnUrlGmat" name="ctl00$HTMLSection$HdnUrlGmat" type="hidden"/>
#    <input id="HdnUrlToefl" name="ctl00$HTMLSection$HdnUrlToefl" type="hidden"/>
#    <input id="HdnUrlIelts" name="ctl00$HTMLSection$HdnUrlIelts" type="hidden"/>
#    <input id="HdnUrlMarks" name="ctl00$HTMLSection$HdnUrlMarks" type="hidden"/>
#    <input id="HdnUrlCgpa" name="ctl00$HTMLSection$HdnUrlCgpa" type="hidden"/>
#    <input id="HdnUrlGpa" name="ctl00$HTMLSection$HdnUrlGpa" type="hidden"/>
#    <input id="HdnUrlIntake" name="ctl00$HTMLSection$HdnUrlIntake" type="hidden"/>
#    <input id="HdnUrlFee" name="ctl00$HTMLSection$HdnUrlFee" type="hidden"/>
#    <input id="HdnUrlRent" name="ctl00$HTMLSection$HdnUrlRent" type="hidden"/>
#    <input id="HdnUrlRegion" name="ctl00$HTMLSection$HdnUrlRegion" type="hidden"/>
#    <input id="HdnUrlUnivType" name="ctl00$HTMLSection$HdnUrlUnivType" type="hidden"/>
#    <input id="HdnUrlRank" name="ctl00$HTMLSection$HdnUrlRank" type="hidden"/>
#    <input id="HdnUrlSort" name="ctl00$HTMLSection$HdnUrlSort" type="hidden"/>
#    <input id="HdnName" name="ctl00$HTMLSection$HdnName" type="hidden" value="Management Information Systems"/>
#    <main class="content" role="main">
#     <section class="show_sub_section" style="display: none;">
#      <link href="http://fonts.googleapis.com/css?family=Open+Sans:400,300,600,700&amp;subset=all" rel="stylesheet" type="text/css"/>
#      <style type="text/css">
#       .margin-bottom-10{margin-bottom:10px;}
# .margin-top-20{margin-bottom:20px;}
# .margin-top-5{margin-top:5px;}
# .margin-left-5{margin-left:5px;}
# #container_gallery{width: 99% !important;}
# .scl-icns{left: 138px !important;}
# .text-yellow{color:#FFCC00;}
# #partner_imp_fact li{margin-bottom:10px;}
# #partner_box .nano{min-height: 500px !important;}
# .page-portlet-fullscreen{overflow: hidden;}
# .portlet{margin-top:0;margin-bottom:25px;padding:0;-webkit-border-radius:4px;-moz-border-radius:4px;-ms-border-radius:4px;-o-border-radius:4px;border-radius:4px}
# .portlet.portlet-fullscreen{z-index:10060;margin:0;position:fixed;top:0;left:0;bottom:0;right:0;width:100%;height:100%;background:#fff}
# .portlet.portlet-fullscreen>.portlet-body{overflow-y:auto;overflow-x:hidden;padding:0 10px}
# .portlet.portlet-fullscreen>.portlet-title{padding:0 10px}
# .portlet>.portlet-title{border-bottom:1px solid #eee;padding:0;margin-bottom:10px;min-height:41px;-webkit-border-radius:4px 4px 0 0;-moz-border-radius:4px 4px 0 0;-ms-border-radius:4px 4px 0 0;-o-border-radius:4px 4px 0 0;border-radius:4px 4px 0 0}
# .portlet>.portlet-title:after,.portlet>.portlet-title:before{content:" ";display:table}
# .portlet>.portlet-title:after{clear:both}
# .portlet>.portlet-title>.caption{float:left;display:inline-block;font-size:18px;line-height:18px;font-weight:300;padding:10px 0}
# .portlet>.portlet-title>.caption.bold{font-weight:400}
# .portlet>.portlet-title>.caption>i{float:left;margin-top:4px;display:inline-block;font-size:13px;margin-right:5px;color:#666}
# .portlet>.portlet-title>.caption>i.glyphicon{margin-top:2px}
# .portlet>.portlet-title>.caption>.caption-helper{padding:0;margin:0;line-height:13px;color:#9eacb4;font-size:13px;font-weight:400}
# .portlet>.portlet-title>.actions{float:right;display:inline-block;padding:6px 0}
# .portlet>.portlet-title>.actions>.dropdown-menu i{color:#555}
# .portlet>.portlet-title>.actions>.btn,.portlet>.portlet-title>.actions>.btn-group>.btn,.portlet>.portlet-title>.actions>.btn-group>.btn.btn-sm,.portlet>.portlet-title>.actions>.btn.btn-sm{padding:4px 10px;font-size:13px;line-height:1.5}
# .portlet>.portlet-title>.actions>.btn-group>.btn.btn-default,.portlet>.portlet-title>.actions>.btn-group>.btn.btn-sm.btn-default,.portlet>.portlet-title>.actions>.btn.btn-default,.portlet>.portlet-title>.actions>.btn.btn-sm.btn-default{padding:3px 9px}
# .portlet>.portlet-title>.actions>.btn-group>.btn.btn-sm>i,.portlet>.portlet-title>.actions>.btn-group>.btn>i,.portlet>.portlet-title>.actions>.btn.btn-sm>i,.portlet>.portlet-title>.actions>.btn>i{font-size:13px}
# .portlet>.portlet-title>.actions .btn-icon-only{padding:5px 7px 3px}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default{padding:4px 6px 2px}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default>i{font-size:14px}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default.fullscreen{font-family:FontAwesome;color:#a0a0a0;padding-top:3px}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default.fullscreen.btn-sm{padding:3px!important;height:27px;width:27px}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default.fullscreen:before{content:"\f065"}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default.fullscreen.on:before{content:"\f066"}
# .portlet>.portlet-title>.tools{float:right;display:inline-block;padding:12px 0 8px}
# .portlet>.portlet-title>.tools>a{display:inline-block;height:19px;margin-left:5px;opacity:1;filter:alpha(opacity=100)}
# .portlet>.portlet-title>.tools>a.remove{background-image:url(/images/portlet-remove-icon.png);background-repeat:no-repeat;width:11px}
# .portlet>.portlet-title>.tools>a.config{background-image:url(/images/portlet-config-icon.png);background-repeat:no-repeat;width:12px}
# .portlet>.portlet-title>.tools>a.reload{background-image:url(/images/portlet-reload-icon.png);width:13px}
# .portlet>.portlet-title>.tools>a.expand-full{background-image:url(/images/plus.png);width:20px;height:20px;visibility:visible}
# .portlet>.portlet-title>.tools>a.collapse-full{background-image:url(/images/minus-b.png);width:19px;visibility:visible}
# .portlet>.portlet-title>.tools>a.fullscreen{display:inline-block;top:-3px;position:relative;font-size:13px;font-family:FontAwesome;color:#ACACAC}
# .portlet>.portlet-title>.tools>a.fullscreen:before{content:"\f065"}
# .portlet>.portlet-title>.tools>a.fullscreen.on:before{content:"\f066"}
# .portlet>.portlet-title>.tools>a:hover{text-decoration:none;-webkit-transition:all .1s ease-in-out;-moz-transition:all .1s ease-in-out;-o-transition:all .1s ease-in-out;-ms-transition:all .1s ease-in-out;transition:all .1s ease-in-out;opacity:.8;filter:alpha(opacity=80)}
# .portlet>.portlet-title>.pagination{float:right;display:inline-block;margin:2px 0 0;border:0;padding:4px 0}
# .portlet>.portlet-title>.nav-tabs{background:0 0;margin:0;float:right;display:inline-block;border:0}
# .portlet>.portlet-title>.nav-tabs>li{background:0 0;margin:0;border:0}
# .portlet>.portlet-title>.nav-tabs>li>a{background:0 0;margin:5px 0 0 1px;border:0;padding:8px 10px;color:#fff}
# .portlet>.portlet-title>.nav-tabs>li.active>a,.portlet>.portlet-title>.nav-tabs>li:hover>a{color:#333;background:#fff;border:0}
# .portlet>.portlet-body{clear:both;-webkit-border-radius:0 0 4px 4px;-moz-border-radius:0 0 4px 4px;-ms-border-radius:0 0 4px 4px;-o-border-radius:0 0 4px 4px;border-radius:0 0 4px 4px}
# .portlet>.portlet-empty{min-height:125px}
# .portlet.full-height-content{margin-bottom:0}
# .portlet.bordered{border-left:2px solid #e6e9ec!important}
# .portlet.bordered>.portlet-title{border-bottom:0}
# .portlet.solid{padding:0 10px 10px;border:0}
# .portlet.solid>.portlet-title{border-bottom:0;margin-bottom:10px}
# .portlet.solid>.portlet-title>.caption{padding:16px 0 2px}
# .portlet.solid>.portlet-title>.actions{padding:12px 0 6px}
# .portlet.solid>.portlet-title>.tools{padding:14px 0 6px}
# .portlet.solid.bordered>.portlet-title{margin-bottom:10px}
# .portlet.box{padding:0!important}
# .portlet.box>.portlet-title{border-bottom:0;padding:0 10px;margin-bottom:0;color:#fff}
# .portlet.box>.portlet-title>.caption{padding:11px 0 9px}
# .portlet.box>.portlet-title>.tools>a.remove{background-image:url(/images/portlet-remove-icon-white.png)}
# .portlet.box>.portlet-title>.tools>a.config{background-image:url(/images/portlet-config-icon-white.png)}
# .portlet.box>.portlet-title>.tools>a.reload{background-image:url(/images/portlet-reload-icon-white.png)}
# .portlet.box>.portlet-title>.tools>a.expand{background-image:url(/images/portlet-expand-icon-white.png)}
# .portlet.box>.portlet-title>.tools>a.collapse{background-image:url(/images/portlet-collapse-icon-white.png)}
# .portlet.box>.portlet-title>.tools>a.fullscreen{color:#fdfdfd}
# .portlet.box>.portlet-title>.actions{padding:7px 0 5px}
# .portlet.box>.portlet-body{background-color:#fff;padding:10px}
# .portlet.box.portlet-fullscreen>.portlet-body{padding:10px}
# .portlet.light{padding:12px 20px 15px;background-color:#fff}
# .portlet.light.bordered{border:1px solid #e1e1e1!important}
# .portlet.light.bordered>.portlet-title{border-bottom:1px solid #eee}
# .portlet.light.bg-inverse{background:#F7F7F7}
# .portlet.light>.portlet-title{padding:0;min-height:48px}
# .portlet.light>.portlet-title>.caption{color:#666;padding:10px 0}
# .portlet.light>.portlet-title>.caption>.caption-subject{font-size:16px}
# .portlet.light>.portlet-title>.caption>i{color:#777;font-size:15px;font-weight:300;margin-top:3px}
# .portlet.light>.portlet-title>.caption.caption-md>.caption-subject{font-size:15px}
# .portlet.light>.portlet-title>.caption.caption-md>i{font-size:14px}
# .portlet.light>.portlet-title>.actions{padding:6px 0 14px}
# .portlet.light>.portlet-title>.actions .btn-default{color:#666}
# .portlet.light>.portlet-title>.actions .btn-icon-only{height:27px;width:27px}
# .portlet.light>.portlet-title>.actions .dropdown-menu li>a{color:#555}
# .portlet.light>.portlet-title>.inputs{float:right;display:inline-block;padding:4px 0}
# .portlet.light>.portlet-title>.inputs>.portlet-input .input-icon>i{font-size:14px;margin-top:9px}
# .portlet.light>.portlet-title>.inputs>.portlet-input .input-icon>.form-control{height:30px;padding:2px 26px 3px 10px;font-size:13px}
# .portlet.light>.portlet-title>.inputs>.portlet-input>.form-control{height:30px;padding:3px 10px;font-size:13px}
# .portlet.light>.portlet-title>.pagination{padding:2px 0 13px}
# .portlet.light>.portlet-title>.tools{padding:10px 0 13px;margin-top:2px}
# .portlet.light>.portlet-title>.nav-tabs>li{margin:0;padding:0}
# .portlet.light>.portlet-title>.nav-tabs>li>a{margin:0;padding:12px 13px 13px;font-size:13px;color:#666}
# .portlet.light>.portlet-title>.nav-tabs>li.active>a,.portlet.light>.portlet-title>.nav-tabs>li:hover>a{margin:0;background:0 0;color:#333}
# .portlet.light.form-fit{padding:0}
# .portlet.light.form-fit>.portlet-title{padding:17px 20px 10px;margin-bottom:0}
# .portlet.light .portlet-body{padding-top:8px}
# .portlet.light.portlet-fullscreen>.portlet-body{padding:8px 0}
# .tab-pane>p:last-child{margin-bottom:0}
# .tabs-reversed>li{float:right;margin-right:0}
# .tabs-reversed>li>a{margin-right:0}
# .portlet-sortable:not(.portlet-fullscreen)>.portlet-title{cursor:move}
# .portlet-sortable-placeholder{border:2px dashed #eee;margin-bottom:25px}
# .portlet-sortable-empty{height:45px}
# body{position:relative}
# .page-header{margin:0}
# .fixed-header{position:fixed;top:0;left:20}
# .hor-menu .search-bg li:hover a{background:#dea908!important;color:#fff}
# #imp_fact li:last-child{list-style-type:none}
#      </style>
#      <style type="text/css">
#       .item{float:left;position:relative;line-height:1em;border-bottom:.094em solid #fff;border-right:.031em solid #fff;border-left:.031em solid #fff}
# .grid-sizer, .item{width:20%}
# @media screen and (max-width:1224px){
# .grid-sizer, .item{width:33.33%}
# }
# @media screen and (max-width:720px){
# .grid-sizer, .item{width:50%}
# }
# .overlay,.overlay .description{width:100%;left:0;position:absolute}
# @media screen and (max-width:480px){
# .grid-sizer, .item{width:100%}
# }
# .image{max-width:100%;display:block;margin:5px}
# .image:after{clear:both}
# .overlay{height:100%;background-color:rgba(0,0,0,.5);top:0;text-decoration:none;color:#fff!important;display:none}
# .overlay .title{text-align:center;font-size:20px}
# .overlay .description{bottom:0;background-color:rgba(0,0,0,.8);margin:0}
# .timeline_div,.timeline_resp{background:#36a6eb;border-radius:60px;color:#fff;height:100px;padding:20px;text-align:center;width:100px;font-size:12px}
# .overlay .description p{margin:20px}
# .item:hover .overlay{display:block}
# .timeline_div{left:0;position:absolute;top:-45px}
# .time-points li{text-align:center}
# #deadlines_responsive{display:none}
# @media (max-width:800px){
# #deadlines_responsive{display:block!important}
# .timeLine{display:none}
# }
# .btn-group>.dropdown-menu::after,.btn-group>.dropdown-menu::before,.col-srch-drop .dropdown>.dropdown-menu::after,.col-srch-drop .dropdown>.dropdown-menu::before,.dropdown-toggle>.dropdown-menu::after,.dropdown-toggle>.dropdown-menu::before{right:9px!important;left:auto}
# .affix{top:0}
# #detail_div .page-header{background-color:#fff!important}
#      </style>
#      <div class="header-bg page-header">
#       <div class="container">
#        <div class="row">
#         <label class="" id="return_to_main" style="cursor:pointer; position:absolute; top:80px;right:15px;">
#          <img src="/images/remove.png" title="close"/>
#         </label>
#         <div class="col-md-4">
#         </div>
#         <div class="col-md-4 text-center margin-top-10">
#          <div class="margin-bottom-10" style="height:190px;">
#           <img alt="" class="img-circle campus_logo" height="100" src="" width="100"/>
#           <h1 class="text-w campus_name" style="font-size:14px;">
#           </h1>
#           <label class="block font-grey-lite font-12" id="campus_addr">
#           </label>
#          </div>
#          <label class="scl-icns">
#           <a href="#" id="fb_link">
#            <img alt="facebook" src="/images/fb-circle.png"/>
#           </a>
#           <a href="#" id="twitter_link">
#            <img alt="twitter" src="/images/twit-circle.png"/>
#           </a>
#           <a href="#" id="youtube_link">
#            <img alt="Youtube" src="/images/youtube-circle.png"/>
#           </a>
#          </label>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="clear">
#      </div>
#      <div class="page-container">
#       <!-- BEGIN PAGE CONTENT -->
#       <div class="page-content">
#        <div class="container-fluid" style="margin-left:15px;">
#         <div>
#          <ul class="list-inline gallery-links text-center margin-top-10">
#           <li class="active" id="menu_overview" style="cursor:pointer;">
#            Overview
#           </li>
#           <li id="menu_tour" style="cursor:pointer;">
#           </li>
#           <li id="menu_vtour" style="cursor:pointer;">
#           </li>
#          </ul>
#         </div>
#         <div class="clearfix">
#         </div>
#         <div class="row margin-bottom-50" id="desc_divs">
#          <div class="col-sm-12 col-md-12 line-hgt" id="desc">
#          </div>
#          <div id="galary_list" style="display:none;">
#           <h5 class="bold font-grey-lite">
#            Gallery
#           </h5>
#           <div id="container_gallery">
#            <div class="grid-sizer">
#            </div>
#           </div>
#          </div>
#          <div id="show_iframe" style="display:none;">
#           <iframe height="768" id="youvisit_link" src="" width="99%">
#           </iframe>
#           <div id="visit_err">
#           </div>
#          </div>
#          <div class="clearfix">
#          </div>
#         </div>
#         <div class="alert alert-warning margin-top-30 text-center" id="partner_div" style="margin-bottom:40px;display:none;">
#          <h5 class="mt-0">
#           <strong>
#            Partnered University
#           </strong>
#          </h5>
#          <label class="block" style="font-weight:normal; color:#333;">
#           This university is actively interacting with students on Ubergrad.  If you are interested, The University officials will answer your questions. They can also look at your profile and evaluate your chances of Admission.
#          </label>
#          <label class="btn-group margin-top-5 margin-right-10 bookmark_univ_popup">
#           <a class="btn btn-default btn-icon " style="height:34px;">
#            <i class="fa fa-star" id="bk_icon">
#            </i>
#           </a>
#           <a class="btn btn-default btn-text " href="#" id="add_to_fav" style="width:170px;">
#            I am Interested
#           </a>
#          </label>
#          <button class="btn btn-green student_eval_submit" id="evaluate" type="button">
#           Request Profile Evaluation
#          </button>
#         </div>
#         <div class="row show_overview">
#          <div class="col-sm-3 col-md-3">
#           <ul class="comn-list list-group font-13 item-mb margin-top-10">
#            <li>
#             <div class="col-sm-2">
#              <img alt="Established Year" src="/images/establish-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Established Year:
#              </h5>
#              <label id="estd">
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li>
#             <div class="col-sm-2">
#              <img alt="University Type" src="/images/uni-type-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               University Type:
#              </h5>
#              <label id="c_type" style="text-transform:capitalize">
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li>
#             <div class="col-sm-2">
#              <img alt="University Setting" src="/images/location-pin-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               University Location:
#              </h5>
#              <label id="c_setting">
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li>
#             <div class="col-sm-2">
#              <img alt="Highest Degree Offered" src="/images/uni-type-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Highest Degree Offered:
#              </h5>
#              <label id="high_degree">
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li>
#             <div class="col-sm-2">
#              <img alt="Geographic Region" src="/images/chart-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Geographic Region:
#              </h5>
#              <label id="region">
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li>
#             <div class="col-sm-2">
#              <img alt="Calendar" src="/images/calen-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Admission Seasons:
#              </h5>
#              <label id="calender">
#               -N/A-
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li class="partner_li" style="display:none;">
#             <div class="col-sm-2">
#              <img alt="Calendar" src="/images/tution-fee-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Tution Fee:
#              </h5>
#              <label id="p_tution_fee">
#               $500 Per Year
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li class="partner_li" style="display:none;">
#             <div class="col-sm-2">
#              <img alt="Calendar" src="/images/application-fee.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Application Fee:
#              </h5>
#              <label id="p_app_fee">
#               $50
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#           </ul>
#          </div>
#          <div class="col-sm-5 col-md-5">
#           <h5 class="bold font-grey-lite">
#            Why this University ?
#           </h5>
#           <div id="normal_box" style="display:none;">
#            <ul class="list-inline">
#             <li class="col-md-4">
#              <div class="box-sm box-pd box-red margin-bottom-10">
#               <span class="block font-xs text-op" id="enrol_stu" style="color:#c13232;">
#               </span>
#               <span class="block font-12" id="male_rate">
#               </span>
#               <span class="font-12" id="female_rate">
#               </span>
#               <span class="block font-12" id="int_stu">
#               </span>
#              </div>
#              <div class="box-sm box-pd box-green">
#               <span class="font-xs bold text-op" style="color:#0b8546;">
#                Acceptance Ratio
#               </span>
#               <span class="block margin-top-10" id="acpt_rate">
#               </span>
#              </div>
#             </li>
#             <li class="col-md-8">
#              <div class="box-md box-pd box-yellow">
#               <span class="font-xs bold text-op" style="color:#967c0d;">
#                Why this University ?
#               </span>
#               <ul class="block margin-top-10" id="imp_fact" style="list-style-type:disc;margin-left:-25px;">
#               </ul>
#              </div>
#             </li>
#            </ul>
#            <div class="clearfix">
#            </div>
#            <ul class="list-inline margin-top-20">
#             <li class="col-md-8">
#              <div class="box-md box-pd box-purple">
#               <span class="font-xs bold text-op" style="color:#6e43ab;">
#                Admission Requirements
#               </span>
#               <label class="block margin-top-10" id="requirements">
#               </label>
#              </div>
#             </li>
#             <li class="col-md-4">
#              <div class="box-sm box-pd box-acqa margin-bottom-10">
#               <span class="font-xs bold text-op" style="color:#1274ac;">
#                Scholarships &amp; Assistanships
#               </span>
#               <label class="block margin-top-10" id="c_scholarship">
#               </label>
#              </div>
#              <div class="box-sm box-pd box-orange">
#               <span class="font-xs bold text-op" style="color:#b8511f;">
#                College Fee (per Year)
#               </span>
#               <label class="block" id="c_clg_fee">
#               </label>
#               <span class="font-xs bold text-op" style="color:#b8511f;">
#                Application Fee
#               </span>
#               <label class="block" id="c_app_fee">
#               </label>
#              </div>
#             </li>
#            </ul>
#            <div class="clearfix">
#            </div>
#           </div>
#           <div class="partner-box-md box-pd box-purple" id="partner_box" style="display:none;">
#            <div class="scrollable-two nano has-scrollbar" style="height:450px !important;">
#             <div class="nano-content">
#              <ul class="block margin-top-10" id="partner_imp_fact" style="list-style-type:disc;margin-left:-25px;">
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="col-sm-4 col-md-4">
#           <h5 class="bold font-grey-lite">
#            Map
#           </h5>
#           <div class="lite-grey">
#            <div>
#             <div id="google_engine" style="height:140px;margin:0 auto;">
#             </div>
#             <ul class="list-inline margin-top-10 text-center">
#              <li>
#               <label id="map_name">
#               </label>
#              </li>
#             </ul>
#            </div>
#            <h5 class="bold font-grey-lite margin-top-20 margin-left-5">
#             Current Temperature
#            </h5>
#            <div class="weather-box">
#             <ul class="list-inline">
#              <li>
#               <label class="margin-top-30">
#                <a class="temps margin-right-10" href="javascript:;" id="f_temp">
#                 F°
#                </a>
#                |
#                <a class="active temps margin-left-10" href="javascript:;" id="c_temp">
#                 C°
#                </a>
#               </label>
#              </li>
#              <li class="pull-right">
#               <h2>
#                <img alt="" src="/images/sun-icn.png" style="margin-right:20px;"/>
#                <span class="margin-top-5" id="weather">
#                </span>
#               </h2>
#              </li>
#             </ul>
#             <div class="clearfix">
#             </div>
#            </div>
#            <h5 class="bold font-grey-lite margin-left-5" id="temp_heading">
#             Average Monthly Temperature
#            </h5>
#            <div class="p10" id="b_chart" style="margin-left: -40px;">
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="clearfix">
#         </div>
#        </div>
#        <div class="container-fluid show_overview">
#         <div class="row" id="design_tl">
#          <h3 class="bold font-16 font-grey-gallery margin-top-40" style="margin-left: 45px;">
#           Application Deadlines
#          </h3>
#          <div class="timeLine" style="border-bottom:2px solid #ccc;margin: 45px;">
#           <span class="font-blue-soft bold">
#            2015
#           </span>
#           <ul class="list-inline time-points">
#            <li class="col-sm-1">
#             <div id="Jan_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Jan
#            </li>
#            <li class="col-sm-1">
#             <div id="Feb_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Feb
#            </li>
#            <li class="col-sm-1">
#             <div id="Mar_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Mar
#            </li>
#            <li class="col-sm-1">
#             <div id="Apr_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Apr
#            </li>
#            <li class="col-sm-1">
#             <div id="May_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             May
#            </li>
#            <li class="col-sm-1">
#             <div id="Jun_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Jun
#            </li>
#            <li class="col-sm-1">
#             <div id="Jul_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Jul
#            </li>
#            <li class="col-sm-1">
#             <div id="Aug_tl">
#             </div>
#             <img alt="" src="/images/point.png"/>
#             <br/>
#             Aug
#            </li>
#            <li class="col-sm-1">
#             <div id="Sep_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Sep
#            </li>
#            <li class="col-sm-1">
#             <div id="Oct_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Oct
#            </li>
#            <li class="col-sm-1">
#             <div id="Nov_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Nov
#            </li>
#            <li class="col-sm-1">
#             <div id="Dec_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Dec
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="row" id="deadlines_responsive">
#         </div>
#        </div>
#        <div class="container-fluid " id="deadline_stat" style="display:none;">
#         <label class="pull-right">
#          <b style="color:#f16565">
#           Note:
#          </b>
#          Has rolling deadlines
#         </label>
#        </div>
#        <div class="text-center margin-top-40 margin-bottom-50 show_overview">
#         <ul class="list-inline program_click">
#          <li>
#           <button class="btn btn-circle blue-darken bold-6 btn-wd" id="match_btn" type="button">
#            Matching Programs
#           </button>
#          </li>
#          <li>
#           <button class="btn btn-circle btn-normal bold-6 btn-wd" id="rest_btn" type="button">
#            All Programs
#           </button>
#          </li>
#         </ul>
#        </div>
#        <div class="container">
#         <div class="show_overview p15" id="match_prgm_div" style="display:none;">
#         </div>
#         <div class="show_overview p15" id="rest_prgm_div" style="display:none;">
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="modal" id="gallery-view-box" style="display:none;">
#       <div class="modal-header">
#        <a data-dismiss="modal" href="javascript:;" style="float:right;">
#         <img src="/Content/images/icon-color-close.png"/>
#        </a>
#       </div>
#       <div>
#        <ul class="pic-view" style="z-index:2 !important;">
#         <li>
#          <a href="javascript:;" id="prev_img">
#          </a>
#         </li>
#         <li class="displayed">
#          <div id="img-view" style="display:none;">
#          </div>
#          <div id="video-view" style="display:none;">
#          </div>
#          <div style="clear:both;">
#          </div>
#         </li>
#         <li>
#          <a href="javascript:;" id="next_img">
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div style="clear:both;">
#       </div>
#       <div class="row">
#        <div class="bold font-md gal-bot-txt" id="g_txt" style="padding:0px ! important;">
#        </div>
#       </div>
#      </div>
#      <!-- /.modal -->
#      <div class="modal fade" id="Bookmark_PopUp">
#       <div class="modal-dialog" style="width:500px;">
#        <div class="modal-content">
#         <div class="modal-header" style="padding:0px">
#          <button class="close" data-dismiss="modal" type="button">
#           <span aria-hidden="true">
#            ×
#           </span>
#           <span class="sr-only">
#            Close
#           </span>
#          </button>
#         </div>
#         <div class="modal-body" style="padding:15px;">
#          <div class="UniversityDetails text-center">
#           <img alt="" id="show_univ_logo_popup" src="" width="100"/>
#           <h5 class="font-12 bold font-black" id="UniversityNamePopup">
#            UniversityName
#           </h5>
#           <label class="text-grey font-12">
#            <span class="margin-top-5" id="CityPopup">
#             City
# ...
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <input id="Redirecturl" type="hidden"/>
#   <input id="PageORPopup" type="hidden" value="1"/>
#   <input id="Captcharesponse" type="hidden" value=""/>
#   <input id="hdn_actiontab" type="hidden" value=""/>
#   <input id="hdn_profilepic" type="hidden" value=""/>
#   <input id="hdn_currentobj" objecttype="" type="hidden" value=""/>
#   <input id="HdnEmail" type="hidden"/>
#   <input id="OffsiteRedirecturl" name="ctl00$OffsiteRedirecturl" type="hidden"/>
#   <input id="hdnWebsiteURL" name="ctl00$hdnWebsiteURL" type="hidden" value="https://www.ubergrad.com"/>
#   <script async="" defer="" src="https://apis.google.com/js/client:platform.js?onload=render">
#   </script>
#   <script src="/PreloginHeaderScript?v=R_aa2Zy1PkJxydgujr-mUXB5mrHytUPuGgQLPPLUMEQ1">
#   </script>
#   <script src="/content/scripts/blockUI.js">
#   </script>
#   <script type="text/javascript">
#    function blinker() { $('.blinking').fadeOut(800); $('.blinking').fadeIn(800); }
#         setInterval(blinker, 1000);
#         var CurrentClickedObj;
#         $('[data-toggle="tooltip"]').tooltip();
#         $(document).delegate("#doitlater", "click", function () {
#             window.location.href = "/" + $("#Redirecturl").val();
#         });
#         $(document).delegate(".fb_login", "click", function () {
#             login();
#             schedule_login = $(".fb-login").attr("sch");
#             tutorial_login = $(".fb-login").attr("tt");
#         });
#         $(document).delegate(".g_login", "click", function () {
#             gapi.auth.signIn({
#                 'callback': signinCallback
#             });
#         });
#
#         function login() {
#             FB.getLoginStatus(function (a) {
#                 if (a.status === "connected") {
#                     console.log(a.authResponse.userID);
#                     create_session(a.authResponse.userID);
#                 } else {
#                     FB.login(function (response) {
#                         if (response.authResponse) {
#                             // connected
#                             access_token = response.authResponse.accessToken;
#                             fb_user_id = response.authResponse.userID;
#                             create_session(fb_user_id);
#                             console.log(access_token);
#                             console.log(fb_user_id);
#                         } else {
#                             // cancelled
#                         }
#                     }, { scope: 'email,publish_actions' })
#                 }
#             });
#         }
#
#         function create_session(fb_user_id) {
#             FB.api('/me', { fields: 'email,first_name,last_name,gender,name,location' }, function (response) {
#                 //console.log(response);
#                 var st = "", city = "", country = "", gender = "", fn = "", ln = "";
#                 fn = (response.first_name) ? response.first_name : "";
#                 ln = (response.last_name) ? response.last_name : "";
#                 gender = (response.gender) ? response.gender : "";
#                 city = (response.location) ? response.location.name : "";
#                 var tutorial = $('#tutorial').html();
#                 var PageorPopup = $("#PageORPopup").val();
#                 $.ajax(
#                         {
#                             url: '/StudentLogin.ashx',
#                             type: 'POST',
#                             dataType: 'JSON',
#                             beforeSend: function (xhr) { xhr.setRequestHeader('X-CSRF-Token', $('meta[name="csrf-token"]').attr('content')) },
#                             data: {
#                                 type: 6, facebook_user_id: response.id, facebook_name: response.name, facebook_email: response.email, tutorial: tutorial,
#                                 first_name: fn, last_name: ln, gender: gender, state: st, country: country, city: city
#                             },
#                             success: function (data) {
#                                 if (data.ret_msg == 'ok') {
#                                     if (PageorPopup == 0) {
#                                     $("#SignUpModal").modal("hide");
#                                     //if (res.profileStatus == 0) {
#                                     //        SignupAfterAction(res.profileStatus);
#                                     //       $("#WelcomeModal").modal("show");
#                                     //   } else {
#                                             window.location.reload();
#                                      //  }
#                                    }
#                                     if (PageorPopup == 1 ) {
#                                     //  window.location.href = "/welcome";
#                                     //} else if (res.profileStatus == 1) {
#                                         window.location.href = "/studenthome";
#                                     }
#                                   // $("#DegreeLevelModal").modal("show");
#                                   if ($("#OffsiteRedirecturl").val() != "") {
#                                        window.location.href = $("#OffsiteRedirecturl").val();
#                                    }
#                                   else {
#                                       // SignupAfterAction(data.profileStatus);
#                                       window.location.href = "/studenthome";
#                                   }
#
#                                 }
#                                 else if (data.ret_msg == 'exists') {
#                                     alert("email already exists");
#                                 }
#                             }
#                         }
#                         );
#             });
#         }
#         var access_token = "";
#         var fb_user_id = "";
#         $(document).ready(function () {
#             $("#registration").addClass("active");
#             $("#logIn").removeClass("active");
#             (function () {
#                 var e = document.createElement('script');
#                 e.src = '//connect.facebook.net/en_US/all.js';
#                 e.async = true;
#                 document.getElementById('fb-root').appendChild(e);
#             }());
#             window.fbAsyncInit = function () {
#
#                 FB.init({ appId: "170090126513098", status: true, cookie: true, xfbml: true, oauth: true });
#             };
#         });
#
#         //function render() {
#         //    $('.g_login').click(function () {
#         //        gapi.auth.signIn({
#         //            'callback': signinCallback
#         //        });
#         //    });
#         //}
#         function signinCallback(authResult) {
#             var PageorPopup = $("#PageORPopup").val();
#             if (authResult['status']['signed_in']) {
#                 console.log(authResult);
#                 if (authResult['status']['method'] == "PROMPT") {
#                     $.ajax({
#                         url: "/StudentLogin.ashx",
#                         type: "POST",
#                         async: false,
#                         data: { atoken: authResult.access_token, type: 7 },
#                         dataType: "json",
#                         success: function (a) {
#
#                             $.ajax({
#                                 url: "/StudentLogin.ashx",
#                                 type: "POST",
#                                 async: false,
#                                 data: { name: a.name, email: a.email, user_id: a.id, picture: a.picture, type: 8, otype: "google", fname: a.given_name, lname: a.family_name },
#                                 dataType: "json",
#                                 success: function (a) {
#                                     if (a.ret_msg == 'ok') {
#                                        // $("#DegreeLevelModal").modal("show");
#                                         if ($("#OffsiteRedirecturl").val() != "") {
#                                             window.location.href = $("#OffsiteRedirecturl").val();
#                                         }
#                                         else {
#                                             //SignupAfterAction(a.profileStatus);
#                                             window.location.href = "/studenthome";
#                                         }
#
#                                         if (PageorPopup == 0) {
#                                             $("#SignUpModal").modal("hide");
#                                             //if (res.profileStatus == 0) {
#                                             //    $("#WelcomeModal").modal("show");
#                                             //} else {
#                                                 window.location.reload();
#                                             //}
#                                         }
#                                         if (PageorPopup == 1) {
#                                         //    window.location.href = "/welcome";
#                                         //} else if (res.profileStatus == 1) {
#                                             window.location.href = "/studenthome";
#                                         }
#
#                                     }
#                                     else if (a.ret_msg == 'exists') {
#                                         alert("Already account exists with this Email Address !! Please use another account.");
#                                     }
#                                 },
#                                 error: function (a, err) { alert(err); }
#                             });
#
#
#                         },
#                         error: function (a, err) {
#                             alert(err);
#                         }
#                     });
#
#                 }
#             }
#         }
#         function ReplaceAllSpecChar(name) {
#             name = name.replace(/( |_|&|-|\/|'|"|,)+/gi, '-');
#             return name;
#         }
#
#
#         function GetUnivEncodedName(name) {
#             name = name.replace(/[^a-zA-Z0-9]+/gi, '-').replace(/(^-)|(-$)/g, "");
#             return name;
#         }
#         $(document).ready(function () {
#             $(document).on("click", ".headerscroll", function () {
#                 $("html, body").animate({ scrollTop: $("#headerScrollDiv").offset().top - 300 }, 1000);
#             });
#             $(document).on('click', '.show-reset-form', function () {
#                 $("#errorPassword").html('')
#                 $("#two_btn").hide();
#                 $("#txtUsermail").val('');
#                 $(".section-log-in").hide();
#                 $(".section-forgot-password").show();
#             });
#             $(document).on('click', '.show-login-form', function () {
#                 $(".section-log-in").show();
#                 $(".section-forgot-password").hide();
#
#             });
#             $('#txtSearchUniversityName').keypress(function (event) {
#                 if (event.keyCode == 13) {
#                     var searchUniversityKey = $('#txtSearchUniversityName').val();
#                     if (searchUniversityKey != '' || searchUniversityKey != 0) {
#                         window.location.href = $("#hdnWebsiteURL").val() + '/CommunityCollegeList.aspx?universityKey=' + searchUniversityKey;
#                     }
#                 }
#             });
#
#
#             var images = $(".img-circle");
#             images.on('load', function () {
#             }).on('error', function () { $(this).attr("src", "/newimages/add-universe.png") });
#
#         });
#   </script>
#   <script src="/content/scripts/jquery-ui-1.10.3.custom.min.js" type="text/javascript">
#   </script>
#   <script src="/Content/Plugins/nanoscroller/dist/javascripts/jquery.nanoscroller.js" type="text/javascript">
#   </script>
#   <script src="/Content/Scripts/bootstrap-multiselect.min.js" type="text/javascript">
#   </script>
#   <script src="/Content/scripts/jPaginator.js">
#   </script>
#   <script src="/Content/scripts/lodash.js">
#   </script>
#   <script src="/Content/Scripts/jquery.knob.js">
#   </script>
#   <script src="/Content/Scripts/SignupNew.js?V=1.2">
#   </script>
#   <script src="/Content/Scripts/StuLogin.js?V=1.2">
#   </script>
#   <script src="/Content/Scripts/Custom/emailMobileVerification.js?V=1.1">
#   </script>
#   <script src="/Content/Scripts/UrlSearch.js?V=1.2" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var refFlag = 0;
#         var websiteURL = $("#hdnWebsiteURL").val();
#         $("#closeLoginIcon").show();
#         $("#closeSignUpIcon").show();
#         $(".knob").knob();
#         $("#profile_complete_now").click(function () {
#             $("#SignUpModal").modal("show");
#             $("#RedirectionPage").val(websiteURL+"/my-profile");
#         });
#         $("#set_prefernces").click(function () {
#             $("#SignUpModal").modal("show");
#             $("#RedirectionPage").val(websiteURL + "/my-preferences");
#         });
#         DefultPageNames();
#         function DefultPageNames() {
#             var PageNames = '';
#             PageNames += '<ul>';
#             PageNames += '<li><a href="'+websiteURL+'">Home</a></li>';
#             PageNames += '<li><a href="' + websiteURL + '/universities">Universities</a></li>';
#             PageNames += '<li class="mle">Search</li>';
#             PageNames += '</ul>';
#             $("#PageNameIds").html(PageNames);
#         }
#   </script>
#   <script type="text/javascript">
#    //var verifyCallback = function (response) {
#         //    $("#Captcharesponse").val(response);
#         //};
#         //var LoadCallBack = function () {
#         //    grecaptcha.render('googlecaptcha', {
#         //        'sitekey': '6Le_BhcUAAAAAPl9y_eAFogi3SHgtA-XiMDxUM65',
#         //        'callback': verifyCallback
#         //    });
#         //}
#
#         function VerifyCaptcha() {
#             var boolFlag = false;
#             $.ajax({
#                 url: "/StudentLogin.ashx",
#                 type: "POST",
#                 async: false,
#                 data: { gresponse: $("#Captcharesponse").val(), type: 29 },
#                 dataType: "JSON",
#                 success: function (a) {
#                     //alert(a.success);
#                     boolFlag = a.success;
#                 },
#                 error: function (res, err) {
#                     console.log(err);
#                 }
#             });
#             return boolFlag;
#         }
#         $(document).on("click", "#StuBachelor", function () {
#             var studentLevel = 'Bachelors';
#             submitstudentlevel(studentLevel);
#         });
#         $(document).on("click", "#StuMaster", function () {
#             var studentLevel = 'Masters';
#             submitstudentlevel(studentLevel);
#         });
#         function submitstudentlevel(studentLevel) {
#             $.ajax({
#                 url: "/StudentLogin.ashx",
#                 type: "POST",
#                 async: false,
#                 data: { Degreelevel: studentLevel, type: 31 },
#                 dataType: "JSON",
#                 success: function (a) {
#                     if (a.retMsg == 'ok') {
#                         $("#DegreeLevelModal").modal("hide");
#                         if ($("#OffsiteRedirecturl").val() != "") {
#                             window.location.href = $("#OffsiteRedirecturl").val();
#                         }
#                         else {
#                             if (studentLevel == "Bachelors") {
#                                 window.location.href = "Bachelors/Home";
#                             }
#                             else {
#                                 window.location.href = "/studenthome";
#                             }
#                             //SignupAfterAction(a.Level, a.profileStatus);
#                         }
#
#                     }
#                 },
#                 error: function (res, err) {
#                     console.log(err);
#                 }
#             });
#         }
#   </script>
#  </body>
# </html>

# %% [markdown]
# Tried using session to login to the website as the data I needed was restricted by a login access.

# %%
from lxml import html

session_requests = requests.session()

login_url = "https://www.ubergrad.com/login"
result = session_requests.get(login_url)
payload = {
	"ctl00$HTMLSection$ctl00$txtUsername": "agasthya.agu@gmail.com", 
	"ctl00$HTMLSection$ctl00$txtPassword": "agasthya1992", 
	"csrfmiddlewaretoken": "<CSRF_TOKEN>"
}
tree = html.fromstring(result.text)
#authenticity_token = list(set(tree.xpath("//input[@name='csrfmiddlewaretoken']/@value")))[0]
result = session_requests.post(
	login_url, 
	data = payload, 
	headers = dict(referer=login_url)
)

# %%
url = 'https://www.ubergrad.com/universities/usa/mba-in-management-information-systems/top-universities'
result = session_requests.get(
	url, 
	headers = dict(referer = url)
)

# %%
soup3 = BeautifulSoup(result.content, "lxml")
print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="519848174591-nj4uphrnrn6fjft50lvv72ikcu6jp55q.apps.googleusercontent.com" name="google-signin-clientid"/>
#   <meta content="https://www.googleapis.com/auth/plus.login https://www.googleapis.com/auth/userinfo.email" name="google-signin-scope"/>
#   <meta content="http://schema.org/AddAction" name="google-signin-requestvisibleactions"/>
#   <meta content="single_host_origin" name="google-signin-cookiepolicy"/>
#   <meta content="C8616F1DFF041DD64206D74E84019EF1" name="msvalidate.01"/>
#   <meta content="noodp" name="robots"/>
#   <meta content="FHdSolGD5jGIACQp4e9DZbhfgQo1nSJWZGKTrNn5S5c" name="google-site-verification"/>
#   <meta content="Study Abroad, Study in USA, Overseas Education &amp; Study Abroad Consultants - Ubergrad.com" property="keywords"/>
#   <meta content="Study abroad for overseas higher education or want to study in US? Ubergrad.com is an Overseas Higher Education &amp; Study Abroad Consultants providing expert advice &amp; information on leading universities &amp; colleges, courses, admission, student visa, application process to study overseas." property="description"/>
#   <meta content="Study Abroad, Study in USA, Overseas Education &amp; Study Abroad Consultants - Ubergrad.com" property="og:title"/>
#   <meta content="Study abroad for overseas higher education or want to study in US? Ubergrad.com is an Overseas Higher Education &amp; Study Abroad Consultants providing expert advice &amp; information on leading universities &amp; colleges, courses, admission, student visa, application process to study overseas." property="og:description"/>
#   <meta content="https://www.ubergrad.com/universities/usa/mba-in-management-information-systems/top-universities" property="og:url"/>
#   <meta content="https://www.ubergrad.com/images/logocap.png" property="og:image"/>
#   <link href="https://www.ubergrad.com/universities/usa/mba-in-management-information-systems/top-universities" rel="canonical"/>
#   <link href="https://fonts.googleapis.com/css?family=Abril+Fatface" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:300,300i,400,400i,500,500i,600,600i,700,700i" rel="stylesheet"/>
#   <style>
#    .g-recaptcha > div > div > iframe {
#             width: 100%;
#             height: 98px;
#         }
#
#         .g-recaptcha .rc-anchor-normal {
#             width: 100% !important;
#         }
#
#         #cssmenu > ul > li:last-child {
#             float: right;
#         }
#
#         @media (max-width:640px) {
#             #cssmenu > ul {
#                 padding-left: 0;
#             }
#         }
#   </style>
#   <link href="/fav32.ico" rel="icon" type="image/x-icon"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/fav120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/fav152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/PreloginHeaderCSS?v=BGRMC_d9RqnnXjLu4_t8EDfnv-7R95yFDpRiB_LN9zM1" rel="stylesheet"/>
#   <link href="/Content/Plugins/seiyria-bootstrap-slider/dist/css/bootstrap-slider.css" rel="stylesheet"/>
#   <link href="/Content/Plugins/nanoscroller/dist/css/nanoscroller.css" rel="stylesheet"/>
#   <link href="/Content/Plugins/awesome-bootstrap-checkbox/awesome-bootstrap-checkbox.css" rel="stylesheet"/>
#   <link href="/Content/css/jPaginator.css" rel="stylesheet"/>
#   <link href="/Content/css/bootstrap-responsive-table-scrolling-shadows.css" rel="stylesheet"/>
#   <link href="/Content/css/bootstrap-multiselect.css" rel="stylesheet" type="text/css"/>
#   <link href="/Content/css/select2.css" rel="stylesheet"/>
#   <style type="text/css">
#    .filtersortbycost{font-size:13px;line-height:24px}
# .filtersortbycost a{display:block;color:grey;text-decoration:none}
# .filtersortbycost a.active,.filtersortbycost a:hover{color:#009df7;text-decoration:none}
# #SignUpModal{background:rgba(0,0,0,.3)}
# .modal-content{border:none;box-shadow:inherit}
# .panel-default{border:none}
# .checkbox input[type=checkbox],.checkbox input[type=radio]{opacity:1}
# .btn-group,.btn-group-vertical{width:100%}
# .dropdown-menu{width:230px;left:-20px}
# .newbtngroup{width:600px;margin:0 auto}
# .multiselect-container>li>a>label{overflow:hidden;margin-top:0;margin-bottom:0}
# .btn-group>.dropdown-menu::before,.dropdown-toggle>.dropdown-menu::before,.dropdown>.dropdown-menu::before{top:-10px}
# .section.search-layout .leftcell .module button.btn.btn-default{margin:0 0 10px}
# .btn-group>.dropdown-menu,.dropdown-toggle>.dropdown-menu,.dropdown>.dropdown-menu{margin-top:0}
# .recommendationsleft{width:70%;float:left}
# .recommendationsright{width:30%;float:left}
# .getrecommendationbox{width:95%;float:right;border:1px solid #E0E0E0;border-radius:5px;padding:15px;margin:10px 0}
# .getrecommendationboxtext{font-size:14px;line-height:20px;color:#606060}
# .removeTags{margin-left:3px}
# .form-control:focus{color:#202020!important}
# .form-control,.select2-container .select2-choice{color:#555!important}
# section.signup-section .form-group{margin:0;padding:0 0 10px}
# section.signup-section .row .col-sm-4,section.signup-section .row .col-sm-8,section.signup-section .row .left,section.signup-section .row .right{padding:0}
# section.signup-section .row{margin:0}
# section.signup-section .row .left .form-control{-webkit-border-radius:6px 0 0 6px;border-radius:6px 0 0 6px;border-right:0}
# section.signup-section .row .right .form-control{-webkit-border-radius:0 6px 6px 0;border-radius:0 6px 6px 0;border-left:1px solid #dce1e4}
# #ResultsDiv .featured{border-color:#d7b81f;background:#fffdf3;padding-top:16px}
# #ResultsDiv .featured span.sticky{position:absolute;top:-20px;right:25px;display:block;text-transform:uppercase;font-size:.72em;background:#d7b81f;padding:2px 7px;color:#fff;-webkit-border-radius:3px;border-radius:3px}
# #sort_by_items{background:0 0;border:1px solid #a7b5bd;border-radius:6px;height:30px;box-shadow:none;padding:0 12px!important}
# .search-layout .leftcell .module ul.nav.nav-tabs li a{color:#8b98a6!important;background:#fff!important}
# .search-layout .leftcell .module ul.nav.nav-tabs li.active a{background:#eef0f2!important;font-size:13px!important;color:#000!important}
# section.search-layout .leftcell .module span.radio label{color:grey;font-size:.86em}
# .scrollable-one{height:215px!important;margin-bottom:8px;width:100%}
# .nano{min-height:150px!important;max-height:250px!important}
# .dropdown-menu li a{color:#505050}
# .msaddbtn{position:absolute;top:10px;right:5px}
# .dropdown-menu>.active>a,.dropdown-menu>.active>a:focus,.dropdown-menu>.active>a:hover{background-color:#f6f6f6}
# .filtersortbycost{font-size:13px; line-height:24px;}
# .filtersortbycost a{display:block; color:#808080; text-decoration:none;}
# .filtersortbycost a:hover, .filtersortbycost a.active{color:#009df7; text-decoration:none;}
# #SignUpModal{background:rgba(0, 0, 0, 0.3);}
# .modal-content {border:none; box-shadow:inherit; }
# .panel-default{border:none;}
#  .checkbox input[type=checkbox],.checkbox input[type=radio]{opacity:1}
#  .checkbox input[type=radio],.checkboxnew input[type=checkbox]{opacity:0!important}
# .btn-group, .btn-group-vertical{width:100%;}
# .dropdown-menu{width:230px; left:-20px;}
# .newbtngroup{width:600px; margin:0 auto; }
# .section.search-layout .leftcell .module button.btn.btn-default{margin:0;}
# .multiselect-container > li > a > label{overflow:hidden; margin-top:0px; margin-bottom:0px;}
# .btn-group > .dropdown-menu::before, .dropdown-toggle > .dropdown-menu::before, .dropdown > .dropdown-menu::before{top:-10px;}
# .section.search-layout .leftcell .module button.btn.btn-default{margin-bottom:10px;}
# .btn-group > .dropdown-menu, .dropdown-toggle > .dropdown-menu, .dropdown > .dropdown-menu{margin-top:0;}
# .recommendationsleft{width:70%; float:left;}
# .recommendationsright{width:30%; float:left;}
# .getrecommendationbox{width:95%; float:right; border:#E0E0E0 1px solid; border-radius:5px; padding:15px; margin:10px 0;}
# .getrecommendationboxtext{font-size:14px; line-height:20px; color:#606060; }
# .removeTags{margin-left:3px;}
# .form-control:focus{color:#202020 !important;}
# .select2-container .select2-choice, .form-control{color:#555 !important;}
# section.signup-section .form-group{margin:0; padding:0px 0px 10px 0px;}
# section.signup-section .row{margin:0;}
# section.signup-section .row .col-sm-4, section.signup-section .row .col-sm-8{padding:0;}
# section.signup-section .row .left{padding:0px 0px 0px 0px;}
# section.signup-section .row .left .form-control{-webkit-border-radius: 6px 0 0 6px; border-radius:6px 0 0 6px; border-right: 0;}
# section.signup-section .row .right{padding:0px 0px 0px 0px;}
# section.signup-section .row .right .form-control{-webkit-border-radius:0 6px 6px 0; border-radius:0 6px 6px 0; border-left:1px solid #dce1e4;}
# #ResultsDiv .featured{border-color:#d7b81f; background:#fffdf3; padding-top:16px;}
# #ResultsDiv .featured span.sticky{position:absolute; top:-20px; right:25px; display:block; text-transform:uppercase; font-size:0.72em; background:#d7b81f; padding:2px 7px; color:#fff; -webkit-border-radius:3px; border-radius:3px;}
# #sort_by_items{background:transparent none repeat scroll 0 0; border:1px solid #a7b5bd; border-radius:6px; height:30px; box-shadow:none;}
# .search-layout .leftcell .module ul.nav.nav-tabs li a{color:#8b98a6 !important; background:#fff !important;}
# .search-layout .leftcell .module ul.nav.nav-tabs li.active a{background:#eef0f2 !important; font-size:13px !important; color:#000 !important;}
# section.search-layout .leftcell .module span.radio label{color:#808080; font-size:0.86em;}
# .scrollable-one{height:215px !important; margin-bottom:8px; width:100%;}
# #sort_by_items{padding:0 12px !important;}
# .nano{min-height:150px !important; max-height:250px !important;}
# .dropdown-menu li a{color:#505050;}
# .msaddbtn{position:absolute; top:10px; right:5px;}
# .dropdown-menu > .active > a, .dropdown-menu > .active > a:hover, .dropdown-menu > .active > a:focus{background-color:#f6f6f6;}
# input[type="checkbox"].styled:checked + label:after,
# input[type="radio"].styled:checked + label:after {
#   font-family: 'FontAwesome';
#   content: "";
# }
# .affix{top:120px !important;}
# #divGetFreeRecommendations{max-width:320px;}
#   </style>
#   <style type="text/css">
#    @media (max-width: 768px){
# .sidenav{height:100%;width:0px;position: fixed;z-index:500;top: 0;left:-30px;background-color: #FFFFFF;overflow-x: hidden;transition: 0.5s;padding:0;}
# .sidenavpadd{padding:0px 20px 0 30px;}
# .sidenav .closebtn{position: absolute;top: 0;right: 25px;font-size: 36px;margin-left: 50px;}
# }
# @media screen and (max-height: 450px){
# .sidenav a{font-size: 13px;}
# }
#   </style>
#   <script>
#    function openNav() {
#             document.getElementById("mySidenav").style.width = "350px";
#         }
#         function closeNav() {
#             document.getElementById("mySidenav").style.width = "0";
#         }
#   </script>
#   <script type="text/javascript">
#    var Tawk_API = Tawk_API || {}, Tawk_LoadStart = new Date();
#         (function () {
#             var s1 = document.createElement("script"), s0 = document.getElementsByTagName("script")[0];
#             s1.async = true;
#             s1.src = 'https://embed.tawk.to/573aa9ac1b563e906dddf7a1/default';
#             s1.charset = 'UTF-8';
#             s1.setAttribute('crossorigin', '*');
#             s0.parentNode.insertBefore(s1, s0);
#         })();
#
#         window.heap = window.heap || [], heap.load = function (e, t) { window.heap.appid = e, window.heap.config = t = t || {}; var n = t.forceSSL || "https:" === document.location.protocol, a = document.createElement("script"); a.type = "text/javascript", a.async = !0, a.src = (n ? "https:" : "http:") + "//cdn.heapanalytics.com/js/heap-" + e + ".js"; var o = document.getElementsByTagName("script")[0]; o.parentNode.insertBefore(a, o); for (var r = function (e) { return function () { heap.push([e].concat(Array.prototype.slice.call(arguments, 0))) } }, p = ["clearEventProperties", "identify", "setEventProperties", "track", "unsetEventProperty"], c = 0; c < p.length; c++) heap[p[c]] = r(p[c]) };
#         heap.load("803541404");
#
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-44204673-1', 'ubergrad.com', { 'siteSpeedSampleRate': 100 });
#         ga('require', 'displayfeatures');
#         ga('send', 'pageview');
#
#         // Hotjar Tracking Code for http://www.ubergrad.com
#         (function (h, o, t, j, a, r) {
#             h.hj = h.hj || function () { (h.hj.q = h.hj.q || []).push(arguments) };
#             h._hjSettings = { hjid: 170562, hjsv: 5 };
#             a = o.getElementsByTagName('head')[0];
#             r = o.createElement('script'); r.async = 1;
#             r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#             a.appendChild(r);
#         })(window, document, '//static.hotjar.com/c/hotjar-', '.js?sv=');
#   </script>
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script type="text/javascript">
#    (adsbygoogle = window.adsbygoogle || []).push({
#             google_ad_client: "ca-pub-8545655977583242",
#             enable_page_level_ads: true
#         });
#   </script>
#   <title>
#    Study Abroad, Study in USA, Overseas Education &amp; Study Abroad Consultants - Ubergrad.com
#   </title>
#  </head>
#  <body data-offset="120" data-spy="scroll" data-target="#myScrollspy">
#   <div class="loading">
#   </div>
#   <!--HEAER PART DESIGN START-->
#   <div id="fb-root">
#   </div>
#   <div id="headerScrollDiv">
#   </div>
#   <div class="container-fluid header">
#    <div class="row header_1">
#     <div class="fixwidthlg">
#      <div class="col-lg-2 col-md-2 col-sm-3 col-xs-8">
#       <div class="emblem">
#        <a href="/">
#         <img alt="" src="/newimages/logo.png"/>
#        </a>
#       </div>
#      </div>
#      <div class="col-lg-7 col-md-7 col-sm-4 col-xs-4">
#       <div id="cssmenu">
#        <ul>
#         <li class="headertabs" id="universitiestab">
#          <a href="https://www.ubergrad.com/universities" style="background: none;">
#           Universities
#          </a>
#         </li>
#         <li class="headertabs" id="communitytab">
#          <a href="https://www.ubergrad.com/success-stories" style="background: none;">
#           Success Stories
#          </a>
#         </li>
#         <li class="headertabs" id="marketpalcetab">
#          <a href="https://www.ubergrad.com/market-place" style="background: none;">
#           Market Place
#          </a>
#         </li>
#         <li class="headertabs" id="informationtab">
#          <a href="https://www.ubergrad.com/information-hub" style="background: none;">
#           Information Hub
#          </a>
#         </li>
#         <li class="headertabs positionrel" id="">
#          <a class="counselor" href="https://www.ubergrad.com/talk-to-our-counselor">
#           Talk to Our Counselor
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-5 col-xs-12">
#       <div class="signin">
#        <a class="active" href="https://www.ubergrad.com/login">
#         Sign In
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="row" style="border-bottom: 1px solid #eef0f2; background: #FFFFFF;">
#     <div class="fixwidthlg">
#      <div class="secnav" id="PageNameIds">
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--HEADER PART DESIGN END-->
#   <div class="fixedheight">
#    <input id="DefaultScoresList" name="ctl00$HTMLSection$DefaultScoresList" type="hidden" value='{
#   "GreMin": "210",
#   "GreMax": "340",
#   "GmatMin": "300",
#   "GmatMax": "800",
#   "IeltsMax": "9",
#   "IeltsMin": "3",
#   "ToeflMin": "50",
#   "ToeflMax": "120",
#   "MarksMin": "40",
#   "MarksMax": "100",
#   "CgpaMin": "4",
#   "CgpaMax": "10",
#   "GpaMin": "2",
#   "GpaMax": "4",
#   "FeeMin": "4500",
#   "FeeMax": "45000",
#   "HouseRentMin": "3000",
#   "HouseRentMax": "20000"
# }'/>
#    <input id="program_list" name="ctl00$HTMLSection$program_list" style="display: none;" type="hidden" value="Business / Management"/>
#    <input id="spec_list" name="ctl00$HTMLSection$spec_list" style="display: none;" type="hidden" value="Management Information Systems"/>
#    <input id="bud_min" name="ctl00$HTMLSection$bud_min" style="display: none;" type="hidden" value="4500"/>
#    <input id="bud_max" name="ctl00$HTMLSection$bud_max" style="display: none;" type="hidden" value="45000"/>
#    <input id="catalogID" name="ctl00$HTMLSection$catalogID" style="display: none;" type="hidden" value="31"/>
#    <input id="CatalogDeptID" name="ctl00$HTMLSection$CatalogDeptID" style="display: none;" type="hidden" value="2"/>
#    <input id="IsSearchPage" type="hidden" value="1"/>
#    <input id="IsBookmark" type="hidden" value="0"/>
#    <input id="SelectedCampusID" type="hidden" value="1"/>
#    <input id="SelectedCourseRefID" type="hidden" value="1"/>
#    <input id="hdn_actiontab" name="ctl00$HTMLSection$hdn_actiontab" type="hidden"/>
#    <input id="hdnStudentId" name="ctl00$HTMLSection$hdnStudentId" type="hidden" value="0"/>
#    <input id="HdnEmail" name="ctl00$HTMLSection$HdnEmail" type="hidden"/>
#    <input id="HdnSMObile" name="ctl00$HTMLSection$HdnSMObile" type="hidden"/>
#    <input id="hdnUrlID" name="ctl00$HTMLSection$hdnUrlID" type="hidden" value="mba-in-management-information-systems"/>
#    <input id="hdnDeptSort" name="ctl00$HTMLSection$hdnDeptSort" type="hidden" value="top-universities"/>
#    <input id="HdnUrlGre" name="ctl00$HTMLSection$HdnUrlGre" type="hidden"/>
#    <input id="HdnUrlGmat" name="ctl00$HTMLSection$HdnUrlGmat" type="hidden"/>
#    <input id="HdnUrlToefl" name="ctl00$HTMLSection$HdnUrlToefl" type="hidden"/>
#    <input id="HdnUrlIelts" name="ctl00$HTMLSection$HdnUrlIelts" type="hidden"/>
#    <input id="HdnUrlMarks" name="ctl00$HTMLSection$HdnUrlMarks" type="hidden"/>
#    <input id="HdnUrlCgpa" name="ctl00$HTMLSection$HdnUrlCgpa" type="hidden"/>
#    <input id="HdnUrlGpa" name="ctl00$HTMLSection$HdnUrlGpa" type="hidden"/>
#    <input id="HdnUrlIntake" name="ctl00$HTMLSection$HdnUrlIntake" type="hidden"/>
#    <input id="HdnUrlFee" name="ctl00$HTMLSection$HdnUrlFee" type="hidden"/>
#    <input id="HdnUrlRent" name="ctl00$HTMLSection$HdnUrlRent" type="hidden"/>
#    <input id="HdnUrlRegion" name="ctl00$HTMLSection$HdnUrlRegion" type="hidden"/>
#    <input id="HdnUrlUnivType" name="ctl00$HTMLSection$HdnUrlUnivType" type="hidden"/>
#    <input id="HdnUrlRank" name="ctl00$HTMLSection$HdnUrlRank" type="hidden"/>
#    <input id="HdnUrlSort" name="ctl00$HTMLSection$HdnUrlSort" type="hidden"/>
#    <input id="HdnName" name="ctl00$HTMLSection$HdnName" type="hidden" value="Management Information Systems"/>
#    <main class="content" role="main">
#     <section class="show_sub_section" style="display: none;">
#      <link href="http://fonts.googleapis.com/css?family=Open+Sans:400,300,600,700&amp;subset=all" rel="stylesheet" type="text/css"/>
#      <style type="text/css">
#       .margin-bottom-10{margin-bottom:10px;}
# .margin-top-20{margin-bottom:20px;}
# .margin-top-5{margin-top:5px;}
# .margin-left-5{margin-left:5px;}
# #container_gallery{width: 99% !important;}
# .scl-icns{left: 138px !important;}
# .text-yellow{color:#FFCC00;}
# #partner_imp_fact li{margin-bottom:10px;}
# #partner_box .nano{min-height: 500px !important;}
# .page-portlet-fullscreen{overflow: hidden;}
# .portlet{margin-top:0;margin-bottom:25px;padding:0;-webkit-border-radius:4px;-moz-border-radius:4px;-ms-border-radius:4px;-o-border-radius:4px;border-radius:4px}
# .portlet.portlet-fullscreen{z-index:10060;margin:0;position:fixed;top:0;left:0;bottom:0;right:0;width:100%;height:100%;background:#fff}
# .portlet.portlet-fullscreen>.portlet-body{overflow-y:auto;overflow-x:hidden;padding:0 10px}
# .portlet.portlet-fullscreen>.portlet-title{padding:0 10px}
# .portlet>.portlet-title{border-bottom:1px solid #eee;padding:0;margin-bottom:10px;min-height:41px;-webkit-border-radius:4px 4px 0 0;-moz-border-radius:4px 4px 0 0;-ms-border-radius:4px 4px 0 0;-o-border-radius:4px 4px 0 0;border-radius:4px 4px 0 0}
# .portlet>.portlet-title:after,.portlet>.portlet-title:before{content:" ";display:table}
# .portlet>.portlet-title:after{clear:both}
# .portlet>.portlet-title>.caption{float:left;display:inline-block;font-size:18px;line-height:18px;font-weight:300;padding:10px 0}
# .portlet>.portlet-title>.caption.bold{font-weight:400}
# .portlet>.portlet-title>.caption>i{float:left;margin-top:4px;display:inline-block;font-size:13px;margin-right:5px;color:#666}
# .portlet>.portlet-title>.caption>i.glyphicon{margin-top:2px}
# .portlet>.portlet-title>.caption>.caption-helper{padding:0;margin:0;line-height:13px;color:#9eacb4;font-size:13px;font-weight:400}
# .portlet>.portlet-title>.actions{float:right;display:inline-block;padding:6px 0}
# .portlet>.portlet-title>.actions>.dropdown-menu i{color:#555}
# .portlet>.portlet-title>.actions>.btn,.portlet>.portlet-title>.actions>.btn-group>.btn,.portlet>.portlet-title>.actions>.btn-group>.btn.btn-sm,.portlet>.portlet-title>.actions>.btn.btn-sm{padding:4px 10px;font-size:13px;line-height:1.5}
# .portlet>.portlet-title>.actions>.btn-group>.btn.btn-default,.portlet>.portlet-title>.actions>.btn-group>.btn.btn-sm.btn-default,.portlet>.portlet-title>.actions>.btn.btn-default,.portlet>.portlet-title>.actions>.btn.btn-sm.btn-default{padding:3px 9px}
# .portlet>.portlet-title>.actions>.btn-group>.btn.btn-sm>i,.portlet>.portlet-title>.actions>.btn-group>.btn>i,.portlet>.portlet-title>.actions>.btn.btn-sm>i,.portlet>.portlet-title>.actions>.btn>i{font-size:13px}
# .portlet>.portlet-title>.actions .btn-icon-only{padding:5px 7px 3px}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default{padding:4px 6px 2px}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default>i{font-size:14px}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default.fullscreen{font-family:FontAwesome;color:#a0a0a0;padding-top:3px}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default.fullscreen.btn-sm{padding:3px!important;height:27px;width:27px}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default.fullscreen:before{content:"\f065"}
# .portlet>.portlet-title>.actions .btn-icon-only.btn-default.fullscreen.on:before{content:"\f066"}
# .portlet>.portlet-title>.tools{float:right;display:inline-block;padding:12px 0 8px}
# .portlet>.portlet-title>.tools>a{display:inline-block;height:19px;margin-left:5px;opacity:1;filter:alpha(opacity=100)}
# .portlet>.portlet-title>.tools>a.remove{background-image:url(/images/portlet-remove-icon.png);background-repeat:no-repeat;width:11px}
# .portlet>.portlet-title>.tools>a.config{background-image:url(/images/portlet-config-icon.png);background-repeat:no-repeat;width:12px}
# .portlet>.portlet-title>.tools>a.reload{background-image:url(/images/portlet-reload-icon.png);width:13px}
# .portlet>.portlet-title>.tools>a.expand-full{background-image:url(/images/plus.png);width:20px;height:20px;visibility:visible}
# .portlet>.portlet-title>.tools>a.collapse-full{background-image:url(/images/minus-b.png);width:19px;visibility:visible}
# .portlet>.portlet-title>.tools>a.fullscreen{display:inline-block;top:-3px;position:relative;font-size:13px;font-family:FontAwesome;color:#ACACAC}
# .portlet>.portlet-title>.tools>a.fullscreen:before{content:"\f065"}
# .portlet>.portlet-title>.tools>a.fullscreen.on:before{content:"\f066"}
# .portlet>.portlet-title>.tools>a:hover{text-decoration:none;-webkit-transition:all .1s ease-in-out;-moz-transition:all .1s ease-in-out;-o-transition:all .1s ease-in-out;-ms-transition:all .1s ease-in-out;transition:all .1s ease-in-out;opacity:.8;filter:alpha(opacity=80)}
# .portlet>.portlet-title>.pagination{float:right;display:inline-block;margin:2px 0 0;border:0;padding:4px 0}
# .portlet>.portlet-title>.nav-tabs{background:0 0;margin:0;float:right;display:inline-block;border:0}
# .portlet>.portlet-title>.nav-tabs>li{background:0 0;margin:0;border:0}
# .portlet>.portlet-title>.nav-tabs>li>a{background:0 0;margin:5px 0 0 1px;border:0;padding:8px 10px;color:#fff}
# .portlet>.portlet-title>.nav-tabs>li.active>a,.portlet>.portlet-title>.nav-tabs>li:hover>a{color:#333;background:#fff;border:0}
# .portlet>.portlet-body{clear:both;-webkit-border-radius:0 0 4px 4px;-moz-border-radius:0 0 4px 4px;-ms-border-radius:0 0 4px 4px;-o-border-radius:0 0 4px 4px;border-radius:0 0 4px 4px}
# .portlet>.portlet-empty{min-height:125px}
# .portlet.full-height-content{margin-bottom:0}
# .portlet.bordered{border-left:2px solid #e6e9ec!important}
# .portlet.bordered>.portlet-title{border-bottom:0}
# .portlet.solid{padding:0 10px 10px;border:0}
# .portlet.solid>.portlet-title{border-bottom:0;margin-bottom:10px}
# .portlet.solid>.portlet-title>.caption{padding:16px 0 2px}
# .portlet.solid>.portlet-title>.actions{padding:12px 0 6px}
# .portlet.solid>.portlet-title>.tools{padding:14px 0 6px}
# .portlet.solid.bordered>.portlet-title{margin-bottom:10px}
# .portlet.box{padding:0!important}
# .portlet.box>.portlet-title{border-bottom:0;padding:0 10px;margin-bottom:0;color:#fff}
# .portlet.box>.portlet-title>.caption{padding:11px 0 9px}
# .portlet.box>.portlet-title>.tools>a.remove{background-image:url(/images/portlet-remove-icon-white.png)}
# .portlet.box>.portlet-title>.tools>a.config{background-image:url(/images/portlet-config-icon-white.png)}
# .portlet.box>.portlet-title>.tools>a.reload{background-image:url(/images/portlet-reload-icon-white.png)}
# .portlet.box>.portlet-title>.tools>a.expand{background-image:url(/images/portlet-expand-icon-white.png)}
# .portlet.box>.portlet-title>.tools>a.collapse{background-image:url(/images/portlet-collapse-icon-white.png)}
# .portlet.box>.portlet-title>.tools>a.fullscreen{color:#fdfdfd}
# .portlet.box>.portlet-title>.actions{padding:7px 0 5px}
# .portlet.box>.portlet-body{background-color:#fff;padding:10px}
# .portlet.box.portlet-fullscreen>.portlet-body{padding:10px}
# .portlet.light{padding:12px 20px 15px;background-color:#fff}
# .portlet.light.bordered{border:1px solid #e1e1e1!important}
# .portlet.light.bordered>.portlet-title{border-bottom:1px solid #eee}
# .portlet.light.bg-inverse{background:#F7F7F7}
# .portlet.light>.portlet-title{padding:0;min-height:48px}
# .portlet.light>.portlet-title>.caption{color:#666;padding:10px 0}
# .portlet.light>.portlet-title>.caption>.caption-subject{font-size:16px}
# .portlet.light>.portlet-title>.caption>i{color:#777;font-size:15px;font-weight:300;margin-top:3px}
# .portlet.light>.portlet-title>.caption.caption-md>.caption-subject{font-size:15px}
# .portlet.light>.portlet-title>.caption.caption-md>i{font-size:14px}
# .portlet.light>.portlet-title>.actions{padding:6px 0 14px}
# .portlet.light>.portlet-title>.actions .btn-default{color:#666}
# .portlet.light>.portlet-title>.actions .btn-icon-only{height:27px;width:27px}
# .portlet.light>.portlet-title>.actions .dropdown-menu li>a{color:#555}
# .portlet.light>.portlet-title>.inputs{float:right;display:inline-block;padding:4px 0}
# .portlet.light>.portlet-title>.inputs>.portlet-input .input-icon>i{font-size:14px;margin-top:9px}
# .portlet.light>.portlet-title>.inputs>.portlet-input .input-icon>.form-control{height:30px;padding:2px 26px 3px 10px;font-size:13px}
# .portlet.light>.portlet-title>.inputs>.portlet-input>.form-control{height:30px;padding:3px 10px;font-size:13px}
# .portlet.light>.portlet-title>.pagination{padding:2px 0 13px}
# .portlet.light>.portlet-title>.tools{padding:10px 0 13px;margin-top:2px}
# .portlet.light>.portlet-title>.nav-tabs>li{margin:0;padding:0}
# .portlet.light>.portlet-title>.nav-tabs>li>a{margin:0;padding:12px 13px 13px;font-size:13px;color:#666}
# .portlet.light>.portlet-title>.nav-tabs>li.active>a,.portlet.light>.portlet-title>.nav-tabs>li:hover>a{margin:0;background:0 0;color:#333}
# .portlet.light.form-fit{padding:0}
# .portlet.light.form-fit>.portlet-title{padding:17px 20px 10px;margin-bottom:0}
# .portlet.light .portlet-body{padding-top:8px}
# .portlet.light.portlet-fullscreen>.portlet-body{padding:8px 0}
# .tab-pane>p:last-child{margin-bottom:0}
# .tabs-reversed>li{float:right;margin-right:0}
# .tabs-reversed>li>a{margin-right:0}
# .portlet-sortable:not(.portlet-fullscreen)>.portlet-title{cursor:move}
# .portlet-sortable-placeholder{border:2px dashed #eee;margin-bottom:25px}
# .portlet-sortable-empty{height:45px}
# body{position:relative}
# .page-header{margin:0}
# .fixed-header{position:fixed;top:0;left:20}
# .hor-menu .search-bg li:hover a{background:#dea908!important;color:#fff}
# #imp_fact li:last-child{list-style-type:none}
#      </style>
#      <style type="text/css">
#       .item{float:left;position:relative;line-height:1em;border-bottom:.094em solid #fff;border-right:.031em solid #fff;border-left:.031em solid #fff}
# .grid-sizer, .item{width:20%}
# @media screen and (max-width:1224px){
# .grid-sizer, .item{width:33.33%}
# }
# @media screen and (max-width:720px){
# .grid-sizer, .item{width:50%}
# }
# .overlay,.overlay .description{width:100%;left:0;position:absolute}
# @media screen and (max-width:480px){
# .grid-sizer, .item{width:100%}
# }
# .image{max-width:100%;display:block;margin:5px}
# .image:after{clear:both}
# .overlay{height:100%;background-color:rgba(0,0,0,.5);top:0;text-decoration:none;color:#fff!important;display:none}
# .overlay .title{text-align:center;font-size:20px}
# .overlay .description{bottom:0;background-color:rgba(0,0,0,.8);margin:0}
# .timeline_div,.timeline_resp{background:#36a6eb;border-radius:60px;color:#fff;height:100px;padding:20px;text-align:center;width:100px;font-size:12px}
# .overlay .description p{margin:20px}
# .item:hover .overlay{display:block}
# .timeline_div{left:0;position:absolute;top:-45px}
# .time-points li{text-align:center}
# #deadlines_responsive{display:none}
# @media (max-width:800px){
# #deadlines_responsive{display:block!important}
# .timeLine{display:none}
# }
# .btn-group>.dropdown-menu::after,.btn-group>.dropdown-menu::before,.col-srch-drop .dropdown>.dropdown-menu::after,.col-srch-drop .dropdown>.dropdown-menu::before,.dropdown-toggle>.dropdown-menu::after,.dropdown-toggle>.dropdown-menu::before{right:9px!important;left:auto}
# .affix{top:0}
# #detail_div .page-header{background-color:#fff!important}
#      </style>
#      <div class="header-bg page-header">
#       <div class="container">
#        <div class="row">
#         <label class="" id="return_to_main" style="cursor:pointer; position:absolute; top:80px;right:15px;">
#          <img src="/images/remove.png" title="close"/>
#         </label>
#         <div class="col-md-4">
#         </div>
#         <div class="col-md-4 text-center margin-top-10">
#          <div class="margin-bottom-10" style="height:190px;">
#           <img alt="" class="img-circle campus_logo" height="100" src="" width="100"/>
#           <h1 class="text-w campus_name" style="font-size:14px;">
#           </h1>
#           <label class="block font-grey-lite font-12" id="campus_addr">
#           </label>
#          </div>
#          <label class="scl-icns">
#           <a href="#" id="fb_link">
#            <img alt="facebook" src="/images/fb-circle.png"/>
#           </a>
#           <a href="#" id="twitter_link">
#            <img alt="twitter" src="/images/twit-circle.png"/>
#           </a>
#           <a href="#" id="youtube_link">
#            <img alt="Youtube" src="/images/youtube-circle.png"/>
#           </a>
#          </label>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="clear">
#      </div>
#      <div class="page-container">
#       <!-- BEGIN PAGE CONTENT -->
#       <div class="page-content">
#        <div class="container-fluid" style="margin-left:15px;">
#         <div>
#          <ul class="list-inline gallery-links text-center margin-top-10">
#           <li class="active" id="menu_overview" style="cursor:pointer;">
#            Overview
#           </li>
#           <li id="menu_tour" style="cursor:pointer;">
#           </li>
#           <li id="menu_vtour" style="cursor:pointer;">
#           </li>
#          </ul>
#         </div>
#         <div class="clearfix">
#         </div>
#         <div class="row margin-bottom-50" id="desc_divs">
#          <div class="col-sm-12 col-md-12 line-hgt" id="desc">
#          </div>
#          <div id="galary_list" style="display:none;">
#           <h5 class="bold font-grey-lite">
#            Gallery
#           </h5>
#           <div id="container_gallery">
#            <div class="grid-sizer">
#            </div>
#           </div>
#          </div>
#          <div id="show_iframe" style="display:none;">
#           <iframe height="768" id="youvisit_link" src="" width="99%">
#           </iframe>
#           <div id="visit_err">
#           </div>
#          </div>
#          <div class="clearfix">
#          </div>
#         </div>
#         <div class="alert alert-warning margin-top-30 text-center" id="partner_div" style="margin-bottom:40px;display:none;">
#          <h5 class="mt-0">
#           <strong>
#            Partnered University
#           </strong>
#          </h5>
#          <label class="block" style="font-weight:normal; color:#333;">
#           This university is actively interacting with students on Ubergrad.  If you are interested, The University officials will answer your questions. They can also look at your profile and evaluate your chances of Admission.
#          </label>
#          <label class="btn-group margin-top-5 margin-right-10 bookmark_univ_popup">
#           <a class="btn btn-default btn-icon " style="height:34px;">
#            <i class="fa fa-star" id="bk_icon">
#            </i>
#           </a>
#           <a class="btn btn-default btn-text " href="#" id="add_to_fav" style="width:170px;">
#            I am Interested
#           </a>
#          </label>
#          <button class="btn btn-green student_eval_submit" id="evaluate" type="button">
#           Request Profile Evaluation
#          </button>
#         </div>
#         <div class="row show_overview">
#          <div class="col-sm-3 col-md-3">
#           <ul class="comn-list list-group font-13 item-mb margin-top-10">
#            <li>
#             <div class="col-sm-2">
#              <img alt="Established Year" src="/images/establish-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Established Year:
#              </h5>
#              <label id="estd">
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li>
#             <div class="col-sm-2">
#              <img alt="University Type" src="/images/uni-type-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               University Type:
#              </h5>
#              <label id="c_type" style="text-transform:capitalize">
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li>
#             <div class="col-sm-2">
#              <img alt="University Setting" src="/images/location-pin-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               University Location:
#              </h5>
#              <label id="c_setting">
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li>
#             <div class="col-sm-2">
#              <img alt="Highest Degree Offered" src="/images/uni-type-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Highest Degree Offered:
#              </h5>
#              <label id="high_degree">
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li>
#             <div class="col-sm-2">
#              <img alt="Geographic Region" src="/images/chart-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Geographic Region:
#              </h5>
#              <label id="region">
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li>
#             <div class="col-sm-2">
#              <img alt="Calendar" src="/images/calen-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Admission Seasons:
#              </h5>
#              <label id="calender">
#               -N/A-
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li class="partner_li" style="display:none;">
#             <div class="col-sm-2">
#              <img alt="Calendar" src="/images/tution-fee-icn.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Tution Fee:
#              </h5>
#              <label id="p_tution_fee">
#               $500 Per Year
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#            <li class="partner_li" style="display:none;">
#             <div class="col-sm-2">
#              <img alt="Calendar" src="/images/application-fee.png"/>
#             </div>
#             <div class="col-sm-9">
#              <h5 class="bold font-grey-lite margin-bottom-5 mt-0">
#               Application Fee:
#              </h5>
#              <label id="p_app_fee">
#               $50
#              </label>
#             </div>
#             <div class="clearfix">
#             </div>
#            </li>
#           </ul>
#          </div>
#          <div class="col-sm-5 col-md-5">
#           <h5 class="bold font-grey-lite">
#            Why this University ?
#           </h5>
#           <div id="normal_box" style="display:none;">
#            <ul class="list-inline">
#             <li class="col-md-4">
#              <div class="box-sm box-pd box-red margin-bottom-10">
#               <span class="block font-xs text-op" id="enrol_stu" style="color:#c13232;">
#               </span>
#               <span class="block font-12" id="male_rate">
#               </span>
#               <span class="font-12" id="female_rate">
#               </span>
#               <span class="block font-12" id="int_stu">
#               </span>
#              </div>
#              <div class="box-sm box-pd box-green">
#               <span class="font-xs bold text-op" style="color:#0b8546;">
#                Acceptance Ratio
#               </span>
#               <span class="block margin-top-10" id="acpt_rate">
#               </span>
#              </div>
#             </li>
#             <li class="col-md-8">
#              <div class="box-md box-pd box-yellow">
#               <span class="font-xs bold text-op" style="color:#967c0d;">
#                Why this University ?
#               </span>
#               <ul class="block margin-top-10" id="imp_fact" style="list-style-type:disc;margin-left:-25px;">
#               </ul>
#              </div>
#             </li>
#            </ul>
#            <div class="clearfix">
#            </div>
#            <ul class="list-inline margin-top-20">
#             <li class="col-md-8">
#              <div class="box-md box-pd box-purple">
#               <span class="font-xs bold text-op" style="color:#6e43ab;">
#                Admission Requirements
#               </span>
#               <label class="block margin-top-10" id="requirements">
#               </label>
#              </div>
#             </li>
#             <li class="col-md-4">
#              <div class="box-sm box-pd box-acqa margin-bottom-10">
#               <span class="font-xs bold text-op" style="color:#1274ac;">
#                Scholarships &amp; Assistanships
#               </span>
#               <label class="block margin-top-10" id="c_scholarship">
#               </label>
#              </div>
#              <div class="box-sm box-pd box-orange">
#               <span class="font-xs bold text-op" style="color:#b8511f;">
#                College Fee (per Year)
#               </span>
#               <label class="block" id="c_clg_fee">
#               </label>
#               <span class="font-xs bold text-op" style="color:#b8511f;">
#                Application Fee
#               </span>
#               <label class="block" id="c_app_fee">
#               </label>
#              </div>
#             </li>
#            </ul>
#            <div class="clearfix">
#            </div>
#           </div>
#           <div class="partner-box-md box-pd box-purple" id="partner_box" style="display:none;">
#            <div class="scrollable-two nano has-scrollbar" style="height:450px !important;">
#             <div class="nano-content">
#              <ul class="block margin-top-10" id="partner_imp_fact" style="list-style-type:disc;margin-left:-25px;">
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="col-sm-4 col-md-4">
#           <h5 class="bold font-grey-lite">
#            Map
#           </h5>
#           <div class="lite-grey">
#            <div>
#             <div id="google_engine" style="height:140px;margin:0 auto;">
#             </div>
#             <ul class="list-inline margin-top-10 text-center">
#              <li>
#               <label id="map_name">
#               </label>
#              </li>
#             </ul>
#            </div>
#            <h5 class="bold font-grey-lite margin-top-20 margin-left-5">
#             Current Temperature
#            </h5>
#            <div class="weather-box">
#             <ul class="list-inline">
#              <li>
#               <label class="margin-top-30">
#                <a class="temps margin-right-10" href="javascript:;" id="f_temp">
#                 F°
#                </a>
#                |
#                <a class="active temps margin-left-10" href="javascript:;" id="c_temp">
#                 C°
#                </a>
#               </label>
#              </li>
#              <li class="pull-right">
#               <h2>
#                <img alt="" src="/images/sun-icn.png" style="margin-right:20px;"/>
#                <span class="margin-top-5" id="weather">
#                </span>
#               </h2>
#              </li>
#             </ul>
#             <div class="clearfix">
#             </div>
#            </div>
#            <h5 class="bold font-grey-lite margin-left-5" id="temp_heading">
#             Average Monthly Temperature
#            </h5>
#            <div class="p10" id="b_chart" style="margin-left: -40px;">
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="clearfix">
#         </div>
#        </div>
#        <div class="container-fluid show_overview">
#         <div class="row" id="design_tl">
#          <h3 class="bold font-16 font-grey-gallery margin-top-40" style="margin-left: 45px;">
#           Application Deadlines
#          </h3>
#          <div class="timeLine" style="border-bottom:2px solid #ccc;margin: 45px;">
#           <span class="font-blue-soft bold">
#            2015
#           </span>
#           <ul class="list-inline time-points">
#            <li class="col-sm-1">
#             <div id="Jan_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Jan
#            </li>
#            <li class="col-sm-1">
#             <div id="Feb_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Feb
#            </li>
#            <li class="col-sm-1">
#             <div id="Mar_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Mar
#            </li>
#            <li class="col-sm-1">
#             <div id="Apr_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Apr
#            </li>
#            <li class="col-sm-1">
#             <div id="May_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             May
#            </li>
#            <li class="col-sm-1">
#             <div id="Jun_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Jun
#            </li>
#            <li class="col-sm-1">
#             <div id="Jul_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Jul
#            </li>
#            <li class="col-sm-1">
#             <div id="Aug_tl">
#             </div>
#             <img alt="" src="/images/point.png"/>
#             <br/>
#             Aug
#            </li>
#            <li class="col-sm-1">
#             <div id="Sep_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Sep
#            </li>
#            <li class="col-sm-1">
#             <div id="Oct_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Oct
#            </li>
#            <li class="col-sm-1">
#             <div id="Nov_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Nov
#            </li>
#            <li class="col-sm-1">
#             <div id="Dec_tl">
#             </div>
#             <img src="/images/point.png"/>
#             <br/>
#             Dec
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="row" id="deadlines_responsive">
#         </div>
#        </div>
#        <div class="container-fluid " id="deadline_stat" style="display:none;">
#         <label class="pull-right">
#          <b style="color:#f16565">
#           Note:
#          </b>
#          Has rolling deadlines
#         </label>
#        </div>
#        <div class="text-center margin-top-40 margin-bottom-50 show_overview">
#         <ul class="list-inline program_click">
#          <li>
#           <button class="btn btn-circle blue-darken bold-6 btn-wd" id="match_btn" type="button">
#            Matching Programs
#           </button>
#          </li>
#          <li>
#           <button class="btn btn-circle btn-normal bold-6 btn-wd" id="rest_btn" type="button">
#            All Programs
#           </button>
#          </li>
#         </ul>
#        </div>
#        <div class="container">
#         <div class="show_overview p15" id="match_prgm_div" style="display:none;">
#         </div>
#         <div class="show_overview p15" id="rest_prgm_div" style="display:none;">
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="modal" id="gallery-view-box" style="display:none;">
#       <div class="modal-header">
#        <a data-dismiss="modal" href="javascript:;" style="float:right;">
#         <img src="/Content/images/icon-color-close.png"/>
#        </a>
#       </div>
#       <div>
#        <ul class="pic-view" style="z-index:2 !important;">
#         <li>
#          <a href="javascript:;" id="prev_img">
#          </a>
#         </li>
#         <li class="displayed">
#          <div id="img-view" style="display:none;">
#          </div>
#          <div id="video-view" style="display:none;">
#          </div>
#          <div style="clear:both;">
#          </div>
#         </li>
#         <li>
#          <a href="javascript:;" id="next_img">
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div style="clear:both;">
#       </div>
#       <div class="row">
#        <div class="bold font-md gal-bot-txt" id="g_txt" style="padding:0px ! important;">
#        </div>
#       </div>
#      </div>
#      <!-- /.modal -->
#      <div class="modal fade" id="Bookmark_PopUp">
#       <div class="modal-dialog" style="width:500px;">
#        <div class="modal-content">
#         <div class="modal-header" style="padding:0px">
#          <button class="close" data-dismiss="modal" type="button">
#           <span aria-hidden="true">
#            ×
#           </span>
#           <span class="sr-only">
#            Close
#           </span>
#          </button>
#         </div>
#         <div class="modal-body" style="padding:15px;">
#          <div class="UniversityDetails text-center">
#           <img alt="" id="show_univ_logo_popup" src="" width="100"/>
#           <h5 class="font-12 bold font-black" id="UniversityNamePopup">
#            UniversityName
#           </h5>
#           <label class="text-grey font-12">
#            <span class="margin-top-5" id="CityPopup">
#             City
# ...
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <input id="Redirecturl" type="hidden"/>
#   <input id="PageORPopup" type="hidden" value="1"/>
#   <input id="Captcharesponse" type="hidden" value=""/>
#   <input id="hdn_actiontab" type="hidden" value=""/>
#   <input id="hdn_profilepic" type="hidden" value=""/>
#   <input id="hdn_currentobj" objecttype="" type="hidden" value=""/>
#   <input id="HdnEmail" type="hidden"/>
#   <input id="OffsiteRedirecturl" name="ctl00$OffsiteRedirecturl" type="hidden"/>
#   <input id="hdnWebsiteURL" name="ctl00$hdnWebsiteURL" type="hidden" value="https://www.ubergrad.com"/>
#   <script async="" defer="" src="https://apis.google.com/js/client:platform.js?onload=render">
#   </script>
#   <script src="/PreloginHeaderScript?v=R_aa2Zy1PkJxydgujr-mUXB5mrHytUPuGgQLPPLUMEQ1">
#   </script>
#   <script src="/content/scripts/blockUI.js">
#   </script>
#   <script type="text/javascript">
#    function blinker() { $('.blinking').fadeOut(800); $('.blinking').fadeIn(800); }
#         setInterval(blinker, 1000);
#         var CurrentClickedObj;
#         $('[data-toggle="tooltip"]').tooltip();
#         $(document).delegate("#doitlater", "click", function () {
#             window.location.href = "/" + $("#Redirecturl").val();
#         });
#         $(document).delegate(".fb_login", "click", function () {
#             login();
#             schedule_login = $(".fb-login").attr("sch");
#             tutorial_login = $(".fb-login").attr("tt");
#         });
#         $(document).delegate(".g_login", "click", function () {
#             gapi.auth.signIn({
#                 'callback': signinCallback
#             });
#         });
#
#         function login() {
#             FB.getLoginStatus(function (a) {
#                 if (a.status === "connected") {
#                     console.log(a.authResponse.userID);
#                     create_session(a.authResponse.userID);
#                 } else {
#                     FB.login(function (response) {
#                         if (response.authResponse) {
#                             // connected
#                             access_token = response.authResponse.accessToken;
#                             fb_user_id = response.authResponse.userID;
#                             create_session(fb_user_id);
#                             console.log(access_token);
#                             console.log(fb_user_id);
#                         } else {
#                             // cancelled
#                         }
#                     }, { scope: 'email,publish_actions' })
#                 }
#             });
#         }
#
#         function create_session(fb_user_id) {
#             FB.api('/me', { fields: 'email,first_name,last_name,gender,name,location' }, function (response) {
#                 //console.log(response);
#                 var st = "", city = "", country = "", gender = "", fn = "", ln = "";
#                 fn = (response.first_name) ? response.first_name : "";
#                 ln = (response.last_name) ? response.last_name : "";
#                 gender = (response.gender) ? response.gender : "";
#                 city = (response.location) ? response.location.name : "";
#                 var tutorial = $('#tutorial').html();
#                 var PageorPopup = $("#PageORPopup").val();
#                 $.ajax(
#                         {
#                             url: '/StudentLogin.ashx',
#                             type: 'POST',
#                             dataType: 'JSON',
#                             beforeSend: function (xhr) { xhr.setRequestHeader('X-CSRF-Token', $('meta[name="csrf-token"]').attr('content')) },
#                             data: {
#                                 type: 6, facebook_user_id: response.id, facebook_name: response.name, facebook_email: response.email, tutorial: tutorial,
#                                 first_name: fn, last_name: ln, gender: gender, state: st, country: country, city: city
#                             },
#                             success: function (data) {
#                                 if (data.ret_msg == 'ok') {
#                                     if (PageorPopup == 0) {
#                                     $("#SignUpModal").modal("hide");
#                                     //if (res.profileStatus == 0) {
#                                     //        SignupAfterAction(res.profileStatus);
#                                     //       $("#WelcomeModal").modal("show");
#                                     //   } else {
#                                             window.location.reload();
#                                      //  }
#                                    }
#                                     if (PageorPopup == 1 ) {
#                                     //  window.location.href = "/welcome";
#                                     //} else if (res.profileStatus == 1) {
#                                         window.location.href = "/studenthome";
#                                     }
#                                   // $("#DegreeLevelModal").modal("show");
#                                   if ($("#OffsiteRedirecturl").val() != "") {
#                                        window.location.href = $("#OffsiteRedirecturl").val();
#                                    }
#                                   else {
#                                       // SignupAfterAction(data.profileStatus);
#                                       window.location.href = "/studenthome";
#                                   }
#
#                                 }
#                                 else if (data.ret_msg == 'exists') {
#                                     alert("email already exists");
#                                 }
#                             }
#                         }
#                         );
#             });
#         }
#         var access_token = "";
#         var fb_user_id = "";
#         $(document).ready(function () {
#             $("#registration").addClass("active");
#             $("#logIn").removeClass("active");
#             (function () {
#                 var e = document.createElement('script');
#                 e.src = '//connect.facebook.net/en_US/all.js';
#                 e.async = true;
#                 document.getElementById('fb-root').appendChild(e);
#             }());
#             window.fbAsyncInit = function () {
#
#                 FB.init({ appId: "170090126513098", status: true, cookie: true, xfbml: true, oauth: true });
#             };
#         });
#
#         //function render() {
#         //    $('.g_login').click(function () {
#         //        gapi.auth.signIn({
#         //            'callback': signinCallback
#         //        });
#         //    });
#         //}
#         function signinCallback(authResult) {
#             var PageorPopup = $("#PageORPopup").val();
#             if (authResult['status']['signed_in']) {
#                 console.log(authResult);
#                 if (authResult['status']['method'] == "PROMPT") {
#                     $.ajax({
#                         url: "/StudentLogin.ashx",
#                         type: "POST",
#                         async: false,
#                         data: { atoken: authResult.access_token, type: 7 },
#                         dataType: "json",
#                         success: function (a) {
#
#                             $.ajax({
#                                 url: "/StudentLogin.ashx",
#                                 type: "POST",
#                                 async: false,
#                                 data: { name: a.name, email: a.email, user_id: a.id, picture: a.picture, type: 8, otype: "google", fname: a.given_name, lname: a.family_name },
#                                 dataType: "json",
#                                 success: function (a) {
#                                     if (a.ret_msg == 'ok') {
#                                        // $("#DegreeLevelModal").modal("show");
#                                         if ($("#OffsiteRedirecturl").val() != "") {
#                                             window.location.href = $("#OffsiteRedirecturl").val();
#                                         }
#                                         else {
#                                             //SignupAfterAction(a.profileStatus);
#                                             window.location.href = "/studenthome";
#                                         }
#
#                                         if (PageorPopup == 0) {
#                                             $("#SignUpModal").modal("hide");
#                                             //if (res.profileStatus == 0) {
#                                             //    $("#WelcomeModal").modal("show");
#                                             //} else {
#                                                 window.location.reload();
#                                             //}
#                                         }
#                                         if (PageorPopup == 1) {
#                                         //    window.location.href = "/welcome";
#                                         //} else if (res.profileStatus == 1) {
#                                             window.location.href = "/studenthome";
#                                         }
#
#                                     }
#                                     else if (a.ret_msg == 'exists') {
#                                         alert("Already account exists with this Email Address !! Please use another account.");
#                                     }
#                                 },
#                                 error: function (a, err) { alert(err); }
#                             });
#
#
#                         },
#                         error: function (a, err) {
#                             alert(err);
#                         }
#                     });
#
#                 }
#             }
#         }
#         function ReplaceAllSpecChar(name) {
#             name = name.replace(/( |_|&|-|\/|'|"|,)+/gi, '-');
#             return name;
#         }
#
#
#         function GetUnivEncodedName(name) {
#             name = name.replace(/[^a-zA-Z0-9]+/gi, '-').replace(/(^-)|(-$)/g, "");
#             return name;
#         }
#         $(document).ready(function () {
#             $(document).on("click", ".headerscroll", function () {
#                 $("html, body").animate({ scrollTop: $("#headerScrollDiv").offset().top - 300 }, 1000);
#             });
#             $(document).on('click', '.show-reset-form', function () {
#                 $("#errorPassword").html('')
#                 $("#two_btn").hide();
#                 $("#txtUsermail").val('');
#                 $(".section-log-in").hide();
#                 $(".section-forgot-password").show();
#             });
#             $(document).on('click', '.show-login-form', function () {
#                 $(".section-log-in").show();
#                 $(".section-forgot-password").hide();
#
#             });
#             $('#txtSearchUniversityName').keypress(function (event) {
#                 if (event.keyCode == 13) {
#                     var searchUniversityKey = $('#txtSearchUniversityName').val();
#                     if (searchUniversityKey != '' || searchUniversityKey != 0) {
#                         window.location.href = $("#hdnWebsiteURL").val() + '/CommunityCollegeList.aspx?universityKey=' + searchUniversityKey;
#                     }
#                 }
#             });
#
#
#             var images = $(".img-circle");
#             images.on('load', function () {
#             }).on('error', function () { $(this).attr("src", "/newimages/add-universe.png") });
#
#         });
#   </script>
#   <script src="/content/scripts/jquery-ui-1.10.3.custom.min.js" type="text/javascript">
#   </script>
#   <script src="/Content/Plugins/nanoscroller/dist/javascripts/jquery.nanoscroller.js" type="text/javascript">
#   </script>
#   <script src="/Content/Scripts/bootstrap-multiselect.min.js" type="text/javascript">
#   </script>
#   <script src="/Content/scripts/jPaginator.js">
#   </script>
#   <script src="/Content/scripts/lodash.js">
#   </script>
#   <script src="/Content/Scripts/jquery.knob.js">
#   </script>
#   <script src="/Content/Scripts/SignupNew.js?V=1.2">
#   </script>
#   <script src="/Content/Scripts/StuLogin.js?V=1.2">
#   </script>
#   <script src="/Content/Scripts/Custom/emailMobileVerification.js?V=1.1">
#   </script>
#   <script src="/Content/Scripts/UrlSearch.js?V=1.2" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var refFlag = 0;
#         var websiteURL = $("#hdnWebsiteURL").val();
#         $("#closeLoginIcon").show();
#         $("#closeSignUpIcon").show();
#         $(".knob").knob();
#         $("#profile_complete_now").click(function () {
#             $("#SignUpModal").modal("show");
#             $("#RedirectionPage").val(websiteURL+"/my-profile");
#         });
#         $("#set_prefernces").click(function () {
#             $("#SignUpModal").modal("show");
#             $("#RedirectionPage").val(websiteURL + "/my-preferences");
#         });
#         DefultPageNames();
#         function DefultPageNames() {
#             var PageNames = '';
#             PageNames += '<ul>';
#             PageNames += '<li><a href="'+websiteURL+'">Home</a></li>';
#             PageNames += '<li><a href="' + websiteURL + '/universities">Universities</a></li>';
#             PageNames += '<li class="mle">Search</li>';
#             PageNames += '</ul>';
#             $("#PageNameIds").html(PageNames);
#         }
#   </script>
#   <script type="text/javascript">
#    //var verifyCallback = function (response) {
#         //    $("#Captcharesponse").val(response);
#         //};
#         //var LoadCallBack = function () {
#         //    grecaptcha.render('googlecaptcha', {
#         //        'sitekey': '6Le_BhcUAAAAAPl9y_eAFogi3SHgtA-XiMDxUM65',
#         //        'callback': verifyCallback
#         //    });
#         //}
#
#         function VerifyCaptcha() {
#             var boolFlag = false;
#             $.ajax({
#                 url: "/StudentLogin.ashx",
#                 type: "POST",
#                 async: false,
#                 data: { gresponse: $("#Captcharesponse").val(), type: 29 },
#                 dataType: "JSON",
#                 success: function (a) {
#                     //alert(a.success);
#                     boolFlag = a.success;
#                 },
#                 error: function (res, err) {
#                     console.log(err);
#                 }
#             });
#             return boolFlag;
#         }
#         $(document).on("click", "#StuBachelor", function () {
#             var studentLevel = 'Bachelors';
#             submitstudentlevel(studentLevel);
#         });
#         $(document).on("click", "#StuMaster", function () {
#             var studentLevel = 'Masters';
#             submitstudentlevel(studentLevel);
#         });
#         function submitstudentlevel(studentLevel) {
#             $.ajax({
#                 url: "/StudentLogin.ashx",
#                 type: "POST",
#                 async: false,
#                 data: { Degreelevel: studentLevel, type: 31 },
#                 dataType: "JSON",
#                 success: function (a) {
#                     if (a.retMsg == 'ok') {
#                         $("#DegreeLevelModal").modal("hide");
#                         if ($("#OffsiteRedirecturl").val() != "") {
#                             window.location.href = $("#OffsiteRedirecturl").val();
#                         }
#                         else {
#                             if (studentLevel == "Bachelors") {
#                                 window.location.href = "Bachelors/Home";
#                             }
#                             else {
#                                 window.location.href = "/studenthome";
#                             }
#                             //SignupAfterAction(a.Level, a.profileStatus);
#                         }
#
#                     }
#                 },
#                 error: function (res, err) {
#                     console.log(err);
#                 }
#             });
#         }
#   </script>
#  </body>
# </html>

# %% [markdown]
# After trying normal methods, I tried using Selenium with a webdriver to get data. But was able to open the website, still faced login issues. I had spent a lot of time trying to fix this, but was unable to do so. So, I went back to trying to get data from a normal html website.

# %%
from selenium import webdriver
import os
path_to_chromedriver = '/Applications/chromedriver'
browser = webdriver.Chrome(path_to_chromedriver)
url = 'https://www.ubergrad.com/universities/usa/mba-in-management-information-systems/top-universities'
browser.get(url)

# %% [markdown]
# Needed median Pay information of people who work in MSIS related careers. This would give a view of how beneficial it would be to study a MSIS degree.

# %%
urlPay = 'https://www.payscale.com/research/US/Degree=Master_of_Science_(MS)%2C_Management_Information_Systems_(MIS)/Salary'
rPay = requests.get(urlPay)
rPay.content
soupPay = BeautifulSoup(rPay.content, "lxml")
#print(soup.prettify())

# %%
for dataPay in soupPay.find_all("td"):
    print(dataPay.text)
# Out:
# Project Manager, Information Technology (IT)
# $81,591
# Software Engineer
# $86,000
# Network Security Engineer
# $119,792
# Software Developer
# $81,472
# Senior Business Analyst
# $105,000
# Senior Project Manager, IT
# $103,917
# Information Technology (IT) Manager
# $132,250
#
# Project Manager, Information Technology (IT)3 profiles
# $81,591
# $0$82K
#
# Software Engineer3 profiles
# $86,000
# $0$86K
#
# Network Security Engineer2 profiles
# $119,792
# $0$120K
#
# Get a personalized salary report!Location:Years in Field/Career:Years in Field/Career:United States (change)
#
# Software Developer2 profiles
# $81,472
# $0$81K
#
# Senior Business Analyst2 profiles
# $105,000
# $0$105K
#
# Senior Project Manager, IT2 profiles
# $103,917
# $0$104K
#
# Information Technology (IT) Manager2 profiles
# $132,250
# $0$132K
#
# See all employers for Master of Science (MS), Management Information Systems (MIS) »
# See all employers for Master of Science (MS), Management Information Systems (MIS) »
# Currency: USDUpdated: 16 Sep 2017Individuals Reporting: 50View Table
#
#
#                         Female
#                         27 %
#
#
#
#
#
#
#
#
#
#
#
#                         Male
#                         73 %
#
#
#
#
#
#
#
#
#
#
#                         Salary
#                         $56,673 - $123,908
#
#
#                         Salary
#                         $60,678 - $122,301
#
#
#
#                     Satisfied
#
#                     Rated 3 out of 5based on 5 votes.
#
# Less than 1 year4%1-4 years14%5-9 years29%10-19 years41%20 years or more13%
#
#
# Less than 1 year
# 4%
#
# 1-4 years
# 14%
#
# 5-9 years
# 29%
#
# 10-19 years
# 41%
#
# 20 years or more
# 13%
#
#
#
#
#
#
# Seriously, Do Not Lie About Your Salary as a Negotiation Tactic
#                             Pixabay
# While the best salary negotiation advice is to base your ask on the job, not on your salary history, many hiring managers won’t play alo...
#
#
#
# PayScale’s VIP Blog Roundup: How to Take a Stand Without Making an Enemy
#                             Rawpixel/Unsplash
# These are polarized times. Online, in your personal life and at work, it can be very difficult to take a stand without contributing ...
#
#
#
# Hate Your Job? Here’s How to Find a Career You’re Passionate About
#                             Volkan Olmez/Unsplash
# When your job is wearing you down and you can’t quite seem to find your pep, you sometimes daydream about doing something ...

# %% [markdown]
# Saving the Data to arrays and later form DataFrames.

# %%
arrJobType = []
arrJobSalary = []
iCount = 0
for dataPay in soupPay.find_all("td"):
    if(iCount < 14):
        iCount = iCount+1
        if(iCount%2 != 0):
            arrJobType.append(dataPay.text)
        else:
            arrJobSalary.append(dataPay.text)

print(arrJobSalary)
print(arrJobType)
# Out:
# ['$81,591', '$86,000', '$119,792', '$81,472', '$105,000', '$103,917', '$132,250']
# ['Project Manager, Information Technology (IT)', 'Software Engineer', 'Network Security Engineer', 'Software Developer', 'Senior Business Analyst', 'Senior Project Manager, IT', 'Information Technology (IT) Manager']

# %% [markdown]
# Get Data that shows the % job growth for the possible career tracks

# %%
urlPay10 = 'http://study.com/articles/Salary_and_Job_Information_for_MIS_Majors.html'
rPay10 = requests.get(urlPay10)
rPay10.content
soupPay10 = BeautifulSoup(rPay10.content, "lxml")
print(soupPay10.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Salary and Job Information for MIS Majors
#   </title>
#   <meta content="index,follow,noodp" name="robots"/>
#   <meta content="article" property="og:type"/>
#   <meta content="http://study.com/images/StudyCom-og-Facebook-Logo.jpg" property="og:image"/>
#   <meta content="image/jpg" property="og:image:type"/>
#   <meta content="Salary and Job Information for MIS Majors" property="og:title"/>
#   <meta content="Students who searched for Salary and Job Information for MIS Majors  found the articles, information, and resources on this page  helpful." property="og:description"/>
#   <meta content="http://study.com/articles/Salary_and_Job_Information_for_MIS_Majors.html" property="og:url"/>
#   <meta content="Study.com" property="og:site_name"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="" name="author"/>
#   <!-- CSS -->
#   <link href="//fonts.googleapis.com/css?family=Open+Sans:400italic,400,600,300,700|Droid+Serif:400,700,400italic" rel="stylesheet" type="text/css"/>
#   <link href="/css/icons/icomoon-08d57fcab5.css" rel="stylesheet"/>
#   <link href="/css/pages/global-db7728c894.css" rel="stylesheet"/>
#   <link href="/css/notification/humane-3.2.0-themes/remilon-custom-6af209b03a.css" rel="stylesheet"/>
#   <link href="/favicon.ico?v=2" rel="shortcut icon"/>
#   <meta content="f5faf6ebbc1c8a30ad607e451abf8a4b" name="requestGuid"/>
#   <meta content="" name="searchGuid"/>
#   <meta content="" name="impressionGuid"/>
#   <meta content="Salary and Job Information for MIS Majors" name="keywords"/>
#   <meta content="Students who searched for Salary and Job Information for MIS Majors  found the articles, information, and resources on this page  helpful." name="description"/>
#   <link href="/rss/article_directory/Glossary_of_Career_Education_Programs.html.xml" rel="alternate" title="Glossary of Career Education Programs" type="application/rss+xml"/>
#   <link href="/css/oiewinner-5ca0246758.css" rel="stylesheet"/>
#   <link href="/css/pages/article-8f58b0a5a4.css" rel="stylesheet"/>
#  </head>
#  <body id="articleMain">
#   <content itemscope="" itemtype="http://schema.org/Organization">
#    <meta content="Study.com" itemprop="name"/>
#    <meta content="Take online courses that are fun and engaging. Pass exams to earn real college credit. Research schools and degrees to further your education." itemprop="description"/>
#    <meta content="http://study.com/images/StudyCom-og-Facebook-Logo.jpg" itemprop="image"/>
#   </content>
#   <div class="study-nav">
#    <div class="study-nav__top ">
#     <div class="container-fluid">
#      <div class="study-nav__top__actions">
#       <a class="for-link" data-cname="teacher_product" href="/academy/plans/teacher.html" test-id="teacher_product">
#        <em>
#         for
#        </em>
#        Teachers
#       </a>
#       <a class="for-link" data-cname="institution_product" href="/academy/plans/teacher-group.html" test-id="institution_product">
#        <em>
#         for
#        </em>
#        Schools
#       </a>
#       <a class="for-link" data-cname="corporate_product" href="/academy/plans/corporate.html" test-id="corporate_product">
#        <em>
#         for
#        </em>
#        Companies
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="collapseSearch xs-search">
#     <form action="/search/quicksearch.html" method="POST">
#      <div class="input-group">
#       <input class="form-control" name="q" placeholder="Search Degrees, Careers, or Schools" type="text"/>
#       <button class="input-group-addon form-control" id="topSearchRun">
#        <span class="icon icon-search" data-cname="top_search_icon" test-id="top_search_icon">
#        </span>
#       </button>
#      </div>
#     </form>
#    </div>
#    <div class="study-nav__main">
#     <div class="container-fluid">
#      <div class="study-nav__logo">
#       <a data-cname="logo" href="/" test-id="logo">
#        <img alt="Study.com" src="/images/reDesign/global/logo.png"/>
#       </a>
#      </div>
#      <div class="study-nav__main-actions">
#       <div>
#        <a class="text-link" data-cname="login" href="/academy/login.html" test-id="login">
#         Login
#        </a>
#       </div>
#       <div>
#        <a class="hidden-xs btn btn-primary" data-cname="sign_up" href="/academy/plans.html" test-id="sign_up">
#         Sign Up
#        </a>
#       </div>
#       <button aria-controls="navsContainer" aria-expanded="false" class="visible-xs btn btn-primary" data-cname="mobile_user_nav" data-target="#navsContainer" data-toggle="collapse" test-id="mobile_user_nav">
#        Menu
#       </button>
#       <div class="searchTrigger dropdown" id="topSearchOpen">
#        <span class="icon icon-search" data-cname="top_search_icon" id="searchToggleTablet" test-id="top_search_icon">
#        </span>
#       </div>
#       <form action="/search/quicksearch.html" class="search-form" data-cname="text_search" id="searchBarDesktop" method="POST" test-id="text_search">
#        <div class="input-group">
#         <input class="form-control" name="q" placeholder="Search Degrees, Careers, or Schools" type="text"/>
#         <button class="input-group-addon form-control">
#          <span class="icon icon-search" data-cname="top_search_icon" test-id="top_search_icon">
#          </span>
#         </button>
#        </div>
#       </form>
#      </div>
#      <div class="study-nav__navs-container collapse" id="navsContainer">
#       <div class="study-nav__mobile-actions">
#        <a class="for-link" data-cname="teacher_product" href="/academy/plans/teacher.html" test-id="teacher_product">
#         <em>
#          for
#         </em>
#         Teachers
#        </a>
#        <a class="for-link" data-cname="institution_product" href="/academy/plans/teacher-group.html" test-id="institution_product">
#         <em>
#          for
#         </em>
#         Schools
#        </a>
#        <a class="for-link" data-cname="corporate_product" href="/academy/plans/corporate.html" test-id="corporate_product">
#         <em>
#          for
#         </em>
#         Companies
#        </a>
#       </div>
#       <ul class="study-nav__site-nav">
#        <li class="dropdown no-sub-nav " data-cname="top_menu" test-id="top_menu">
#         <a data-cname="plans" href="/academy/plans.html">
#          Plans
#         </a>
#        </li>
#        <li data-cname="top_menu" test-id="top_menu">
#         <a class="hidden-xs" data-cname="courses" href="/academy/course/index.html" test-id="courses">
#          Courses
#         </a>
#         <a aria-controls="navCourses" aria-expanded="false" class="visible-xs collapsed" data-target="#navCourses" data-toggle="collapse">
#          Courses
#         </a>
#         <div class="study-nav__sub-nav collapse" id="navCourses">
#          <div class="col-sm-6 study-nav__sub-nav__border-right">
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="coursesBySubject" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#coursesBySubject" data-toggle="collapse">
#             Find Courses by Subject
#            </a>
#            <ul class="collapse" data-cname="course_subject" id="coursesBySubject" test-id="course_subject">
#             <li>
#              <a href="/academy/subj/science.html">
#               Science
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/math.html">
#               Math
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/business.html">
#               Business
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/psychology.html">
#               Psychology
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/history.html">
#               History
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/english.html">
#               English
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/social-science.html">
#               Social Science
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/humanities.html">
#               Humanities
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/foreign-language.html">
#               Spanish
#              </a>
#             </li>
#             <li>
#              <a href="/academy/goal/test-prep/act-and-sat-prep.html">
#               ACT &amp; SAT Test Prep
#              </a>
#             </li>
#             <li>
#              <a href="/academy/goal/professional-licensure/teacher-certification.html">
#               Teacher Certification
#              </a>
#             </li>
#             <li>
#              <a href="/academy/goal/professional-licensure.html">
#               Professional Development
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="col-sm-6">
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="coursesByLevel" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#coursesByLevel" data-toggle="collapse">
#             By Education Level
#            </a>
#            <ul class="collapse" data-cname="course_education_level" id="coursesByLevel" test-id="course_education_level">
#             <li>
#              <a href="/academy/level/college.html">
#               College
#              </a>
#             </li>
#             <li>
#              <a href="/academy/level/high-school.html">
#               High School
#              </a>
#             </li>
#             <li>
#              <a href="/academy/level/middle-school.html">
#               Middle School
#              </a>
#             </li>
#            </ul>
#            <hr/>
#           </div>
#          </div>
#          <div class="study-nav__cta-text">
#           <div class="hidden-xs">
#            <em>
#             Explore over
#            </em>
#            <strong>
#             3,700
#            </strong>
#            <small>
#             video courses
#            </small>
#           </div>
#           <a class="btn btn-primary" data-cname="browse_all_courses" href="/academy/course/index.html" test-id="browse_all_courses">
#            Browse All Courses
#            <span class="icon-arrow-right">
#            </span>
#           </a>
#          </div>
#         </div>
#        </li>
#        <li data-cname="top_menu" test-id="top_menu">
#         <a class="dropdown-toggle hidden-xs" data-cname="credit" href="/academy/college-accelerator-hub/how-to-transfer-college-credit-online.html" test-id="credit">
#          Credit
#         </a>
#         <a aria-controls="navCredit" aria-expanded="false" class="visible-xs collapsed" data-target="#navCredit" data-toggle="collapse">
#          Credit
#         </a>
#         <div class="study-nav__sub-nav collapse" id="navCredit">
#          <div class="study-nav__sub-nav__section">
#           <a class="hidden-xs study-nav__sub-nav__section__header">
#            Credit Options
#           </a>
#           <ul data-cname="earn_credit" test-id="earn_credit">
#            <li>
#             <a data-cname="earn_credit_online_college_credit" href="/academy/goal/transferable-credit/online-college-credit.html" test-id="earn_credit_online_college_credit">
#              Online College Credit
#             </a>
#            </li>
#            <li>
#             <a data-cname="earn_credit_high_school" href="/academy/level/high-school.html" test-id="earn_credit_high_school">
#              High School &amp; GED
#             </a>
#            </li>
#            <li>
#             <a data-cname="earn_credit_certificates" href="/academy/goal/certificates/certificates-of-completion.html" test-id="earn_credit_certificates">
#              Certificates of Completion
#             </a>
#            </li>
#            <li>
#             <a data-cname="earn_credit_how_it_works" href="/academy/college-accelerator-hub/how-to-transfer-college-credit-online.html" test-id="earn_credit_how_it_works">
#              How it Works
#             </a>
#            </li>
#           </ul>
#          </div>
#          <hr/>
#          <div class="study-nav__cta-text">
#           <div class="hidden-xs">
#            Earn Transferable Credit &amp; Get your Degree
#            <em>
#             fast
#            </em>
#           </div>
#           <a class="btn btn-primary" data-cname="credit_learn_more" href="/academy/college-accelerator-hub/how-to-transfer-college-credit-online.html" test-id="credit_learn_more">
#            Learn more
#            <span class="icon-arrow-right">
#            </span>
#           </a>
#          </div>
#         </div>
#        </li>
#        <li data-cname="top_menu" test-id="top_menu">
#         <a class="hidden-xs" href="/directory/category/index.html">
#          Degrees
#         </a>
#         <a aria-controls="navDegrees" aria-expanded="false" class="visible-xs collapsed" data-target="#navDegrees" data-toggle="collapse">
#          Degrees
#         </a>
#         <div class="study-nav__sub-nav collapse" id="navDegrees">
#          <div class="col-sm-8 study-nav__sub-nav__border-right">
#           <div class="study-nav__sub-nav__section">
#            <p class="hidden-xs header study-nav__sub-nav__section__header">
#             Find Degrees by Subject
#            </p>
#            <a class="study-nav__sub-nav__section__header visible-xs" data-target="#degreeCollapsible" data-toggle="collapse">
#             Find Degrees by Subject
#            </a>
#            <div class="collapse" id="degreeCollapsible">
#             <div class="researchBreadcrumb researchBreadcrumb-sub">
#              <ul class="breadcrumbLinks">
#               <li class="crumb sans-chevron">
#                <a class="override-nav" href="/directory/category/index.html">
#                 Subject Categories
#                </a>
#               </li>
#               <li class="divider sans-chevron">
#                <span class="override-nav">
#                 /
#                </span>
#               </li>
#               <li class="crumb sans-chevron">
#                <a class="override-nav" href="/directory/category/Business.html">
#                 Business
#                </a>
#               </li>
#               <li class="divider sans-chevron">
#                <span class="override-nav">
#                 /
#                </span>
#               </li>
#               <li class="crumb sans-chevron">
#                <a class="override-nav" href="/directory/category/Business/Information_System_Management.html">
#                 Information System Management
#                </a>
#               </li>
#              </ul>
#             </div>
#             <hr/>
#             <ul class="navGroup12 no-bullet-list" data-cname="degree_subject" test-id="degree_subject">
#              <li>
#               <ul class="twoCols clear">
#                <li class="col">
#                 <ul>
#                  <li>
#                   <a href="/directory/category/Business.html">
#                    Business
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Information_System_Management/Information_Resources_Mgmt.html">
#                    Information Resources Mgmt
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Information_System_Management/Knowledge_Management.html">
#                    Knowledge Management
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Accounting_and_Bookkeeping.html">
#                    Accounting and Bookkeeping
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Business_Economics.html">
#                    Business Economics
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Business_Finance.html">
#                    Business Finance
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Business_Management_and_Operations.html">
#                    Business Management and Operations
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Business_Marketing.html">
#                    Business Marketing
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#                <li class="col">
#                 <ul>
#                  <li>
#                   <a href="/directory/category/Business/Business_Support_and_Administrative_Services.html">
#                    Business Support and Administrative Services
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Entrepreneurship_and_Small_Business_Development.html">
#                    Entrepreneurship and Small Business Development
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Hospitality_Management.html">
#                    Hospitality Management
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Human_Resource_Management.html">
#                    Human Resource Management
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/International_Business.html">
#                    International Business
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Sales_and_Merchandising.html">
#                    Sales and Merchandising
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Business/Specialized_Sales.html">
#                    Specialized Sales
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="col-sm-4">
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="degreesByLevel" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#degressByLevel" data-toggle="collapse">
#             By Level
#            </a>
#            <ul class="no-bullet-list collapse" data-cname="degree_level" id="degressByLevel" test-id="degree_level">
#             <li>
#              <a href="/pages/Online_High_Schools.html">
#               High School Diploma
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Glossary_of_Associate%27s_Degree_Programs.html">
#               Associates Degrees
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Glossary_of_Bachelor%27s_Degree_Programs.html">
#               Bachelor Degrees
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Glossary_of_Master%27s_Degree_Programs.html">
#               Master Degrees
#              </a>
#             </li>
#             <li>
#              <a href="/online_degree.html">
#               Online Degrees
#              </a>
#             </li>
#            </ul>
#            <hr/>
#           </div>
#          </div>
#          <div class="study-nav__cta-text">
#           <div class="hidden-xs">
#            Find a degree that
#            <em>
#             fits your goals
#            </em>
#           </div>
#           <a class="btn btn-primary" data-cname="search_degrees" href="/directory/category/index.html" test-id="search_degrees">
#            Search degrees
#            <span class="icon-arrow-right">
#            </span>
#           </a>
#          </div>
#         </div>
#        </li>
#        <li data-cname="top_menu" test-id="top_menu">
#         <a class="hidden-xs" data-cname="schools" href="/article_directory/College_and_University_Overviews_(by_State).html" test-id="schools">
#          Schools
#         </a>
#         <a aria-controls="navSchools" aria-expanded="false" class="visible-xs collapsed" data-target="#navSchools" data-toggle="collapse">
#          Schools
#         </a>
#         <div class="study-nav__sub-nav collapse" id="navSchools">
#          <div class="col-sm-6 study-nav__sub-nav__border-right">
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="schoolsByDegree" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#schoolsByDegree" data-toggle="collapse">
#             Browse Schools by Degree Level
#            </a>
#            <ul class="no-bullet-list collapse" data-cname="school_education_level" id="schoolsByDegree" test-id="school_education_level">
#             <li>
#              <a href="/directory/degree_type/Graduate.html">
#               Graduate Degrees
#              </a>
#             </li>
#             <li>
#              <a href="/directory/degree_type/High_School_Diploma.html">
#               High School Diplomas
#              </a>
#             </li>
#             <li>
#              <a href="/directory/degree_type/Non-Degree.html">
#               Certificate Programs
#              </a>
#             </li>
#             <li>
#              <a href="/directory/degree_type/Post_Degree_Certificate.html">
#               Post Degree Certificates
#              </a>
#             </li>
#             <li>
#              <a href="/directory/degree_type/Undergraduate.html">
#               Undergraduate Degrees
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="allSchools" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#allSchools" data-toggle="collapse">
#             Browse Schools
#            </a>
#            <ul class="no-bullet-list collapse" data-cname="browse_schools" id="allSchools" test-id="browse_schools">
#             <li>
#              <a href="/article_directory/College_and_University_Overviews_(by_State).html">
#               Public Schools by State
#              </a>
#             </li>
#             <li>
#              <a href="/pages/Top_College_and_University_Video_Reviews.html">
#               University Video Reviews
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="col-sm-6">
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="careerCenter" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#careerCenter" data-toggle="collapse">
#             Career Counseling &amp; Job Center
#            </a>
#            <ul class="no-bullet-list collapse" data-cname="career_counseling" id="careerCenter" test-id="career_counseling">
#             <li>
#              <a href="/video_library/Job_Interviewing_Videos.html">
#               Job Interviewing Tip Videos
#              </a>
#             </li>
#             <li>
#              <a href="/video_library/Job_Networking_Videos.html">
#               Job Networking Videos
#              </a>
#             </li>
#             <li>
#              <a href="/video_library/Resume_Videos.html">
#               Résumé How To Videos
#              </a>
#             </li>
#             <li>
#              <a href="/articles/Finding_the_Right_Job_Searching_Resources_for_You.html">
#               Job Search Tips
#              </a>
#             </li>
#             <li>
#              <a href="/video_library/index.html">
#               Career Videos
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="careerResearch" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#careerResearch" data-toggle="collapse">
#             Career Research
#            </a>
#            <ul class="no-bullet-list collapse" data-cname="career_research" id="careerResearch" test-id="career_research">
#             <li>
#              <a href="/video_library/Researching_Careers_Videos.html">
#               Researching Careers Videos
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Glossary_of_Career_Education_Programs.html">
#               Glossary of Careers
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Articles_about_Careers.html">
#               Career Info by Degree
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Articles_about_Career_Planning.html">
#               Job Outlook by Region
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/index.html">
#               Degree &amp; Career Research Articles
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="visible-xs no-sub-nav">
#         <a class="supportEmailTrigger" data-cname="contact_support" href="/contact/index.html" test-id="contact_support">
#          Contact Support
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--[if lte IE 9]>
#     <script src="//oss.maxcdn.com/libs/respond.js/1.4.2/respond.matchmedia.addListener.min.js" defer></script>
# <![endif]-->
#   <!--[if lt IE 9]>
#     <script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js" defer></script>
#     <script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js" defer></script>
#     <script src='/js/polyfill-ddf04d1d4b.js' defer></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/json3/3.3.2/json3.min.js"></script>
#     <script src='/js/courseProgress/excanvas-c1bb7af6a3.js' class="certificate" defer></script>
# <![endif]-->
#   <!--[if gte IE 6]>
#     <link rel="stylesheet" href='/css/ieSpecific-632226d036.css'>
# <![endif]-->
#   <noscript>
#    <img alt="" height="1" src="/timages/noscript.gif" width="1"/>
#   </noscript>
#   <script type="text/javascript">
#    (function() {
# 		"use strict";
# 		window.globalUtils = {
# 			logLimit : 100,
# 			getRequestGuid: function() {
# 				var requestGuidElement = document.querySelector("meta[name=requestGuid]");
# 				var requestGuid;
# 				if (typeof requestGuidElement === 'undefined' || !requestGuidElement) {
# 					requestGuidElement = document.getElementById("requestGuid");
# 					requestGuid = requestGuidElement ? requestGuidElement.value : "";
# 				}
# 				else {
# 					requestGuid = requestGuidElement.getAttribute("content");
# 				}
# 				return requestGuid;
# 			},
# 			generateGuid: function() {
# 				Date.now = Date.now || function() {
# 					 return +new Date();
# 				 };
# 				var d = Date.now();
# 				return 'xxxxxxxxxxxx4xxxyxxxxxxxxxxxxxxx'.replace(/[xy]/g, function(c) {
# 					var r = (d + Math.random() * 16) % 16 | 0;
# 					d = Math.floor(d / 16);
# 					return (c === 'x' ? r : (r & 0x7 | 0x8)).toString(16);
# 				});
# 			},
# 			//these are used in the script tags below
# 			requireConfigError: function(event) {
# 				var exception = {};
# 				exception.message = "error loading require config file";
# 				exception.sourceJavascript = '/js/requireConfig-42da1080e8.js';
# 				exception.lineNumber = 0 + ':' + 0;
# 				globalUtils.logError(exception, "fileload");
# 			},
# 			requireError: function(event) {
# 				var exception = {};
# 				exception.message = "require.js failed to load";
# 				exception.sourceJavascript = "//cdnjs.cloudflare.com/ajax/libs/require.js/2.3.2/require.min.js";
# 				exception.lineNumber = 0 + ':' + 0;
# 				window.globalUtils.logError(exception, "require");
# 			},
# 			onError: function(message, url, lineNumber) {
# 				var exception = {};
# 				exception.message = message;
# 				exception.sourceJavascript = url;
# 				exception.lineNumber = lineNumber;
# 				exception.type = 'preEventTracking';
# 				window.globalUtils.logError(exception, "javascriptError")
# 			},
# 			logError: function(exception, type) {
# 				var loggableEvent = {};
# 				try {
# 					var urlCapture = /\((.+?):(\d+):(\d+)/g;
# 					var matchUrl = urlCapture.exec(exception.stack);
# 					if (matchUrl && matchUrl.length == 4) {
# 						var url = matchUrl[1];
# 						var line = matchUrl[2];
# 						var col = matchUrl[3];
# 						loggableEvent.sourceJavascript = url;
# 						loggableEvent.lineNumber = line + ':' + col;
# 					}
# 				}
# 				catch (e) {
# 					loggableEvent.sourceJavascript = exception.sourceJavascript;
# 					loggableEvent.lineNumber = exception.lineNumber;
# 				}
#
# 				function truncateLog(text) {
# 					return (text && text.length > 4000) ? text.substring(0, 4000) + "....[truncated]" : text;
# 				}
#
# 				loggableEvent.eventType = "javascriptError";
# 				loggableEvent.message = truncateLog(exception.message);
# 				loggableEvent.url = window.location.href;
# 				loggableEvent.name = exception.name;
# 				loggableEvent.stacktrace = truncateLog(exception.stack);
# 				loggableEvent.javascriptUUID = window.globalUtils.generateGuid();
# 				loggableEvent.pageRequestGuid = window.globalUtils.getRequestGuid();
# 				loggableEvent.type = type;
# 				loggableEvent.javascriptTimestamp = new Date().getTime();
# 				if(window.globalUtils.logLimit > 0){
# 					window.globalUtils.logLimit--;
# 					var request = new XMLHttpRequest();
# 					request.open("POST", "/eventLogger/eventLog.ajax");
# 					request.setRequestHeader("Content-Type", "application/json");
# 					request.send(JSON.stringify([loggableEvent]));
# 				}
#
# 			}
# 		};
# 		window.onerror = window.globalUtils.onError;
# 	})()
#   </script>
#   <script crossorigin="anonymous" defer="" onerror="window.globalUtils.requireError(event)" src="//cdnjs.cloudflare.com/ajax/libs/require.js/2.3.2/require.min.js">
#   </script>
#   <script data-remilon-env="prod-aws" defer="" onerror="window.globalUtils.requireConfigError(event)" src="/js/requireConfig-42da1080e8.js">
#   </script>
#   <script defer="" src="/js/trcking/tracking-55934fc313.js">
#   </script>
#   <script defer="" src="/js/trcking/eventTrackingInit-4ae9586985.js">
#   </script>
#   <script defer="" src="/js/redesign/hotjarTriggers-83d3a0ce1e.js">
#   </script>
#   <div class="main-container container-fluid" id="mainContainer">
#    <div class="wrapper" id="mainBody">
#     <div class="contentWithSidebar">
#      <div class="researchBreadcrumb" data-breadcrumb="" data-cname="breadcrumbs" test-id="breadcrumbs">
#       <div id="rss">
#        <a href="/rss/article_directory/Glossary_of_Career_Education_Programs.html.xml">
#         <img alt="Glossary of Career Education Programs RSS feed subscription" class="rss-icon" data-cname="rss-icon" src="/images/rss.gif" test-id="rss-icon" title="Glossary of Career Education Programs RSS feed subscription"/>
#        </a>
#       </div>
#       <ul class="breadcrumbLinks">
#        <li>
#         <a href="/article_directory/Glossary_of_Career_Education_Programs.html">
#          Glossary of Career Education Programs
#         </a>
#        </li>
#        <li class="divider">
#         /
#        </li>
#        <li>
#         <a href="/article_directory/q_p/page/Business/q_p/Glossary_of_Career_Education_Programs.html">
#          Business
#         </a>
#        </li>
#        <li class="divider">
#         /
#        </li>
#        <li>
#         Salary and Job Information for MIS...
#        </li>
#       </ul>
#      </div>
#      <div class="articleContent" id="mainArticle">
#       <div class="desktopArticleHeader">
#        <h1 class="articleTitle">
#         Salary and Job Information for MIS Majors
#        </h1>
#        <p class="date">
#        </p>
#        <p class="wikiDescription">
#         Management information systems majors typically study management, finance, marketing and economics as well as information systems development and design. Find out about the requirements for MIS majors, and learn about career options, job growth and salary info for MIS graduates.
#        </p>
#        <div class="articleCTA hidden-xs" data-cname="top_show_me_schools" data-target="#qualifierOverlay" data-toggle="modal" test-id="top_show_me_schools">
#         <span class="btn btn-cta cta-gold showMeSchools" data-cname="top_show_me_schools_button" id="dropDownSearchButton" test-id="top_show_me_schools_button">
#          Show Me Schools
#         </span>
#         <p class="articleCtaTag" data-cname="top_show_me_schools_link" id="ctaToolTip" test-id="top_show_me_schools_link">
#          <a>
#           View 10 Popular Schools
#           <span class="raquo">
#            »
#           </span>
#          </a>
#         </p>
#        </div>
#       </div>
#       <div class="articleContentContainer displayBlock visible-xs mobileArticleHeader" data-cname="top_show_me_schools_mobile" test-id="top_show_me_schools_mobile">
#        <div class="mobile-view-schools text-center" data-cname="top_show_me_schools_mobile" data-target="#qualifierOverlay" data-toggle="modal" test-id="top_show_me_schools_mobile">
#         <div class="btn btn-md btn-ghost" href="#searchResults">
#          View popular schools
#         </div>
#        </div>
#       </div>
#       <div class="wikiContent" id="article">
#        <p>
#         There are a variety of job opportunities for those pursuing a Management Information Systems major, including positions in network and computer administration, computer analysts and computer and information systems managers. A master's degree is not required to obtain a job in this field, but it's beneficial to those wishing to advance in their careers.
#        </p>
#        <div class=" articleSliderContainer open">
#         <h2 class=" articleSlider" id="section---EssentialInformation">
#          Essential Information
#         </h2>
#         <div class=" articleContentContainer">
#          <p>
#           An MIS (management information systems) major finds jobs in the wide array of tasks that are required to create and sustain complex financial computer systems. Many positions are attainable with a bachelor's degree in MIS or a related field, such as information science or computer science. Master's degree programs in MIS are also available, including MBA programs, and can open advanced career opportunities.
#          </p>
#          <p>
#          </p>
#          <table border="1" class="wikitable">
#           <tbody>
#            <tr class="odd">
#             <td>
#              <b>
#               Career Titles
#              </b>
#             </td>
#             <td>
#              <b>
#               Network &amp; Computer Systems Administrators
#              </b>
#             </td>
#             <td>
#              <b>
#               Computer Systems Analysts
#              </b>
#             </td>
#             <td>
#              <b>
#               Computer &amp; Information Systems Managers
#              </b>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <b>
#               Education Requirements
#              </b>
#             </td>
#             <td>
#              Bachelor's or master's degree
#             </td>
#             <td>
#              Bachelor's or master's degree
#             </td>
#             <td>
#              Bachelor's or master's degree
#             </td>
#            </tr>
#            <tr class="odd">
#             <td>
#              <b>
#               Projected Job Growth (2014-2024)*
#              </b>
#             </td>
#             <td>
#              8%
#             </td>
#             <td>
#              21%
#             </td>
#             <td>
#              15%
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <b>
#               Median Annual Salary (May, 2015)*
#              </b>
#             </td>
#             <td>
#              $77,810
#             </td>
#             <td>
#              $85,800
#             </td>
#             <td>
#              $131,600
#             </td>
#            </tr>
#           </tbody>
#          </table>
#          <p>
#           <i>
#            Source: *United States Bureau of Labor Statistics
#           </i>
#          </p>
#         </div>
#        </div>
#        <div class="cat-cta-group" data-target="#qualifierOverlay" data-toggle="modal">
#         <div class="cat-cta-header">
#          <h2>
#           Find schools that offer
#           <span class="noWrap">
#            these popular programs
#           </span>
#          </h2>
#         </div>
#         <div class="cat-cta-body">
#          <ul class="cat-cta-list" data-cname="cat_list" test-id="cat_list">
#           <li>
#            Information Resources Mgmt
#           </li>
#           <li>
#            Knowledge Management
#           </li>
#          </ul>
#          <div class="cat-cta-footer">
#           <span class="link link-underlined">
#            More Programs
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class=" articleSliderContainer">
#         <h2 class=" articleSlider" id="section---CareerOptions">
#          Career Options
#         </h2>
#         <div class=" articleContentContainer">
#          <p>
#           Though computer sciences and information systems programs already exist, an MIS program also provides financial and business applications to the study of computer science. MIS majors must understand the needs of both the business people using their systems and the computer sciences professionals creating their systems.
#          </p>
#          <p>
#           As such, an MIS major finds jobs in the wide array of tasks that are required to create and sustain complex financial computer systems. These types of jobs can be split into two categories: network administration tasks and computer systems tasks. Potential career titles include network and computer systems administrator, computer systems analyst and computer and information systems manager.
#          </p>
#          <h3 id="section---NetworkAndComputerSystemsAdministrator">
#           Network and Computer Systems Administrator
#          </h3>
#          <p>
#           Network and computer systems administrators install, manage and provide support for the computer networks of organizations. They troubleshoot problems and teach users about the various hardware and software applications.
#          </p>
#          <p>
#           As of May 2015, network and computer systems administrators earned a median yearly income of $77,810, according to the U.S. Bureau of Labor Statistics (BLS). Jobs for these professionals are expected to increase by 8% from 2014 to 2024, which is about as fast as average when compared with other occupations and industries.
#          </p>
#          <h3 id="section---ComputerSystemsAnalyst">
#           Computer Systems Analyst
#          </h3>
#          <p>
#           A computer systems analyst develops information systems that are designed to improve the efficiency of organizations. In addition to designing, programming and installing new computer systems, they work to increase the effectiveness of existing systems. Jobs for computer systems analysts were expected to increase by 21% during the 2014 - 2024 decade. Median annual salaries were $85,800 as of May 2015.
#          </p>
#          <h3 id="section---ComputerAndInformationSystemsManager">
#           Computer and Information Systems Manager
#          </h3>
#          <p>
#           Computer and information systems managers assess the technological needs of organizations and make recommendations for upgrades based on their findings. They may also determine the cost of adding new technologies, oversee IT personnel and work with vendors. The BLS predicted that employment would expand by 15% from 2014 through 2024. Computer and information systems managers earned median annual salaries of $131,600 in May of 2015.
#          </p>
#         </div>
#        </div>
#        <div class=" articleSliderContainer">
#         <h2 class=" articleSlider" id="section---ManagementInformationSystemsDegree">
#          Management Information Systems Degree
#         </h2>
#         <div class=" articleContentContainer">
#          <p>
#           The MIS degree features a mix between a computer sciences and information systems degrees with a business focus. Like many other sectors, the financial and business world heavily relies upon computers and networking for its continued operation. Today, many common financial tasks such as filing taxes and applying for loans or credit cards are completely computerized. MIS majors are the ones behind the scenes of these financial systems ensuring their continued working health.
#          </p>
#          <p>
#           An MIS program is beneficial for those pursuing a career in computer and information sciences in that it provides additional insight to the financial and business aspect of these positions. Having this experience and knowledge could be a major asset for many job candidates and will help to give them an advantage in obtaining employment. There are several career options for someone who has completed an MIS program, and salaries and job growth opportunities vary, depending on the career pursued.
#          </p>
#         </div>
#        </div>
#       </div>
#       <div class="next-schools-wrapper">
#        <div class="btn btn-ghost btn-lg" data-cname="btn_overlay_next_view_schools" data-target="#qualifierOverlay" data-toggle="modal" data-track-visible="" test-id="btn_overlay_next_view_schools">
#         <span>
#          Next:
#         </span>
#         View Schools
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="sidebar">
#      <div class="sticky-module-group sticky-search-module">
#       <div class="sticky-module-body" data-float-module-start=".sticky-module-group" data-float-module-start-mobile=".footer" data-float-module-stop=".sticky-module-blocker" data-float-module-stop-mobile="#articleMain" data-float-search="" data-track-visible="">
#        <div class=" schoolSearchContainer " data-cname="drop_down_search" id="search" test-id="drop_down_search">
#         <div class="header">
#          <h2>
#           Perfect School Search
#          </h2>
#         </div>
#         <form action="/search/find.html" class="schoolSearchForm" id="dropDownSearchForm" name="dropDownSearchForm">
#          <div class="search-group-hloe">
#           <label class="numbered" for="hloe">
#            What is your highest level of education?
#           </label>
#           <select class="largeDropDown" data-cname="drop_down_hloe" data-submit-on-change="false" id="hloe" name="pq_educationLevel" test-id="drop_down_hloe">
#            <option value="">
#             Select your education level
#            </option>
#            <option value="NONE">
#             Some High School
#            </option>
#            <option value="HS">
#             High School Diploma / GED
#            </option>
#            <option value="SOME_COLLEGE">
#             Some College
#            </option>
#            <option value="ASSOCIATE">
#             Associate's Degree
#            </option>
#            <option value="BACHELOR">
#             Bachelor's Degree
#            </option>
#            <option value="MASTER">
#             Master's Degree
#            </option>
#            <option value="DOCTOR">
#             Doctorate Degree
#            </option>
#           </select>
#          </div>
#          <input id="topQ" name="q" type="hidden" value="0"/>
#          <div class="search-group-cat">
#           <label class="numbered" for="topC1">
#            What subject are you interested in?
#           </label>
#           <select class="largeDropDown" data-clear-first="topC2,topC3" data-cname="drop_down_c1" data-submit-on-change="false" id="topC1" name="c1" test-id="drop_down_c1">
#            <option value="ALL">
#             Select your preferred subject area
#            </option>
#            <option value="26">
#             Agriculture
#            </option>
#            <option value="35">
#             Architecture
#            </option>
#            <option value="463">
#             Biological and Biomedical Sciences
#            </option>
#            <option class="yellow" selected="selected" value="388">
#             Business
#            </option>
#            <option value="41">
#             Communications and Journalism
#            </option>
#            <option value="58">
#             Computer Sciences
#            </option>
#            <option value="83">
#             Culinary Arts and Personal Services
#            </option>
#            <option value="94">
#             Education
#            </option>
#            <option value="129">
#             Engineering
#            </option>
#            <option value="187">
#             Legal
#            </option>
#            <option value="200">
#             Liberal Arts and Humanities
#            </option>
#            <option value="282">
#             Mechanic and Repair Technologies
#            </option>
#            <option value="312">
#             Medical and Health Professions
#            </option>
#            <option value="237">
#             Physical Sciences
#            </option>
#            <option value="240">
#             Psychology
#            </option>
#            <option value="295">
#             Transportation and Distribution
#            </option>
#            <option value="298">
#             Visual and Performing Arts
#            </option>
#           </select>
#           <select class="largeDropDown" data-clear-first="topC3" data-cname="drop_down_c2" data-submit-on-change="false" id="topC2" name="c2" test-id="drop_down_c2">
#            <option value="ALL">
#             Narrow your preferred subject area
#            </option>
#            <option value="389">
#             Accounting and Bookkeeping
#            </option>
#            <option value="2039">
#             Business Economics
#            </option>
#            <option value="416">
#             Business Finance
#            </option>
#            <option value="395">
#             Business Management and Operations
#            </option>
#            <option value="436">
#             Business Marketing
#            </option>
#            <option value="404">
#             Business Support and Administrative Services
#            </option>
#            <option value="413">
#             Entrepreneurship and Small Business Development
#            </option>
#            <option value="424">
#             Hospitality Management
#            </option>
#            <option value="428">
#             Human Resource Management
#            </option>
#            <option class="yellow" selected="selected" value="432">
#             Information System Management
#            </option>
#            <option value="430">
#             International Business
#            </option>
#            <option value="421">
#             Sales and Merchandising
#            </option>
#            <option value="442">
#             Specialized Sales
#            </option>
#           </select>
#           <select class="largeDropDown" data-cname="drop_down_c3" data-submit-on-change="false" id="topC3" name="c3" test-id="drop_down_c3">
#            <option value="ALL">
#             Select your specialty subject area
#            </option>
#            <option value="2050">
#             Information Resources Mgmt
#            </option>
#            <option value="3208">
#             Knowledge Management
#            </option>
#           </select>
#          </div>
#          <div class="search-group-qual">
#          </div>
#          <div class="search-group-location">
#           <label class="numbered" for="schoolType">
#            Where do you want to attend class?
#           </label>
#           <select data-cname="drop_down_location" id="schoolType" name="schoolType" test-id="drop_down_location">
#            <option selected="selected" value="locationAll">
#             Show me all schools
#            </option>
#            <option class="hidden-xs" value="zip">
#             Near my home
#            </option>
#            <option value="online">
#             Online schools only
#            </option>
#            <option value="state">
#             I want to choose a state
#            </option>
#           </select>
#           <div class="hidden-xs">
#            <div class="zipInput off">
#             <p>
#              Enter zip:
#              <input class="searchBorder zipInputGroup" data-cname="drop_down_zip" id="dropDownZip" name="zip" test-id="drop_down_zip" type="text" value=""/>
#              <button class="findSchoolsSubmitButton btn btn-primary" data-cname="drop_down_submit_button" data-submit-on-click="false" id="dropDownSearchButton" name="searchButton" test-id="drop_down_submit_button" type="submit" value="">
# ...
#         <input name="formId" type="hidden" value="Full Sail University"/>
#         <input name="lclg" type="hidden" value="true"/>
#         <input name="miniformPost" type="hidden" value="true"/>
#        </form>
#       </li>
#       <li class="seeMore link-underlined text-right" data-cname="side_search_view_more_1" data-test="sm2" test-id="side_search_view_more_1">
#        Show more schools…
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="sticky-module-group floating-bar-module">
#     <div class="sticky-module-body" data-float-bar="" data-float-module-start=".footer" data-float-module-start-mobile=".wikiContent" data-float-module-stop=".footer" data-float-module-stop-mobile=".sticky-module-blocker">
#      <div class="floating-bar" data-track-visible="">
#       <div class="module-inner">
#        <div class="floating-bar-text">
#         <h2>
#          Find your perfect school
#         </h2>
#         <p>
#          What is your highest
#          <span class="noWrap">
#           level of education?
#          </span>
#         </p>
#        </div>
#        <div class="floating-bar-options">
#         <div class="faux-select-element">
#          <div class="faux-select-item-default" data-cname="fbar_select_open" data-faux-select="" test-id="fbar_select_open">
#           Select highest level of education
#           <div class="faux-select-options">
#            <div class="faux-select-item" data-cname="fbar_select_hs_ged" test-id="fbar_select_hs_ged">
#             <a href="/search/find.html?companyIdsToExclude=&amp;c1=388&amp;c2=432&amp;c3=0&amp;q1=0&amp;q2=0&amp;pq_educationLevel=GED">
#              HS diploma
#             </a>
#            </div>
#            <div class="faux-select-item" data-cname="fbar_select_some_college" test-id="fbar_select_some_college">
#             <a href="/search/find.html?companyIdsToExclude=&amp;c1=388&amp;c2=432&amp;c3=0&amp;q1=0&amp;q2=0&amp;pq_educationLevel=SOME_COLLEGE">
#              Some college
#             </a>
#            </div>
#            <div class="faux-select-item" data-cname="fbar_select_associate" test-id="fbar_select_associate">
#             <a href="/search/find.html?companyIdsToExclude=&amp;c1=388&amp;c2=432&amp;c3=0&amp;q1=0&amp;q2=0&amp;pq_educationLevel=ASSOCIATE">
#              Associates degree
#             </a>
#            </div>
#            <div class="faux-select-item" data-cname="fbar_select_bachelor" test-id="fbar_select_bachelor">
#             <a href="/search/find.html?companyIdsToExclude=&amp;c1=388&amp;c2=432&amp;c3=0&amp;q1=0&amp;q2=0&amp;pq_educationLevel=BACHELOR">
#              Bachelors degree
#             </a>
#            </div>
#            <div class="faux-select-item" data-cname="fbar_select_master" test-id="fbar_select_master">
#             <a href="/search/find.html?companyIdsToExclude=&amp;c1=388&amp;c2=432&amp;c3=0&amp;q1=0&amp;q2=0&amp;pq_educationLevel=MASTER">
#              Masters degree
#             </a>
#            </div>
#            <div class="faux-select-item" data-cname="fbar_select_doctor" test-id="fbar_select_doctor">
#             <a href="/search/find.html?companyIdsToExclude=&amp;c1=388&amp;c2=432&amp;c3=0&amp;q1=0&amp;q2=0&amp;pq_educationLevel=DOCTOR">
#              Doctorate
#             </a>
#            </div>
#            <div class="faux-select-item" data-cname="fbar_select_none" test-id="fbar_select_none">
#             <a href="/search/find.html?companyIdsToExclude=&amp;c1=388&amp;c2=432&amp;c3=0&amp;q1=0&amp;q2=0&amp;pq_educationLevel=NONE">
#              Still in HS
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <form action="/search/find.html" class="qualifier-modal-edu-level modal fade in " id="qualifierOverlay" method="get" role="dialog" tabindex="-1">
#     <div class="modal-dialog" role="document">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-label="Close" class="close" data-cname="overlay_close_x" data-dismiss="modal" test-id="overlay_close_x" type="button">
#         <span aria-hidden="true">
#          ×
#         </span>
#        </button>
#        <div class="model-header-inner">
#         <h4 class="modal-title">
#          Select your highest
#          <span class="noWrap">
#           level of education
#          </span>
#         </h4>
#         <p class="hidden-xs">
#          Get Matched to Schools
#         </p>
#        </div>
#       </div>
#       <div class="modal-body">
#        <div class="edu-level-group">
#         <div class="edu-level-item">
#          <button class="btn" data-cname="overlay_some_hs" name="pq_educationLevel" test-id="overlay_some_hs" type="submit" value="NONE">
#           Some high school
#          </button>
#         </div>
#         <div class="edu-level-item">
#          <button class="btn" data-cname="overlay_hs_ged" name="pq_educationLevel" test-id="overlay_hs_ged" type="submit" value="HS">
#           High school / GED
#          </button>
#         </div>
#         <div class="edu-level-item">
#          <button class="btn" data-cname="overlay_some_college" name="pq_educationLevel" test-id="overlay_some_college" type="submit" value="SOME_COLLEGE">
#           Some college
#          </button>
#         </div>
#         <div class="edu-level-item">
#          <button class="btn" data-cname="overlay_college_degree" name="pq_educationLevel" test-id="overlay_college_degree" type="submit" value="">
#           College degree
#          </button>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <input name="online" type="hidden" value="false"/>
#     <input name="c2" type="hidden" value="432"/>
#     <input name="c1" type="hidden" value="388"/>
#     <input name="c3" type="hidden" value="0"/>
#     <input name="state" type="hidden" value=""/>
#     <input name="zip" type="hidden" value=""/>
#    </form>
#    <!-- Snap Engage -->
#   </div>
#   <footer class="footer " data-cname="footer" id="homepageTestFooter" test-id="footer">
#    <div class="container-fluid">
#     <div class="visible-xs">
#      <div class="col50 appDownloads">
#       <h4>
#        Download the app
#       </h4>
#       <a class="appDownloadButton topButton" data-cname="footer_google_play_mobile_app_download" href="https://play.google.com/store/apps/details?id=com.study.app&amp;utm_source=global_co&amp;utm_medium=prtnr&amp;utm_content=Mar2515&amp;utm_campaign=PartBadge&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-PartBadge-Mar2515-1" target="_blank" test-id="google_play_mobile_app_download">
#        <img alt="Get it on Google Play" src="https://play.google.com/intl/en_us/badges/images/generic/en_badge_web_generic.png"/>
#       </a>
#       <a class="appDownloadButton bottomButton" data-cname="footer_ios_mobile_app_download" href="https://itunes.apple.com/us/app/study.com-video-lessons-learn/id1128875336" target="_blank" test-id="ios_mobile_app_download">
#        <img alt="Get it on the App Store" src="/images/reDesign/ctas/apple-app-store-download-button.png"/>
#       </a>
#      </div>
#      <div class="col50">
#       <div class="footer__connect__social" data-cname="footer_social" test-id="footer_social">
#        <div class="col-sm-6 no-padding">
#         <a class="footer__connect__social__icon" data-cname="bottom_facebook" data-external-link="" href="http://www.facebook.com/StudyDotCom" target="_blank" test-id="bottom_facebook">
#          <span class="icon icon-facebook-sign">
#          </span>
#         </a>
#         <a class="footer__connect__social__icon" data-cname="bottom_twitter" data-external-link="" href="http://twitter.com/studydotcom" target="_blank" test-id="bottom_twitter">
#          <span class="icon icon-twitter-sign">
#          </span>
#         </a>
#        </div>
#        <div class="col-sm-6 no-padding">
#         <a class="footer__connect__social__icon" data-cname="bottom_google" data-external-link="" href="https://plus.google.com/+EducationPortalVideo" target="_blank" test-id="bottom_google">
#          <span class="icon icon-google-plus-sign">
#          </span>
#         </a>
#         <a class="footer__connect__social__icon" data-cname="bottom_youtube" data-external-link="" href="http://www.youtube.com/user/EducationPortalVideo/" target="_blank" test-id="bottom_youtube">
#          <span class="icon icon-youtube-sign2">
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="clearfix">
#     </div>
#     <div class="col-sm-4 no-padding">
#      <div class="col50">
#       <h4>
#        <a data-cname="products" href="/academy/plans.html" test-id="products">
#         Products
#        </a>
#       </h4>
#       <ul>
#        <li>
#         <a data-cname="student_solutions" href="/academy/plans.html" test-id="student_solutions">
#          Student Solutions
#         </a>
#        </li>
#        <li>
#         <a data-cname="teacher_solutions" href="/academy/plans/teacher.html" test-id="teacher_solutions">
#          Teacher Solutions
#         </a>
#        </li>
#        <li>
#         <a data-cname="corporate_solutions" href="/academy/plans/corporate.html" test-id="corporate_solutions">
#          Corporate Solutions
#         </a>
#        </li>
#        <li>
#         <a data-cname="for_schools" href="/academy/plans/teacher-group.html" test-id="for_schools">
#          Study.com for Schools
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col50">
#       <h4>
#        <a data-cname="about_us" href="/pages/About_Us.html" test-id="about_us">
#         About Us
#        </a>
#       </h4>
#       <ul>
#        <li>
#         <a data-cname="bottom_blog" href="/blog/index.html" test-id="bottom_blog">
#          Blog
#         </a>
#        </li>
#        <li>
#         <a data-cname="careers" href="/pages/Employment.html" test-id="careers">
#          Careers
#         </a>
#        </li>
#        <li>
#         <a data-cname="advertise_with_us" href="/pages/Advertise.html" test-id="advertise_with_us">
#          Get Your School Listed
#         </a>
#        </li>
#        <li>
#         <a data-cname="teach_for_us" href="/pages/Contractors.html" test-id="teach_for_us">
#          Teach For Us
#         </a>
#        </li>
#        <li>
#         <a data-cname="press_center" href="/press.html" test-id="press_center">
#          Press Center
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="clearfix visible-xs">
#     </div>
#     <div class="col-sm-2">
#      <h4>
#       <a data-cname="support" href="/contact/index.html" test-id="support">
#        Support
#       </a>
#      </h4>
#      <ul>
#       <li>
#        <a class="supportEmailTrigger" data-cname="contact_support" data-external-link="" href="/contact/index.html" test-id="contact_support">
#         Contact Support
#        </a>
#       </li>
#       <li>
#        <a data-cname="faq" data-external-link="" href="http://support.study.com" target="_blank" test-id="faq">
#         FAQ
#        </a>
#       </li>
#       <li>
#        <a data-cname="site_feedback" href="/contact/index.html" test-id="site_feedback">
#         Site Feedback
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="col-sm-2 appDownloads hidden-xs">
#      <h4>
#       Download the app
#      </h4>
#      <a class="appDownloadButton topButton" data-cname="footer_google_play_mobile_app_download" href="https://play.google.com/store/apps/details?id=com.study.app&amp;utm_source=global_co&amp;utm_medium=prtnr&amp;utm_content=Mar2515&amp;utm_campaign=PartBadge&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-PartBadge-Mar2515-1" target="_blank" test-id="google_play_mobile_app_download">
#       <img alt="Get it on Google Play" src="https://play.google.com/intl/en_us/badges/images/generic/en_badge_web_generic.png"/>
#      </a>
#      <a class="appDownloadButton bottomButton" data-cname="footer_ios_mobile_app_download" href="https://itunes.apple.com/us/app/study.com-video-lessons-learn/id1128875336" target="_blank" test-id="ios_mobile_app_download">
#       <img alt="Get it on the App Store" src="/images/reDesign/ctas/apple-app-store-download-button.png"/>
#      </a>
#     </div>
#     <div class="col-sm-4 hidden-xs">
#      <div class="footer__connect__social" data-cname="footer_social" test-id="footer_social">
#       <a class="footer__connect__social__icon" data-cname="bottom_facebook" data-external-link="" href="http://www.facebook.com/StudyDotCom" target="_blank" test-id="bottom_facebook">
#        <span class="icon icon-facebook-sign">
#        </span>
#       </a>
#       <a class="footer__connect__social__icon" data-cname="bottom_twitter" data-external-link="" href="http://twitter.com/studydotcom" target="_blank" test-id="bottom_twitter">
#        <span class="icon icon-twitter-sign">
#        </span>
#       </a>
#       <a class="footer__connect__social__icon" data-cname="bottom_google" data-external-link="" href="https://plus.google.com/+EducationPortalVideo" target="_blank" test-id="bottom_google">
#        <span class="icon icon-google-plus-sign">
#        </span>
#       </a>
#       <a class="footer__connect__social__icon" data-cname="bottom_youtube" data-external-link="" href="http://www.youtube.com/user/EducationPortalVideo/" target="_blank" test-id="bottom_youtube">
#        <span class="icon icon-youtube-sign2">
#        </span>
#       </a>
#      </div>
#      <div class="clearfix">
#      </div>
#      <div class="workingScholars">
#       <a data-cname="working_scholars_footer" href="/pages/working-scholars.html" test-id="working_scholars_footer">
#        <img src="/images/reDesign/home/homepage-test/svg/art_working_scholars_555.svg"/>
#       </a>
#       <a class="workingScholarsText col-sm-8" data-cname="working_scholars_logo_footer" href="/pages/working-scholars.html" test-id="working_scholars_logo_footer">
#        Bringing Tuition-Free College to the Community
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="bbbLogo visible-xs">
#     <a alt="Study.com is a BBB Accredited Educational Consultant in Mountain View, CA" class="footer__links-container__bbb-link" data-cname="bbb_logo" data-external-link="" href="http://www.bbb.org/sanjose/business-reviews/educational-consultants/remilon-1000006412#bbbseal" id="bbblink" target="_blank" test-id="bbb_logo" title="Study.com is a BBB Accredited Educational Consultant in Mountain View, CA">
#     </a>
#    </div>
#    <div class="container-fluid copyright">
#     <p>
#      ©  copyright 2003-2017 Study.com.
# 			All other trademarks and copyrights are the property of their respective owners.
# 			All rights reserved.
#     </p>
#     <div class="bbbLogo hidden-xs">
#      <a alt="Study.com is a BBB Accredited Educational Consultant in Mountain View, CA" class="footer__links-container__bbb-link" data-cname="bbb_logo" data-external-link="" href="http://www.bbb.org/sanjose/business-reviews/educational-consultants/remilon-1000006412#bbbseal" id="bbblink" target="_blank" test-id="bbb_logo" title="Study.com is a BBB Accredited Educational Consultant in Mountain View, CA">
#      </a>
#     </div>
#     <div class="footer__copyright">
#      Curriculum, relevancy of sample programs, and outcomes will vary by school.
#     </div>
#     <div>
#      <a data-cname="terms_of_use" href="/pages/terms_of_use.html" rel="nofollow" test-id="terms_of_use">
#       Terms of Use
#      </a>
#      <a data-cname="privacy_policy" href="/pages/privacy_policy.html" rel="nofollow" test-id="privacy_policy">
#       Privacy Policy
#      </a>
#      <a data-cname="dmca" href="/pages/dmca.html" rel="nofollow" test-id="dmca">
#       DMCA Notice
#      </a>
#     </div>
#    </div>
#   </footer>
#   <script defer="" src="/js/video/initEmbeds-e7b2cbbfb7.js">
#   </script>
#   <script defer="" src="/js/redesign/global-728b2ed2c1.js">
#   </script>
#   <script data-no-freshdesk-button="" data-skip-mobile-reformat="" defer="" src="/js/redesign/research/articleMain-d48ef147d1.js">
#   </script>
#   <!-- {"site":"site-sdy-3-1.ue1.prod.study.com"} -->
#   <!-- {"services":[]} -->
#   <!-- {"rem ip":"false"} -->
#   <div class="hidden" data-member-account-type="NONE" data-member-has-institution-license="false" data-member-id="" data-member-persona="" data-member-product-key="" data-member-status="" id="memberData">
#   </div>
#   <div class="hidden" data-ssoe-debug-cookie-value="" id="ssoeDebugCookieValue">
#   </div>
#  </body>
# </html>

# %%
arrCareerTitles = []
arrProjectedGrowth = []
arrMedianSalary = []
iCount2 = 0
for dataPay10 in soupPay10.find_all("td"):
    iCount2 = iCount2+1
    if(iCount2 >1 and iCount2<=4):
        arrCareerTitles.append(dataPay10.text)
    elif(iCount2 > 9 and iCount2 <=12):
         arrProjectedGrowth.append(dataPay10.text)
    elif(iCount2 >13 and iCount2 <=16):    
         arrMedianSalary.append(dataPay10.text)

# %% [markdown]
# Get the specialization Tracks available in the MSIS program. This relates to the skills that is commonly expected of the students.

# %%
urlTracks = 'https://www.scu.edu/business/ms-information-systems/curriculum/specialization-tracks/'
rTracks = requests.get(urlTracks)
rTracks.content
soupTracks = BeautifulSoup(rTracks.content, "lxml")

# %%
arrTracks = []

# %%
for dataTracks in soupTracks.find_all("h4"):
    arrTracks.append(dataTracks.text)

# %%
arrTracks
# Out:
# ['Business Intelligence / Analytics Track',
#  'Enterprise Computing Track',
#  'Mobile Programming Track',
#  'Computer Security Track',
#  'Supply Chain Management Track',
#  'IT Management Track']

# %%
dataframe=pandas.DataFrame(arrTracks,columns=['Program Tracks'])
dataframe
# Out:
#                             Program Tracks
# 0  Business Intelligence / Analytics Track
# 1               Enterprise Computing Track
# 2                 Mobile Programming Track
# 3                  Computer Security Track
# 4            Supply Chain Management Track
# 5                      IT Management Track

# %%
data =  {'Job Type':arrJobType,'Salary':arrJobSalary}
dataframe2=pandas.DataFrame(data)
dataframe2
# Out:
#                                        Job Type    Salary
# 0  Project Manager, Information Technology (IT)   $81,591
# 1                             Software Engineer   $86,000
# 2                     Network Security Engineer  $119,792
# 3                            Software Developer   $81,472
# 4                       Senior Business Analyst  $105,000
# 5                    Senior Project Manager, IT  $103,917
# 6           Information Technology (IT) Manager  $132,250

# %%
data2 =  {'Career Titles':arrCareerTitles,'Projected Growth Rate:(2014-2024)':arrProjectedGrowth, 'Median Salary':arrMedianSalary}
dataframe3=pandas.DataFrame(data2)
dataframe3
# Out:
#                                  Career Titles Median Salary  \
# 0   Network & Computer Systems Administrators       $77,810
# 1                   Computer Systems Analysts       $85,800
# 2      Computer & Information Systems Managers      $131,600
#
#   Projected Growth Rate:(2014-2024)
# 0                               8%
# 1                              21%
# 2                               15%

# %%
DataComp = requests.get('http://study.com/articles/Top_Ranked_School_for_Information_Technology_-_San_Jose_CA.html')
DataComp.content
soupDataComp = BeautifulSoup(DataComp.content, 'lxml')
print(soupDataComp.prettify())
# Out:
#  Category
#  Santa Clara University
#  San Jose State University
#  University of San Francisco
#
#
#  Rankings (2013)
#  Ranked 2nd among universities in the Western region*
#  Named the 9th best public school in the Western region*
#  106th among national universities in the U.S.*
#
#
#  Location
#  Santa Clara, CA (about 2 miles from San Jose)
#  San Jose, CA
#  San Francisco, CA (roughly 42 miles from San Jose
#
#
#  School Type
#  4-year, private not-for-profit
#  4-year, public
#  4-year, private not-for-profit
#
#
#  Tuition & Fees (2012-2013)
#  $23,976 (graduate)**
#  $6,852, in-state; $18,510, out-of-state (undergrad)**
#  $965 per credit (bachelor's completion program)***; $20,390 per year (graduate)**
#
#
#  Information Technology Degrees and Programs Offered
#  Master's degree
#  Bachelor's degree
#  Adult bachelor's completion and master's degrees
#
#
#  Information Technology Degrees Awarded (All Levels) in 2011-2012
#  22**
#  1,242 for business administration and management (information technology not provided)**
#  248 for business administration and management (information technology not provided)**
#
#
#  Most Popular Information Technology Programs in 2011-2012
#  Master of Science in Information Systems (22 degrees awarded)**
#  N/A
#  N/A
#
#
#  Undergrad Graduation Rate (in 150% of normal program time) for 2005 Entering Class
#  N/A
#  46%**
#  70%**
#
#
#  Noteworthy
#  12th among schools in the Western region for the best educational value in 2013*
#  Listed 38th among universities in the Western region in 2013*
#  Ranked 100th nationally by high school counselors in 2012*

# %%
DataComp = requests.get('http://study.com/articles/Top_Ranked_School_for_Information_Technology_-_San_Jose_CA.html')
DataComp.content
soupDataComp = BeautifulSoup(DataComp.content, 'lxml')
print(soupDataComp.prettify())
table1 = soupDataComp.find('table')
print(table1)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Top Ranked School for Information Technology - San Jose, CA
#   </title>
#   <meta content="index,follow,noodp" name="robots"/>
#   <meta content="article" property="og:type"/>
#   <meta content="http://study.com/images/StudyCom-og-Facebook-Logo.jpg" property="og:image"/>
#   <meta content="image/jpg" property="og:image:type"/>
#   <meta content="Top Ranked School for Information Technology - San Jose, CA" property="og:title"/>
#   <meta content="Individuals searching for Top Ranked School for Information Technology - San Jose, CA  found the following related articles, links, and information  useful." property="og:description"/>
#   <meta content="http://study.com/articles/Top_Ranked_School_for_Information_Technology_-_San_Jose_CA.html" property="og:url"/>
#   <meta content="Study.com" property="og:site_name"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="" name="author"/>
#   <!-- CSS -->
#   <link href="//fonts.googleapis.com/css?family=Open+Sans:400italic,400,600,300,700|Droid+Serif:400,700,400italic" rel="stylesheet" type="text/css"/>
#   <link href="/css/icons/icomoon-08d57fcab5.css" rel="stylesheet"/>
#   <link href="/css/pages/global-db7728c894.css" rel="stylesheet"/>
#   <link href="/css/notification/humane-3.2.0-themes/remilon-custom-6af209b03a.css" rel="stylesheet"/>
#   <link href="/favicon.ico?v=2" rel="shortcut icon"/>
#   <meta content="98d76d6cc867f0144d817c732e15748b" name="requestGuid"/>
#   <meta content="" name="searchGuid"/>
#   <meta content="" name="impressionGuid"/>
#   <meta content="Top Ranked School for Information Technology - San Jose, CA" name="keywords"/>
#   <meta content="Individuals searching for Top Ranked School for Information Technology - San Jose, CA  found the following related articles, links, and information  useful." name="description"/>
#   <link href="/rss/article_directory/Top_Information_Technology_Schools_in_California.html.xml" rel="alternate" title="Top Information Technology Schools in California" type="application/rss+xml"/>
#   <link href="/css/oiewinner-5ca0246758.css" rel="stylesheet"/>
#   <link href="/css/pages/article-8f58b0a5a4.css" rel="stylesheet"/>
#  </head>
#  <body id="articleMain">
#   <content itemscope="" itemtype="http://schema.org/Organization">
#    <meta content="Study.com" itemprop="name"/>
#    <meta content="Take online courses that are fun and engaging. Pass exams to earn real college credit. Research schools and degrees to further your education." itemprop="description"/>
#    <meta content="http://study.com/images/StudyCom-og-Facebook-Logo.jpg" itemprop="image"/>
#   </content>
#   <div class="study-nav">
#    <div class="study-nav__top ">
#     <div class="container-fluid">
#      <div class="study-nav__top__actions">
#       <a class="for-link" data-cname="teacher_product" href="/academy/plans/teacher.html" test-id="teacher_product">
#        <em>
#         for
#        </em>
#        Teachers
#       </a>
#       <a class="for-link" data-cname="institution_product" href="/academy/plans/teacher-group.html" test-id="institution_product">
#        <em>
#         for
#        </em>
#        Schools
#       </a>
#       <a class="for-link" data-cname="corporate_product" href="/academy/plans/corporate.html" test-id="corporate_product">
#        <em>
#         for
#        </em>
#        Companies
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="collapseSearch xs-search">
#     <form action="/search/quicksearch.html" method="POST">
#      <div class="input-group">
#       <input class="form-control" name="q" placeholder="Search Degrees, Careers, or Schools" type="text"/>
#       <button class="input-group-addon form-control" id="topSearchRun">
#        <span class="icon icon-search" data-cname="top_search_icon" test-id="top_search_icon">
#        </span>
#       </button>
#      </div>
#     </form>
#    </div>
#    <div class="study-nav__main">
#     <div class="container-fluid">
#      <div class="study-nav__logo">
#       <a data-cname="logo" href="/" test-id="logo">
#        <img alt="Study.com" src="/images/reDesign/global/logo.png"/>
#       </a>
#      </div>
#      <div class="study-nav__main-actions">
#       <div>
#        <a class="text-link" data-cname="login" href="/academy/login.html" test-id="login">
#         Login
#        </a>
#       </div>
#       <div>
#        <a class="hidden-xs btn btn-primary" data-cname="sign_up" href="/academy/plans.html" test-id="sign_up">
#         Sign Up
#        </a>
#       </div>
#       <button aria-controls="navsContainer" aria-expanded="false" class="visible-xs btn btn-primary" data-cname="mobile_user_nav" data-target="#navsContainer" data-toggle="collapse" test-id="mobile_user_nav">
#        Menu
#       </button>
#       <div class="searchTrigger dropdown" id="topSearchOpen">
#        <span class="icon icon-search" data-cname="top_search_icon" id="searchToggleTablet" test-id="top_search_icon">
#        </span>
#       </div>
#       <form action="/search/quicksearch.html" class="search-form" data-cname="text_search" id="searchBarDesktop" method="POST" test-id="text_search">
#        <div class="input-group">
#         <input class="form-control" name="q" placeholder="Search Degrees, Careers, or Schools" type="text"/>
#         <button class="input-group-addon form-control">
#          <span class="icon icon-search" data-cname="top_search_icon" test-id="top_search_icon">
#          </span>
#         </button>
#        </div>
#       </form>
#      </div>
#      <div class="study-nav__navs-container collapse" id="navsContainer">
#       <div class="study-nav__mobile-actions">
#        <a class="for-link" data-cname="teacher_product" href="/academy/plans/teacher.html" test-id="teacher_product">
#         <em>
#          for
#         </em>
#         Teachers
#        </a>
#        <a class="for-link" data-cname="institution_product" href="/academy/plans/teacher-group.html" test-id="institution_product">
#         <em>
#          for
#         </em>
#         Schools
#        </a>
#        <a class="for-link" data-cname="corporate_product" href="/academy/plans/corporate.html" test-id="corporate_product">
#         <em>
#          for
#         </em>
#         Companies
#        </a>
#       </div>
#       <ul class="study-nav__site-nav">
#        <li class="dropdown no-sub-nav " data-cname="top_menu" test-id="top_menu">
#         <a data-cname="plans" href="/academy/plans.html">
#          Plans
#         </a>
#        </li>
#        <li data-cname="top_menu" test-id="top_menu">
#         <a class="hidden-xs" data-cname="courses" href="/academy/course/index.html" test-id="courses">
#          Courses
#         </a>
#         <a aria-controls="navCourses" aria-expanded="false" class="visible-xs collapsed" data-target="#navCourses" data-toggle="collapse">
#          Courses
#         </a>
#         <div class="study-nav__sub-nav collapse" id="navCourses">
#          <div class="col-sm-6 study-nav__sub-nav__border-right">
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="coursesBySubject" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#coursesBySubject" data-toggle="collapse">
#             Find Courses by Subject
#            </a>
#            <ul class="collapse" data-cname="course_subject" id="coursesBySubject" test-id="course_subject">
#             <li>
#              <a href="/academy/subj/science.html">
#               Science
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/math.html">
#               Math
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/business.html">
#               Business
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/psychology.html">
#               Psychology
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/history.html">
#               History
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/english.html">
#               English
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/social-science.html">
#               Social Science
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/humanities.html">
#               Humanities
#              </a>
#             </li>
#             <li>
#              <a href="/academy/subj/foreign-language.html">
#               Spanish
#              </a>
#             </li>
#             <li>
#              <a href="/academy/goal/test-prep/act-and-sat-prep.html">
#               ACT &amp; SAT Test Prep
#              </a>
#             </li>
#             <li>
#              <a href="/academy/goal/professional-licensure/teacher-certification.html">
#               Teacher Certification
#              </a>
#             </li>
#             <li>
#              <a href="/academy/goal/professional-licensure.html">
#               Professional Development
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="col-sm-6">
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="coursesByLevel" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#coursesByLevel" data-toggle="collapse">
#             By Education Level
#            </a>
#            <ul class="collapse" data-cname="course_education_level" id="coursesByLevel" test-id="course_education_level">
#             <li>
#              <a href="/academy/level/college.html">
#               College
#              </a>
#             </li>
#             <li>
#              <a href="/academy/level/high-school.html">
#               High School
#              </a>
#             </li>
#             <li>
#              <a href="/academy/level/middle-school.html">
#               Middle School
#              </a>
#             </li>
#            </ul>
#            <hr/>
#           </div>
#          </div>
#          <div class="study-nav__cta-text">
#           <div class="hidden-xs">
#            <em>
#             Explore over
#            </em>
#            <strong>
#             3,700
#            </strong>
#            <small>
#             video courses
#            </small>
#           </div>
#           <a class="btn btn-primary" data-cname="browse_all_courses" href="/academy/course/index.html" test-id="browse_all_courses">
#            Browse All Courses
#            <span class="icon-arrow-right">
#            </span>
#           </a>
#          </div>
#         </div>
#        </li>
#        <li data-cname="top_menu" test-id="top_menu">
#         <a class="dropdown-toggle hidden-xs" data-cname="credit" href="/academy/college-accelerator-hub/how-to-transfer-college-credit-online.html" test-id="credit">
#          Credit
#         </a>
#         <a aria-controls="navCredit" aria-expanded="false" class="visible-xs collapsed" data-target="#navCredit" data-toggle="collapse">
#          Credit
#         </a>
#         <div class="study-nav__sub-nav collapse" id="navCredit">
#          <div class="study-nav__sub-nav__section">
#           <a class="hidden-xs study-nav__sub-nav__section__header">
#            Credit Options
#           </a>
#           <ul data-cname="earn_credit" test-id="earn_credit">
#            <li>
#             <a data-cname="earn_credit_online_college_credit" href="/academy/goal/transferable-credit/online-college-credit.html" test-id="earn_credit_online_college_credit">
#              Online College Credit
#             </a>
#            </li>
#            <li>
#             <a data-cname="earn_credit_high_school" href="/academy/level/high-school.html" test-id="earn_credit_high_school">
#              High School &amp; GED
#             </a>
#            </li>
#            <li>
#             <a data-cname="earn_credit_certificates" href="/academy/goal/certificates/certificates-of-completion.html" test-id="earn_credit_certificates">
#              Certificates of Completion
#             </a>
#            </li>
#            <li>
#             <a data-cname="earn_credit_how_it_works" href="/academy/college-accelerator-hub/how-to-transfer-college-credit-online.html" test-id="earn_credit_how_it_works">
#              How it Works
#             </a>
#            </li>
#           </ul>
#          </div>
#          <hr/>
#          <div class="study-nav__cta-text">
#           <div class="hidden-xs">
#            Earn Transferable Credit &amp; Get your Degree
#            <em>
#             fast
#            </em>
#           </div>
#           <a class="btn btn-primary" data-cname="credit_learn_more" href="/academy/college-accelerator-hub/how-to-transfer-college-credit-online.html" test-id="credit_learn_more">
#            Learn more
#            <span class="icon-arrow-right">
#            </span>
#           </a>
#          </div>
#         </div>
#        </li>
#        <li data-cname="top_menu" test-id="top_menu">
#         <a class="hidden-xs" href="/directory/category/index.html">
#          Degrees
#         </a>
#         <a aria-controls="navDegrees" aria-expanded="false" class="visible-xs collapsed" data-target="#navDegrees" data-toggle="collapse">
#          Degrees
#         </a>
#         <div class="study-nav__sub-nav collapse" id="navDegrees">
#          <div class="col-sm-8 study-nav__sub-nav__border-right">
#           <div class="study-nav__sub-nav__section">
#            <p class="hidden-xs header study-nav__sub-nav__section__header">
#             Find Degrees by Subject
#            </p>
#            <a class="study-nav__sub-nav__section__header visible-xs" data-target="#degreeCollapsible" data-toggle="collapse">
#             Find Degrees by Subject
#            </a>
#            <div class="collapse" id="degreeCollapsible">
#             <div class="researchBreadcrumb researchBreadcrumb-sub">
#              <ul class="breadcrumbLinks">
#               <li class="crumb sans-chevron">
#                <a class="override-nav" href="/directory/category/Computer_Sciences.html">
#                 Computer Sciences
#                </a>
#               </li>
#               <li class="divider sans-chevron">
#                <span class="override-nav">
#                 /
#                </span>
#               </li>
#               <li class="crumb sans-chevron">
#                <a class="override-nav" href="/directory/category/Computer_Sciences/Computer_and_Information_Sciences%2C_General.html">
#                 Computer and Information Sciences, General
#                </a>
#               </li>
#               <li class="divider sans-chevron">
#                <span class="override-nav">
#                 /
#                </span>
#               </li>
#               <li class="crumb sans-chevron">
#                <a class="override-nav" href="/directory/category/Computer_Sciences/Computer_and_Information_Sciences%2C_General/Information_Technology.html">
#                 Information Technology
#                </a>
#               </li>
#              </ul>
#             </div>
#             <hr/>
#             <ul class="navGroup12 no-bullet-list" data-cname="degree_subject" test-id="degree_subject">
#              <li>
#               <ul class="twoCols clear">
#                <li class="col">
#                 <ul>
#                  <li>
#                   <a href="/directory/category/Computer_Sciences.html">
#                    Computer Sciences
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Computer_Sciences/Computer_and_Information_Sciences%2C_General.html">
#                    Computer and Information Sciences, General
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Computer_Sciences/Computer_and_Information_Sciences%2C_General/Computer_and_Information_Support_Services%2C_Other.html">
#                    Computer and Information Support Services, Other
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#                <li class="col">
#                 <ul>
#                  <li>
#                   <a href="/directory/category/Computer_Sciences/Computer_and_Information_Sciences%2C_General/Information_Science_and_Studies_General.html">
#                    Information Science and Studies General
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/directory/category/Computer_Sciences/Computer_and_Information_Sciences%2C_General/Robotics_and_Artificial_Intelligence.html">
#                    Robotics and Artificial Intelligence
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="col-sm-4">
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="degreesByLevel" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#degressByLevel" data-toggle="collapse">
#             By Level
#            </a>
#            <ul class="no-bullet-list collapse" data-cname="degree_level" id="degressByLevel" test-id="degree_level">
#             <li>
#              <a href="/pages/Online_High_Schools.html">
#               High School Diploma
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Glossary_of_Associate%27s_Degree_Programs.html">
#               Associates Degrees
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Glossary_of_Bachelor%27s_Degree_Programs.html">
#               Bachelor Degrees
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Glossary_of_Master%27s_Degree_Programs.html">
#               Master Degrees
#              </a>
#             </li>
#             <li>
#              <a href="/online_degree.html">
#               Online Degrees
#              </a>
#             </li>
#            </ul>
#            <hr/>
#           </div>
#          </div>
#          <div class="study-nav__cta-text">
#           <div class="hidden-xs">
#            Find a degree that
#            <em>
#             fits your goals
#            </em>
#           </div>
#           <a class="btn btn-primary" data-cname="search_degrees" href="/directory/category/index.html" test-id="search_degrees">
#            Search degrees
#            <span class="icon-arrow-right">
#            </span>
#           </a>
#          </div>
#         </div>
#        </li>
#        <li data-cname="top_menu" test-id="top_menu">
#         <a class="hidden-xs" data-cname="schools" href="/article_directory/College_and_University_Overviews_(by_State).html" test-id="schools">
#          Schools
#         </a>
#         <a aria-controls="navSchools" aria-expanded="false" class="visible-xs collapsed" data-target="#navSchools" data-toggle="collapse">
#          Schools
#         </a>
#         <div class="study-nav__sub-nav collapse" id="navSchools">
#          <div class="col-sm-6 study-nav__sub-nav__border-right">
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="schoolsByDegree" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#schoolsByDegree" data-toggle="collapse">
#             Browse Schools by Degree Level
#            </a>
#            <ul class="no-bullet-list collapse" data-cname="school_education_level" id="schoolsByDegree" test-id="school_education_level">
#             <li>
#              <a href="/directory/degree_type/Graduate.html">
#               Graduate Degrees
#              </a>
#             </li>
#             <li>
#              <a href="/directory/degree_type/High_School_Diploma.html">
#               High School Diplomas
#              </a>
#             </li>
#             <li>
#              <a href="/directory/degree_type/Non-Degree.html">
#               Certificate Programs
#              </a>
#             </li>
#             <li>
#              <a href="/directory/degree_type/Post_Degree_Certificate.html">
#               Post Degree Certificates
#              </a>
#             </li>
#             <li>
#              <a href="/directory/degree_type/Undergraduate.html">
#               Undergraduate Degrees
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="allSchools" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#allSchools" data-toggle="collapse">
#             Browse Schools
#            </a>
#            <ul class="no-bullet-list collapse" data-cname="browse_schools" id="allSchools" test-id="browse_schools">
#             <li>
#              <a href="/article_directory/College_and_University_Overviews_(by_State).html">
#               Public Schools by State
#              </a>
#             </li>
#             <li>
#              <a href="/pages/Top_College_and_University_Video_Reviews.html">
#               University Video Reviews
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="col-sm-6">
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="careerCenter" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#careerCenter" data-toggle="collapse">
#             Career Counseling &amp; Job Center
#            </a>
#            <ul class="no-bullet-list collapse" data-cname="career_counseling" id="careerCenter" test-id="career_counseling">
#             <li>
#              <a href="/video_library/Job_Interviewing_Videos.html">
#               Job Interviewing Tip Videos
#              </a>
#             </li>
#             <li>
#              <a href="/video_library/Job_Networking_Videos.html">
#               Job Networking Videos
#              </a>
#             </li>
#             <li>
#              <a href="/video_library/Resume_Videos.html">
#               Résumé How To Videos
#              </a>
#             </li>
#             <li>
#              <a href="/articles/Finding_the_Right_Job_Searching_Resources_for_You.html">
#               Job Search Tips
#              </a>
#             </li>
#             <li>
#              <a href="/video_library/index.html">
#               Career Videos
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="study-nav__sub-nav__section">
#            <a aria-controls="careerResearch" aria-expanded="false" class="study-nav__sub-nav__section__header" data-target="#careerResearch" data-toggle="collapse">
#             Career Research
#            </a>
#            <ul class="no-bullet-list collapse" data-cname="career_research" id="careerResearch" test-id="career_research">
#             <li>
#              <a href="/video_library/Researching_Careers_Videos.html">
#               Researching Careers Videos
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Glossary_of_Career_Education_Programs.html">
#               Glossary of Careers
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Articles_about_Careers.html">
#               Career Info by Degree
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/Articles_about_Career_Planning.html">
#               Job Outlook by Region
#              </a>
#             </li>
#             <li>
#              <a href="/article_directory/index.html">
#               Degree &amp; Career Research Articles
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="visible-xs no-sub-nav">
#         <a class="supportEmailTrigger" data-cname="contact_support" href="/contact/index.html" test-id="contact_support">
#          Contact Support
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--[if lte IE 9]>
#     <script src="//oss.maxcdn.com/libs/respond.js/1.4.2/respond.matchmedia.addListener.min.js" defer></script>
# <![endif]-->
#   <!--[if lt IE 9]>
#     <script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js" defer></script>
#     <script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js" defer></script>
#     <script src='/js/polyfill-ddf04d1d4b.js' defer></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/json3/3.3.2/json3.min.js"></script>
#     <script src='/js/courseProgress/excanvas-c1bb7af6a3.js' class="certificate" defer></script>
# <![endif]-->
#   <!--[if gte IE 6]>
#     <link rel="stylesheet" href='/css/ieSpecific-632226d036.css'>
# <![endif]-->
#   <noscript>
#    <img alt="" height="1" src="/timages/noscript.gif" width="1"/>
#   </noscript>
#   <script type="text/javascript">
#    (function() {
# 		"use strict";
# 		window.globalUtils = {
# 			logLimit : 100,
# 			getRequestGuid: function() {
# 				var requestGuidElement = document.querySelector("meta[name=requestGuid]");
# 				var requestGuid;
# 				if (typeof requestGuidElement === 'undefined' || !requestGuidElement) {
# 					requestGuidElement = document.getElementById("requestGuid");
# 					requestGuid = requestGuidElement ? requestGuidElement.value : "";
# 				}
# 				else {
# 					requestGuid = requestGuidElement.getAttribute("content");
# 				}
# 				return requestGuid;
# 			},
# 			generateGuid: function() {
# 				Date.now = Date.now || function() {
# 					 return +new Date();
# 				 };
# 				var d = Date.now();
# 				return 'xxxxxxxxxxxx4xxxyxxxxxxxxxxxxxxx'.replace(/[xy]/g, function(c) {
# 					var r = (d + Math.random() * 16) % 16 | 0;
# 					d = Math.floor(d / 16);
# 					return (c === 'x' ? r : (r & 0x7 | 0x8)).toString(16);
# 				});
# 			},
# 			//these are used in the script tags below
# 			requireConfigError: function(event) {
# 				var exception = {};
# 				exception.message = "error loading require config file";
# 				exception.sourceJavascript = '/js/requireConfig-42da1080e8.js';
# 				exception.lineNumber = 0 + ':' + 0;
# 				globalUtils.logError(exception, "fileload");
# 			},
# 			requireError: function(event) {
# 				var exception = {};
# 				exception.message = "require.js failed to load";
# 				exception.sourceJavascript = "//cdnjs.cloudflare.com/ajax/libs/require.js/2.3.2/require.min.js";
# 				exception.lineNumber = 0 + ':' + 0;
# 				window.globalUtils.logError(exception, "require");
# 			},
# 			onError: function(message, url, lineNumber) {
# 				var exception = {};
# 				exception.message = message;
# 				exception.sourceJavascript = url;
# 				exception.lineNumber = lineNumber;
# 				exception.type = 'preEventTracking';
# 				window.globalUtils.logError(exception, "javascriptError")
# 			},
# 			logError: function(exception, type) {
# 				var loggableEvent = {};
# 				try {
# 					var urlCapture = /\((.+?):(\d+):(\d+)/g;
# 					var matchUrl = urlCapture.exec(exception.stack);
# 					if (matchUrl && matchUrl.length == 4) {
# 						var url = matchUrl[1];
# 						var line = matchUrl[2];
# 						var col = matchUrl[3];
# 						loggableEvent.sourceJavascript = url;
# 						loggableEvent.lineNumber = line + ':' + col;
# 					}
# 				}
# 				catch (e) {
# 					loggableEvent.sourceJavascript = exception.sourceJavascript;
# 					loggableEvent.lineNumber = exception.lineNumber;
# 				}
#
# 				function truncateLog(text) {
# 					return (text && text.length > 4000) ? text.substring(0, 4000) + "....[truncated]" : text;
# 				}
#
# 				loggableEvent.eventType = "javascriptError";
# 				loggableEvent.message = truncateLog(exception.message);
# 				loggableEvent.url = window.location.href;
# 				loggableEvent.name = exception.name;
# 				loggableEvent.stacktrace = truncateLog(exception.stack);
# 				loggableEvent.javascriptUUID = window.globalUtils.generateGuid();
# 				loggableEvent.pageRequestGuid = window.globalUtils.getRequestGuid();
# 				loggableEvent.type = type;
# 				loggableEvent.javascriptTimestamp = new Date().getTime();
# 				if(window.globalUtils.logLimit > 0){
# 					window.globalUtils.logLimit--;
# 					var request = new XMLHttpRequest();
# 					request.open("POST", "/eventLogger/eventLog.ajax");
# 					request.setRequestHeader("Content-Type", "application/json");
# 					request.send(JSON.stringify([loggableEvent]));
# 				}
#
# 			}
# 		};
# 		window.onerror = window.globalUtils.onError;
# 	})()
#   </script>
#   <script crossorigin="anonymous" defer="" onerror="window.globalUtils.requireError(event)" src="//cdnjs.cloudflare.com/ajax/libs/require.js/2.3.2/require.min.js">
#   </script>
#   <script data-remilon-env="prod-aws" defer="" onerror="window.globalUtils.requireConfigError(event)" src="/js/requireConfig-42da1080e8.js">
#   </script>
#   <script defer="" src="/js/trcking/tracking-55934fc313.js">
#   </script>
#   <script defer="" src="/js/trcking/eventTrackingInit-4ae9586985.js">
#   </script>
#   <script defer="" src="/js/redesign/hotjarTriggers-83d3a0ce1e.js">
#   </script>
#   <div class="main-container container-fluid" id="mainContainer">
#    <div class="wrapper" id="mainBody">
#     <div class="contentWithSidebar">
#      <div class="researchBreadcrumb" data-breadcrumb="" data-cname="breadcrumbs" test-id="breadcrumbs">
#       <div id="rss">
#        <a href="/rss/article_directory/Top_Information_Technology_Schools_in_California.html.xml">
#         <img alt="Top Information Technology Schools in California RSS feed subscription" class="rss-icon" data-cname="rss-icon" src="/images/rss.gif" test-id="rss-icon" title="Top Information Technology Schools in California RSS feed subscription"/>
#        </a>
#       </div>
#       <ul class="breadcrumbLinks">
#        <li>
#         <a href="/article_directory/Top_Information_Technology_Schools.html">
#          Top Information Technology Schools
#         </a>
#        </li>
#        <li class="divider">
#         /
#        </li>
#        <li>
#         <a href="/article_directory/Top_Information_Technology_Schools_in_California.html">
#          Top Information Technology Schools in...
#         </a>
#        </li>
#        <li class="divider">
#         /
#        </li>
#        <li>
#         Top Ranked School for Information...
#        </li>
#       </ul>
#      </div>
#      <div class="articleContent" id="mainArticle">
#       <div class="desktopArticleHeader">
#        <h1 class="articleTitle">
#         Top Ranked School for Information Technology - San Jose, CA
#        </h1>
#        <p class="date">
#        </p>
#        <p class="wikiDescription">
#         San Jose has few schools with programs in information technology. Find the best program for you by reading about schools' rankings, program offerings and tuition info.
#        </p>
#        <div class="articleCTA hidden-xs" data-cname="top_show_me_schools" data-target="#qualifierOverlay" data-toggle="modal" test-id="top_show_me_schools">
#         <span class="btn btn-cta cta-gold showMeSchools" data-cname="top_show_me_schools_button" id="dropDownSearchButton" test-id="top_show_me_schools_button">
#          Show Me Schools
#         </span>
#         <p class="articleCtaTag" data-cname="top_show_me_schools_link" id="ctaToolTip" test-id="top_show_me_schools_link">
#          <a>
#           View 10 Popular Schools
#           <span class="raquo">
#            »
#           </span>
#          </a>
#         </p>
#        </div>
#       </div>
#       <div class="articleContentContainer displayBlock visible-xs mobileArticleHeader" data-cname="top_show_me_schools_mobile" test-id="top_show_me_schools_mobile">
#        <div class="mobile-view-schools text-center" data-cname="top_show_me_schools_mobile" data-target="#qualifierOverlay" data-toggle="modal" test-id="top_show_me_schools_mobile">
#         <div class="btn btn-md btn-ghost" href="#searchResults">
#          View popular schools
#         </div>
#        </div>
#       </div>
#       <div class="wikiContent" id="article">
#        <div class=" articleSliderContainer open">
#         <h2 class=" articleSlider" id="section---SchoolAndRankingInformation">
#          School and Ranking Information
#         </h2>
#         <div class=" articleContentContainer">
#          <p>
#           There are a few schools in the San Jose area that have degrees in information technology, including both public and private not-for-profit institutions. The following schools are considered the top three based on proximity to San Jose, rankings and degree levels offered:
#          </p>
#          <ul>
#           <li>
#            <b>
#             Winner:
#            </b>
#            Santa Clara University, located in Santa Clara, is the top school due to its ranking at #2 for regional universities in the West from
#            <i>
#             U.S. News &amp; World Report
#            </i>
#            in 2013 and its high level of information technology degree offered.
#           </li>
#           <li>
#            <b>
#             Runner Up #1:
#            </b>
#            San Jose State University in San Jose secured the first runner up spot for its location, public institution status and tuition rates.
#           </li>
#           <li>
#            <b>
#             Runner Up #2:
#            </b>
#            University of San Francisco, situated in San Francisco, is in third for its national ranking just outside the top 100 schools in the United States in 2013 from
#            <i>
#             U.S. News &amp; World Report
#            </i>
#            and its multiple levels of IT degrees available.
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class=" articleSliderContainer">
#         <h2 class=" articleSlider" id="section---SchoolComparisonChart">
#          School Comparison Chart
#         </h2>
#         <div class=" articleContentContainer">
#          <p>
#          </p>
#          <table border="1" class="wikitable">
#           <tbody>
#            <tr class="odd">
#             <th>
#              Category
#             </th>
#             <th>
#              Santa Clara University
#             </th>
#             <th>
#              San Jose State University
#             </th>
#             <th>
#              University of San Francisco
#             </th>
#            </tr>
#            <tr>
#             <td>
#              <b>
#               Rankings (2013)
#              </b>
#             </td>
#             <td>
#              Ranked 2nd among universities in the Western region*
#             </td>
#             <td>
#              Named the 9th best public school in the Western region*
#             </td>
#             <td>
#              106th among national universities in the U.S.*
#             </td>
#            </tr>
#            <tr class="odd">
#             <td>
#              <b>
#               Location
#              </b>
#             </td>
#             <td>
#              Santa Clara, CA (about 2 miles from San Jose)
#             </td>
#             <td>
#              San Jose, CA
#             </td>
#             <td>
#              San Francisco, CA (roughly 42 miles from San Jose
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <b>
#               School Type
#              </b>
#             </td>
#             <td>
#              4-year, private not-for-profit
#             </td>
#             <td>
#              4-year, public
#             </td>
#             <td>
#              4-year, private not-for-profit
#             </td>
#            </tr>
#            <tr class="odd">
#             <td>
#              <b>
#               Tuition &amp; Fees (2012-2013)
#              </b>
#             </td>
#             <td>
#              $23,976 (graduate)**
#             </td>
#             <td>
#              $6,852, in-state; $18,510, out-of-state (undergrad)**
#             </td>
#             <td>
#              $965 per credit (bachelor's completion program)***; $20,390 per year (graduate)**
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <b>
#               Information Technology Degrees and Programs Offered
#              </b>
#             </td>
#             <td>
#              Master's degree
#             </td>
#             <td>
#              Bachelor's degree
#             </td>
#             <td>
#              Adult bachelor's completion and master's degrees
#             </td>
#            </tr>
#            <tr class="odd">
#             <td>
#              <b>
#               Information Technology Degrees Awarded (All Levels) in 2011-2012
#              </b>
#             </td>
#             <td>
#              22**
#             </td>
#             <td>
#              1,242 for business administration and management (information technology not provided)**
#             </td>
#             <td>
#              248 for business administration and management (information technology not provided)**
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <b>
#               Most Popular Information Technology Programs in 2011-2012
#              </b>
#             </td>
#             <td>
#              Master of Science in Information Systems (22 degrees awarded)**
#             </td>
#             <td>
#              N/A
#             </td>
#             <td>
#              N/A
#             </td>
#            </tr>
#            <tr class="odd">
#             <td>
#              <b>
#               Undergrad Graduation Rate (in 150% of normal program time) for 2005 Entering Class
#              </b>
#             </td>
#             <td>
#              N/A
#             </td>
#             <td>
#              46%**
#             </td>
#             <td>
#              70%**
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <b>
#               Noteworthy
#              </b>
#             </td>
#             <td>
#              12th among schools in the Western region for the best educational value in 2013*
#             </td>
#             <td>
#              Listed 38th among universities in the Western region in 2013*
#             </td>
#             <td>
#              Ranked 100th nationally by high school counselors in 2012*
#             </td>
#            </tr>
#           </tbody>
#          </table>
#          <p>
#           <i>
#            Sources: *U.S. News &amp; World Report, **NCES College Navigator, ***University of San Francisco.
#           </i>
#          </p>
#         </div>
#        </div>
#        <div class="cat-cta-group" data-target="#qualifierOverlay" data-toggle="modal">
#         <div class="cat-cta-header">
#          <h2>
#           Find schools that offer
#           <span class="noWrap">
#            these popular programs
#           </span>
#          </h2>
#         </div>
#         <div class="cat-cta-body">
#          <ul class="cat-cta-list" data-cname="cat_list" test-id="cat_list">
#           <li>
#            Computer and Information Support Services, Other
#           </li>
#           <li>
#            Information Science and Studies General
#           </li>
#           <li>
#            Information Technology
#           </li>
#           <li>
#            Robotics and Artificial Intelligence
#           </li>
#          </ul>
#          <div class="cat-cta-footer">
#           <span class="link link-underlined">
#            More Programs
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class=" articleSliderContainer">
#         <h2 class=" articleSlider" id="section---WinnerSantaClaraUniversity">
#          Winner: Santa Clara University
#         </h2>
#         <div class=" articleContentContainer">
#          <ul>
#           <li>
#            Ranked 72nd by Forbes in 2013
#           </li>
#           <li>
#            The SCU Leavey School of Business was named one of the best business schools in the Western region in 2013 by The Princeton Review
#           </li>
#           <li>
#            Accredited by the Association to Advance Collegiate Schools of Business (AACSB)
#           </li>
#           <li>
#            Courses taught by experienced IT professionals
#           </li>
#          </ul>
#          <p>
#           The Leavey School of Business at SCU offers a 54-credit Master of Science in Information Systems (MSIS) program that combines technology and business coursework to develop students who can work in advanced technology industry roles. The program, which takes a little over 2 years to complete, includes some required classes in computer-based decision making, object-oriented analysis, IS strategy, software project management and database management.
#          </p>
#          <p>
#           Additionally, students select 5 specialization courses and take 4 classes related to the completion of a capstone project. During the capstone project, participants must either solve a real-life issue for a local organization or create a theoretical solution for a current problem in the field of IT.
#          </p>
#         </div>
#        </div>
#        <div class=" articleSliderContainer">
#         <h2 class=" articleSlider" id="section---RunnerUp1SanJoseStateUniversity">
#          Runner-Up #1: San Jose State University
#         </h2>
#         <div class=" articleContentContainer">
#          <ul>
#           <li>
#            The business school is AACSB-accredited
#           </li>
#           <li>
#            The Princeton Review listed the Lucas Graduate School of Business as one of the top business schools in the Western region for 2013
#           </li>
#          </ul>
#          <p>
#           SJSU is located in the heart of the Silicon Valley and offers a Bachelor of Science in Business Administration (BSBA) program that includes several concentrations, one of them being management information systems (MIS). All students in the BSBA program must take classes in business computer productivity tools and business systems. Those who opt to pursue the MIS concentration might take other courses such as network and data communications, advanced business programming and executive support systems. Program participants also complete an MIS practicum. MBA-level courses available to students in the program include electronic commerce, IT methods, distributed information systems and database management.
#          </p>
#          <p>
#           Graduates of this program at SJSU have gone on to work for major corporations in the Silicon Valley. Some specific positions have included IT support specialists, IT auditors, internal tool developers and network architects.
#          </p>
#         </div>
#        </div>
#        <div class=" articleSliderContainer">
#         <h2 class=" articleSlider" id="section---RunnerUp2UniversityOfSanFrancisco">
#          Runner-Up #2: University of San Francisco
#         </h2>
#         <div class=" articleContentContainer">
#          <ul>
#           <li>
#            Named one of the best colleges in the Western region by The Princeton Review in 2013
#           </li>
#           <li>
#            McLaren School of Management is accredited by the AACSB
#           </li>
#           <li>
#            Ranked 141st best undergrad business program among all schools in the nation by 2013
#            <i>
#             U.S. News &amp; World Report
#            </i>
#           </li>
#          </ul>
#          <p>
#           The McLaren School of Management at USF offers an adult bachelor's degree completion program for working professionals that involves a concentration in IS. This Bachelor of Science in Management (BSM) program can be completed in about 23 months with some IS concentration classes in strategy and architecture, information technology, software development, system analysis and database applications. In addition to being offered at the main campus in San Francisco, the BSM program is also presented at the school's branch location in San Jose.
#          </p>
#          <p>
#           Additionally, USF has a 36-credit MSIS program that can be finished in about 27 months with curriculum approved by the Association for Information Systems and the Association for Computing Machinery. Students must have at least 2 years of professional experience for admission to the program, which includes some coursework in IT policy, IT security, enterprise systems and a capstone project. Students may select a concentration in information security or biotechnology and this program is offered at the USF San Jose campus only.
#          </p>
#         </div>
#        </div>
#       </div>
#       <div class="next-schools-wrapper">
#        <div class="btn btn-ghost btn-lg" data-cname="btn_overlay_next_view_schools" data-target="#qualifierOverlay" data-toggle="modal" data-track-visible="" test-id="btn_overlay_next_view_schools">
#         <span>
#          Next:
#         </span>
#         View Schools
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="sidebar">
#      <div class="sticky-module-group sticky-search-module">
#       <div class="sticky-module-body" data-float-module-start=".sticky-module-group" data-float-module-start-mobile=".footer" data-float-module-stop=".sticky-module-blocker" data-float-module-stop-mobile="#articleMain" data-float-search="" data-track-visible="">
#        <div class=" schoolSearchContainer " data-cname="drop_down_search" id="search" test-id="drop_down_search">
#         <div class="header">
#          <h2>
#           Perfect School Search
#          </h2>
#         </div>
#         <form action="/search/find.html" class="schoolSearchForm" id="dropDownSearchForm" name="dropDownSearchForm">
#          <div class="search-group-hloe">
#           <label class="numbered" for="hloe">
#            What is your highest level of education?
#           </label>
#           <select class="largeDropDown" data-cname="drop_down_hloe" data-submit-on-change="false" id="hloe" name="pq_educationLevel" test-id="drop_down_hloe">
#            <option value="">
#             Select your education level
#            </option>
#            <option value="NONE">
#             Some High School
#            </option>
#            <option value="HS">
#             High School Diploma / GED
#            </option>
#            <option value="SOME_COLLEGE">
#             Some College
#            </option>
#            <option value="ASSOCIATE">
#             Associate's Degree
#            </option>
#            <option value="BACHELOR">
#             Bachelor's Degree
#            </option>
#            <option value="MASTER">
#             Master's Degree
#            </option>
#            <option value="DOCTOR">
#             Doctorate Degree
#            </option>
#           </select>
#          </div>
#          <input id="topQ" name="q" type="hidden" value="0"/>
#          <div class="search-group-cat">
#           <label class="numbered" for="topC1">
#            What subject are you interested in?
#           </label>
#           <select class="largeDropDown" data-clear-first="topC2,topC3" data-cname="drop_down_c1" data-submit-on-change="false" id="topC1" name="c1" test-id="drop_down_c1">
#            <option value="ALL">
#             Select your preferred subject area
#            </option>
#            <option value="26">
#             Agriculture
#            </option>
#            <option value="35">
#             Architecture
#            </option>
#            <option value="463">
#             Biological and Biomedical Sciences
#            </option>
#            <option value="388">
#             Business
#            </option>
#            <option value="41">
#             Communications and Journalism
#            </option>
#            <option class="yellow" selected="selected" value="58">
#             Computer Sciences
#            </option>
#            <option value="83">
#             Culinary Arts and Personal Services
#            </option>
#            <option value="94">
#             Education
#            </option>
#            <option value="129">
#             Engineering
#            </option>
#            <option value="187">
#             Legal
#            </option>
#            <option value="200">
#             Liberal Arts and Humanities
#            </option>
#            <option value="282">
#             Mechanic and Repair Technologies
#            </option>
#            <option value="312">
#             Medical and Health Professions
#            </option>
#            <option value="237">
#             Physical Sciences
#            </option>
#            <option value="240">
#             Psychology
#            </option>
#            <option value="295">
#             Transportation and Distribution
#            </option>
#            <option value="298">
#             Visual and Performing Arts
#            </option>
#           </select>
#           <select class="largeDropDown" data-clear-first="topC3" data-cname="drop_down_c2" data-submit-on-change="false" id="topC2" name="c2" test-id="drop_down_c2">
#            <option value="ALL">
#             Narrow your preferred subject area
#            </option>
#            <option class="yellow" selected="selected" value="74">
#             Computer and Information Sciences, General
#            </option>
# ...
#              Bachelors degree
#             </a>
#            </div>
#            <div class="faux-select-item" data-cname="fbar_select_master" test-id="fbar_select_master">
#             <a href="/search/find.html?state=&amp;zip=95101&amp;radius=100&amp;companyIdsToExclude=&amp;c1=58&amp;c2=74&amp;c3=76&amp;q1=0&amp;q2=0&amp;pq_educationLevel=MASTER">
#              Masters degree
#             </a>
#            </div>
#            <div class="faux-select-item" data-cname="fbar_select_doctor" test-id="fbar_select_doctor">
#             <a href="/search/find.html?state=&amp;zip=95101&amp;radius=100&amp;companyIdsToExclude=&amp;c1=58&amp;c2=74&amp;c3=76&amp;q1=0&amp;q2=0&amp;pq_educationLevel=DOCTOR">
#              Doctorate
#             </a>
#            </div>
#            <div class="faux-select-item" data-cname="fbar_select_none" test-id="fbar_select_none">
#             <a href="/search/find.html?state=&amp;zip=95101&amp;radius=100&amp;companyIdsToExclude=&amp;c1=58&amp;c2=74&amp;c3=76&amp;q1=0&amp;q2=0&amp;pq_educationLevel=NONE">
#              Still in HS
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <form action="/search/find.html" class="qualifier-modal-edu-level modal fade in " id="qualifierOverlay" method="get" role="dialog" tabindex="-1">
#     <div class="modal-dialog" role="document">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-label="Close" class="close" data-cname="overlay_close_x" data-dismiss="modal" test-id="overlay_close_x" type="button">
#         <span aria-hidden="true">
#          ×
#         </span>
#        </button>
#        <div class="model-header-inner">
#         <h4 class="modal-title">
#          Select your highest
#          <span class="noWrap">
#           level of education
#          </span>
#         </h4>
#         <p class="hidden-xs">
#          Get Matched to Schools
#         </p>
#        </div>
#       </div>
#       <div class="modal-body">
#        <div class="edu-level-group">
#         <div class="edu-level-item">
#          <button class="btn" data-cname="overlay_some_hs" name="pq_educationLevel" test-id="overlay_some_hs" type="submit" value="NONE">
#           Some high school
#          </button>
#         </div>
#         <div class="edu-level-item">
#          <button class="btn" data-cname="overlay_hs_ged" name="pq_educationLevel" test-id="overlay_hs_ged" type="submit" value="HS">
#           High school / GED
#          </button>
#         </div>
#         <div class="edu-level-item">
#          <button class="btn" data-cname="overlay_some_college" name="pq_educationLevel" test-id="overlay_some_college" type="submit" value="SOME_COLLEGE">
#           Some college
#          </button>
#         </div>
#         <div class="edu-level-item">
#          <button class="btn" data-cname="overlay_college_degree" name="pq_educationLevel" test-id="overlay_college_degree" type="submit" value="">
#           College degree
#          </button>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <input name="c3" type="hidden" value="76"/>
#     <input name="zip" type="hidden" value="95101"/>
#     <input name="online" type="hidden" value="false"/>
#     <input name="radius" type="hidden" value="100"/>
#     <input name="c1" type="hidden" value="58"/>
#     <input name="c2" type="hidden" value="74"/>
#     <input name="state" type="hidden" value=""/>
#    </form>
#    <!-- Snap Engage -->
#   </div>
#   <footer class="footer " data-cname="footer" id="homepageTestFooter" test-id="footer">
#    <div class="container-fluid">
#     <div class="visible-xs">
#      <div class="col50 appDownloads">
#       <h4>
#        Download the app
#       </h4>
#       <a class="appDownloadButton topButton" data-cname="footer_google_play_mobile_app_download" href="https://play.google.com/store/apps/details?id=com.study.app&amp;utm_source=global_co&amp;utm_medium=prtnr&amp;utm_content=Mar2515&amp;utm_campaign=PartBadge&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-PartBadge-Mar2515-1" target="_blank" test-id="google_play_mobile_app_download">
#        <img alt="Get it on Google Play" src="https://play.google.com/intl/en_us/badges/images/generic/en_badge_web_generic.png"/>
#       </a>
#       <a class="appDownloadButton bottomButton" data-cname="footer_ios_mobile_app_download" href="https://itunes.apple.com/us/app/study.com-video-lessons-learn/id1128875336" target="_blank" test-id="ios_mobile_app_download">
#        <img alt="Get it on the App Store" src="/images/reDesign/ctas/apple-app-store-download-button.png"/>
#       </a>
#      </div>
#      <div class="col50">
#       <div class="footer__connect__social" data-cname="footer_social" test-id="footer_social">
#        <div class="col-sm-6 no-padding">
#         <a class="footer__connect__social__icon" data-cname="bottom_facebook" data-external-link="" href="http://www.facebook.com/StudyDotCom" target="_blank" test-id="bottom_facebook">
#          <span class="icon icon-facebook-sign">
#          </span>
#         </a>
#         <a class="footer__connect__social__icon" data-cname="bottom_twitter" data-external-link="" href="http://twitter.com/studydotcom" target="_blank" test-id="bottom_twitter">
#          <span class="icon icon-twitter-sign">
#          </span>
#         </a>
#        </div>
#        <div class="col-sm-6 no-padding">
#         <a class="footer__connect__social__icon" data-cname="bottom_google" data-external-link="" href="https://plus.google.com/+EducationPortalVideo" target="_blank" test-id="bottom_google">
#          <span class="icon icon-google-plus-sign">
#          </span>
#         </a>
#         <a class="footer__connect__social__icon" data-cname="bottom_youtube" data-external-link="" href="http://www.youtube.com/user/EducationPortalVideo/" target="_blank" test-id="bottom_youtube">
#          <span class="icon icon-youtube-sign2">
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="clearfix">
#     </div>
#     <div class="col-sm-4 no-padding">
#      <div class="col50">
#       <h4>
#        <a data-cname="products" href="/academy/plans.html" test-id="products">
#         Products
#        </a>
#       </h4>
#       <ul>
#        <li>
#         <a data-cname="student_solutions" href="/academy/plans.html" test-id="student_solutions">
#          Student Solutions
#         </a>
#        </li>
#        <li>
#         <a data-cname="teacher_solutions" href="/academy/plans/teacher.html" test-id="teacher_solutions">
#          Teacher Solutions
#         </a>
#        </li>
#        <li>
#         <a data-cname="corporate_solutions" href="/academy/plans/corporate.html" test-id="corporate_solutions">
#          Corporate Solutions
#         </a>
#        </li>
#        <li>
#         <a data-cname="for_schools" href="/academy/plans/teacher-group.html" test-id="for_schools">
#          Study.com for Schools
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col50">
#       <h4>
#        <a data-cname="about_us" href="/pages/About_Us.html" test-id="about_us">
#         About Us
#        </a>
#       </h4>
#       <ul>
#        <li>
#         <a data-cname="bottom_blog" href="/blog/index.html" test-id="bottom_blog">
#          Blog
#         </a>
#        </li>
#        <li>
#         <a data-cname="careers" href="/pages/Employment.html" test-id="careers">
#          Careers
#         </a>
#        </li>
#        <li>
#         <a data-cname="advertise_with_us" href="/pages/Advertise.html" test-id="advertise_with_us">
#          Get Your School Listed
#         </a>
#        </li>
#        <li>
#         <a data-cname="teach_for_us" href="/pages/Contractors.html" test-id="teach_for_us">
#          Teach For Us
#         </a>
#        </li>
#        <li>
#         <a data-cname="press_center" href="/press.html" test-id="press_center">
#          Press Center
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="clearfix visible-xs">
#     </div>
#     <div class="col-sm-2">
#      <h4>
#       <a data-cname="support" href="/contact/index.html" test-id="support">
#        Support
#       </a>
#      </h4>
#      <ul>
#       <li>
#        <a class="supportEmailTrigger" data-cname="contact_support" data-external-link="" href="/contact/index.html" test-id="contact_support">
#         Contact Support
#        </a>
#       </li>
#       <li>
#        <a data-cname="faq" data-external-link="" href="http://support.study.com" target="_blank" test-id="faq">
#         FAQ
#        </a>
#       </li>
#       <li>
#        <a data-cname="site_feedback" href="/contact/index.html" test-id="site_feedback">
#         Site Feedback
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="col-sm-2 appDownloads hidden-xs">
#      <h4>
#       Download the app
#      </h4>
#      <a class="appDownloadButton topButton" data-cname="footer_google_play_mobile_app_download" href="https://play.google.com/store/apps/details?id=com.study.app&amp;utm_source=global_co&amp;utm_medium=prtnr&amp;utm_content=Mar2515&amp;utm_campaign=PartBadge&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-PartBadge-Mar2515-1" target="_blank" test-id="google_play_mobile_app_download">
#       <img alt="Get it on Google Play" src="https://play.google.com/intl/en_us/badges/images/generic/en_badge_web_generic.png"/>
#      </a>
#      <a class="appDownloadButton bottomButton" data-cname="footer_ios_mobile_app_download" href="https://itunes.apple.com/us/app/study.com-video-lessons-learn/id1128875336" target="_blank" test-id="ios_mobile_app_download">
#       <img alt="Get it on the App Store" src="/images/reDesign/ctas/apple-app-store-download-button.png"/>
#      </a>
#     </div>
#     <div class="col-sm-4 hidden-xs">
#      <div class="footer__connect__social" data-cname="footer_social" test-id="footer_social">
#       <a class="footer__connect__social__icon" data-cname="bottom_facebook" data-external-link="" href="http://www.facebook.com/StudyDotCom" target="_blank" test-id="bottom_facebook">
#        <span class="icon icon-facebook-sign">
#        </span>
#       </a>
#       <a class="footer__connect__social__icon" data-cname="bottom_twitter" data-external-link="" href="http://twitter.com/studydotcom" target="_blank" test-id="bottom_twitter">
#        <span class="icon icon-twitter-sign">
#        </span>
#       </a>
#       <a class="footer__connect__social__icon" data-cname="bottom_google" data-external-link="" href="https://plus.google.com/+EducationPortalVideo" target="_blank" test-id="bottom_google">
#        <span class="icon icon-google-plus-sign">
#        </span>
#       </a>
#       <a class="footer__connect__social__icon" data-cname="bottom_youtube" data-external-link="" href="http://www.youtube.com/user/EducationPortalVideo/" target="_blank" test-id="bottom_youtube">
#        <span class="icon icon-youtube-sign2">
#        </span>
#       </a>
#      </div>
#      <div class="clearfix">
#      </div>
#      <div class="workingScholars">
#       <a data-cname="working_scholars_footer" href="/pages/working-scholars.html" test-id="working_scholars_footer">
#        <img src="/images/reDesign/home/homepage-test/svg/art_working_scholars_555.svg"/>
#       </a>
#       <a class="workingScholarsText col-sm-8" data-cname="working_scholars_logo_footer" href="/pages/working-scholars.html" test-id="working_scholars_logo_footer">
#        Bringing Tuition-Free College to the Community
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="bbbLogo visible-xs">
#     <a alt="Study.com is a BBB Accredited Educational Consultant in Mountain View, CA" class="footer__links-container__bbb-link" data-cname="bbb_logo" data-external-link="" href="http://www.bbb.org/sanjose/business-reviews/educational-consultants/remilon-1000006412#bbbseal" id="bbblink" target="_blank" test-id="bbb_logo" title="Study.com is a BBB Accredited Educational Consultant in Mountain View, CA">
#     </a>
#    </div>
#    <div class="container-fluid copyright">
#     <p>
#      ©  copyright 2003-2017 Study.com.
# 			All other trademarks and copyrights are the property of their respective owners.
# 			All rights reserved.
#     </p>
#     <div class="bbbLogo hidden-xs">
#      <a alt="Study.com is a BBB Accredited Educational Consultant in Mountain View, CA" class="footer__links-container__bbb-link" data-cname="bbb_logo" data-external-link="" href="http://www.bbb.org/sanjose/business-reviews/educational-consultants/remilon-1000006412#bbbseal" id="bbblink" target="_blank" test-id="bbb_logo" title="Study.com is a BBB Accredited Educational Consultant in Mountain View, CA">
#      </a>
#     </div>
#     <div class="footer__copyright">
#      Curriculum, relevancy of sample programs, and outcomes will vary by school.
#     </div>
#     <div>
#      <a data-cname="terms_of_use" href="/pages/terms_of_use.html" rel="nofollow" test-id="terms_of_use">
#       Terms of Use
#      </a>
#      <a data-cname="privacy_policy" href="/pages/privacy_policy.html" rel="nofollow" test-id="privacy_policy">
#       Privacy Policy
#      </a>
#      <a data-cname="dmca" href="/pages/dmca.html" rel="nofollow" test-id="dmca">
#       DMCA Notice
#      </a>
#     </div>
#    </div>
#   </footer>
#   <script defer="" src="/js/video/initEmbeds-e7b2cbbfb7.js">
#   </script>
#   <script defer="" src="/js/redesign/global-728b2ed2c1.js">
#   </script>
#   <script data-no-freshdesk-button="" data-skip-mobile-reformat="" defer="" src="/js/redesign/research/articleMain-d48ef147d1.js">
#   </script>
#   <!-- {"site":"site-sdy-3-2.ue1.prod.study.com"} -->
#   <!-- {"services":[]} -->
#   <!-- {"rem ip":"false"} -->
#   <div class="hidden" data-member-account-type="NONE" data-member-has-institution-license="false" data-member-id="" data-member-persona="" data-member-product-key="" data-member-status="" id="memberData">
#   </div>
#   <div class="hidden" data-ssoe-debug-cookie-value="" id="ssoeDebugCookieValue">
#   </div>
#  </body>
# </html>
#
# <table border="1" class="wikitable">
# <tbody>
# <tr class="odd">
# <th> Category </th>
# <th> Santa Clara University </th>
# <th> San Jose State University </th>
# <th> University of San Francisco</th>
# </tr>
# <tr>
# <td> <b>Rankings (2013)</b> </td>
# <td> Ranked 2nd among universities in the Western region* </td>
# <td> Named the 9th best public school in the Western region* </td>
# <td> 106th among national universities in the U.S.*</td>
# </tr>
# <tr class="odd">
# <td> <b>Location</b> </td>
# <td> Santa Clara, CA (about 2 miles from San Jose) </td>
# <td> San Jose, CA </td>
# <td> San Francisco, CA (roughly 42 miles from San Jose</td>
# </tr>
# <tr>
# <td> <b>School Type</b> </td>
# <td> 4-year, private not-for-profit </td>
# <td> 4-year, public </td>
# <td> 4-year, private not-for-profit</td>
# </tr>
# <tr class="odd">
# <td> <b>Tuition &amp; Fees (2012-2013)</b> </td>
# <td> $23,976 (graduate)** </td>
# <td> $6,852, in-state; $18,510, out-of-state (undergrad)** </td>
# <td> $965 per credit (bachelor's completion program)***; $20,390 per year (graduate)**</td>
# </tr>
# <tr>
# <td> <b>Information Technology Degrees and Programs Offered</b> </td>
# <td> Master's degree </td>
# <td> Bachelor's degree </td>
# <td> Adult bachelor's completion and master's degrees</td>
# </tr>
# <tr class="odd">
# <td> <b>Information Technology Degrees Awarded (All Levels) in 2011-2012</b> </td>
# <td> 22** </td>
# <td> 1,242 for business administration and management (information technology not provided)** </td>
# <td> 248 for business administration and management (information technology not provided)**</td>
# </tr>
# <tr>
# <td> <b>Most Popular Information Technology Programs in 2011-2012</b> </td>
# <td> Master of Science in Information Systems (22 degrees awarded)** </td>
# <td> N/A </td>
# <td> N/A</td>
# </tr>
# <tr class="odd">
# <td> <b>Undergrad Graduation Rate (in 150% of normal program time) for 2005 Entering Class</b> </td>
# <td> N/A </td>
# <td> 46%** </td>
# <td> 70%**</td>
# </tr>
# <tr>
# <td> <b>Noteworthy</b> </td>
# <td> 12th among schools in the Western region for the best educational value in 2013* </td>
# <td> Listed 38th among universities in the Western region in 2013* </td>
# <td> Ranked 100th nationally by high school counselors in 2012*</td>
# </tr>
# </tbody>
# </table>

# %%
tableData1 = soupDataComp.find('table')
tableDataF = tableData1.find('tbody')
for rows in tableDataF.find_all('tr'):
    for cells in rows.find_all('td'):
        print(cells.text)
# Out:
#  Rankings (2013)
#  Ranked 2nd among universities in the Western region*
#  Named the 9th best public school in the Western region*
#  106th among national universities in the U.S.*
#  Location
#  Santa Clara, CA (about 2 miles from San Jose)
#  San Jose, CA
#  San Francisco, CA (roughly 42 miles from San Jose
#  School Type
#  4-year, private not-for-profit
#  4-year, public
#  4-year, private not-for-profit
#  Tuition & Fees (2012-2013)
#  $23,976 (graduate)**
#  $6,852, in-state; $18,510, out-of-state (undergrad)**
#  $965 per credit (bachelor's completion program)***; $20,390 per year (graduate)**
#  Information Technology Degrees and Programs Offered
#  Master's degree
#  Bachelor's degree
#  Adult bachelor's completion and master's degrees
#  Information Technology Degrees Awarded (All Levels) in 2011-2012
#  22**
#  1,242 for business administration and management (information technology not provided)**
#  248 for business administration and management (information technology not provided)**
#  Most Popular Information Technology Programs in 2011-2012
#  Master of Science in Information Systems (22 degrees awarded)**
#  N/A
#  N/A
#  Undergrad Graduation Rate (in 150% of normal program time) for 2005 Entering Class
#  N/A
#  46%**
#  70%**
#  Noteworthy
#  12th among schools in the Western region for the best educational value in 2013*
#  Listed 38th among universities in the Western region in 2013*
#  Ranked 100th nationally by high school counselors in 2012*

# %%
dataCompF = {
    'Category' : [],
    'Santa Clara University' : [],
    'San Jose State University' : [],
    'University of San Francisco' : []
}

table_columns = ['Category','Santa Clara University','San Jose State University','University of San Francisco']
count = 0
for rows in tableDataF.find_all('tr'):
    for cells in rows.find_all('td'):
        dataCompF[table_columns[count%4]].append(cells.get_text() )
        count = count+1
    
DataCompFinal = pandas.DataFrame(dataCompF)

# %%
DataCompFinal
# Out:
#                                             Category  \
# 0                                   Rankings (2013)
# 1                                          Location
# 2                                       School Type
# 3                        Tuition & Fees (2012-2013)
# 4   Information Technology Degrees and Programs O...
# 5   Information Technology Degrees Awarded (All L...
# 6   Most Popular Information Technology Programs ...
# 7   Undergrad Graduation Rate (in 150% of normal ...
# 8                                        Noteworthy
#
#                            San Jose State University  \
# 0   Named the 9th best public school in the Weste...
# 1                                      San Jose, CA
# 2                                    4-year, public
# 3   $6,852, in-state; $18,510, out-of-state (unde...
# 4                                 Bachelor's degree
# 5   1,242 for business administration and managem...
# 6                                               N/A
# 7                                             46%**
# 8   Listed 38th among universities in the Western...
#
#                               Santa Clara University  \
# 0   Ranked 2nd among universities in the Western ...
# 1     Santa Clara, CA (about 2 miles from San Jose)
# 2                    4-year, private not-for-profit
# 3                              $23,976 (graduate)**
# 4                                   Master's degree
# 5                                              22**
# 6   Master of Science in Information Systems (22 ...
# 7                                               N/A
# 8   12th among schools in the Western region for ...
#
#                          University of San Francisco
# 0     106th among national universities in the U.S.*
# 1   San Francisco, CA (roughly 42 miles from San ...
# 2                     4-year, private not-for-profit
# 3   $965 per credit (bachelor's completion progra...
# 4   Adult bachelor's completion and master's degrees
# 5   248 for business administration and managemen...
# 6                                                N/A
# 7                                              70%**
# 8   Ranked 100th nationally by high school counse...

# %%
dataframe.to_csv('Lab4-Dataset2.csv', index=False, encoding='utf-8')
dataframe2.to_csv('Lab4-Dataset3.csv', index=False, encoding='utf-8')
dataframe3.to_csv('Lab4-Dataset4.csv', index=False, encoding='utf-8')
DataCompFinal.to_csv('Lab4-Dataset5.csv', index=False, encoding='utf-8')

# %% [markdown]
# Santa Clara offers a good MSIS course!
#
# - It has several industry oriented tracks which helps the students to keep in touch with the latest technologies used in the Industry. The curriculum is designed in consultation with Industry experts. This gives an advantage for the students, they can perform better due to the exposure to latest technology.
#
# - Ranked 2nd in the among the universities in the West region. This certifies for the level of the college, quality of the faculty and the level of the students that pursue the course in the university.
#
# - It has a good Return on Investment. The ROI for the program is quite high, considering the opportunities that are available after graduating from the program and the median pay for these opportunities. The number of jobs available for this particular course is also higher than the average job growth rate, this also adds up as an advantage for the course as this gives the students more opportunities.
#
#
# To solidify the claim even more, if we have more data on the actual number of students (alumni) who secured a job within six months of graduation from the university, it would be helpful. This would further solidify the claim that the MSIS course is good and offers the required exposure to the students in joining the work force of the Industry.
#
#
# Link to tableau public - https://public.tableau.com/profile/aashreya.agasthya.kundurthy#!/vizhome/lab4_9/Dashboard1?publish=yes
